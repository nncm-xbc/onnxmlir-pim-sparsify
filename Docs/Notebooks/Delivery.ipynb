# %% [markdown]
# # Container for data

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

class Program:
    # this class contains in a structured manner matrices and biases
    # which encode the semantics of the program network, in the same fashion
    # of the source code of a program

    def __init__(self, topology , activation_functions_list):
        self.topology = topology
        self.activation_functions_list = activation_functions_list
        self.W = [ 0 for t in topology[:-1]]
        self.b = [ 0 for t in topology[:-1]]
    def random_init_weights(self):
        for layer in range(len(self.topology[:-1])):
            self.W[layer] = np.random.normal( size = (self.topology[layer + 1] , self.topology[layer] ) )**2
            size = self.W[layer].shape[0] * self.W[layer].shape[1] 
            for i in range(size - int(np.sqrt(size))):
                r = np.random.choice(len(self.W[layer]))
                c = np.random.choice(len(self.W[layer].T))
                self.W[layer][r,c] = 0.   # adding some sparsity
                
            self.b[layer] = np.random.normal( size = self.topology[layer + 1] )
    def print(self):
        for i,layer in enumerate(self.topology[:-1]):
            print("layer %d->%d "%(i,i+1))
            print("W.shape = %s \t b.shape = %s" % (str(self.W[i].shape),str(self.b[i].shape)))
            
    def visualize_weights(self):
        for w in self.W:
            print(w.shape)
            plt.figure(figsize=(10,10))
            plt.imshow(w > 0.)

# %%
rete = Program([5,30,30,1], ["RELU","RELU","LINEAR"])
rete.random_init_weights()
rete.visualize_weights()
# Out:
# (30, 5)
# (30, 30)
# (1, 30)

# %% [markdown]
# # Intermediate representation

# %%
class c:
    # every element is a node in the tree.
    # the first argument denotes the name of the node ; the possible next arguments are a list of the sons.
    # Note that nodes without sons are simply leaf (eg. ADD, MUL,...)
    def __init__(self, ID, *args):
        self.id   = ID
        self.sons = list()
        for arg in args:
            self.sons.append(arg)
    def print(self,level = 0):
        print( ("\t" * level) + str(self.id) )
        for s in self.sons:
            s.print(level + 1)
    def __str__(self):
        ret = str(self.id)
        if len(self.sons) > 0:
            ret += "("
            for s in self.sons:
                ret += str(s)
                if s != self.sons[-1]:
                    ret += ','
            ret += ")"
        return ret
    def flatten(self):
        ret = []
        ret += [self.id]
        for s in self.sons:
            ret += s.flatten()
        return ret
        
C = c("BINOP", c("ADD"), c("TEMP",c(1)), c("CONST",c(2)) )        
C.flatten()
# Out:
# ['BINOP', 'ADD', 'TEMP', 1, 'CONST', 2]

# %%
def IR(program, compile_time_data = True):
    # for every layer
    print("y = input")
    ret = list()
    
    for layer,t in enumerate(program.topology[1:]):
        IR_instruction = c("COMMENT", c("START"))
        print(IR_instruction)
        ret.append(IR_instruction)
        
        f = program.activation_functions_list[layer]
        R_offset = t
        for i in range(len(program.b[layer])): # for every row
            #print("R[%d] = 0" % (i))
            #print("MOVE( TEMP(%d) , CONST(0) )" % (i + R_offset))
            IR_instruction = c(
                    "MOVE",
                     c("TEMP" , c(i + R_offset) ),
                     c("CONST", c(0))
            )
            print(str(IR_instruction))
            ret.append(IR_instruction)
        for i in range(len(program.W[layer])): # for every row
            for j in range(len(program.W[layer].T)): # for every column
                #print(" >> R[%d] +=  W[%d->%d][%d,%d] * Y[%d]" % (i,layer,layer+1,i,j,j))
                if compile_time_data:
                    if( program.W[layer][i,j] != 0):
                        # if there is zero is useless to compute the contribution
                        #print("->MOVE(TEMP(%d),BINOP(ADD,TEMP(%d),BINOP(MUL,CONST(%f),TEMP(%d)))) " % (i + R_offset,i + R_offset, program.W[layer][i,j],i )) # COMPILE DATA HYPOTHESIS
                        IR_instruction = c(
                            "MOVE",
                            c("TEMP",
                                c(i + R_offset)
                            ),
                            c("BINOP",
                                c("ADD"),
                                c("TEMP",
                                    c(i + R_offset)
                                ),
                                c("BINOP",
                                    c("MUL"),
                                    c("CONST",
                                         c(program.W[layer][i,j])
                                     ),
                                    c("TEMP",
                                     c(i)
                                     )
                                )
                            )
                        )
                        print(IR_instruction)
                        ret.append(IR_instruction)
                    else:
                        print("# here there was a 0 so we exploit sparsity ")
                else:
                    print("#TODO")
                    #N = len(program.W[layer])
                    #ijth_element_position = i*N + j
                    #print("MOVE(TEMP(%d),BINOP(ADD,TEMP(%d),BINOP(MUL,MEM(BINOP(ADD,&W,CONST(%d))),TEMP(%d))))" % (i + R_offset,i + R_offset, ijth_element_position,i )) # COMPILE DATA HYPOTHESIS
        for i in range(len(program.b[layer])): # for every row
            # a priori in compile time since the amount of "repetitions" doens't scale quadratically , in opposite to weights
            #print("->MOVE(TEMP(%d),BINOP(ADD,TEMP(%d),CONST(%f)))" % (i, i + R_offset , program.b[layer][i]) )
            IR_instruction = c("MOVE",
                                c("TEMP",
                                 c(i)
                                 ),
                                c("BINOP",
                                 c("ADD"),
                                 c("TEMP",
                                   c(i + R_offset)
                                  ),
                                 c("CONST",
                                  c(program.b[layer][i])
                                  )
                                 )
                                )
            print((IR_instruction))
            ret.append(IR_instruction)
        for i in range(len(program.b[layer])): # for every row
            #print("y[%d] = f(y[%d])" % (i,i))
            #print("MOVE( TEMP(%d) , CALL( %s, TEMP(%d) ) )" % (i,f,i) )
            IR_instruction = c("MOVE",
                c("TEMP",
                     c(i)
                 ),
                c("CALL",
                     c(f),
                     c("TEMP",
                          c(i)
                      )
                 )
            )
            print(IR_instruction)
            ret.append(IR_instruction)
        IR_instruction = c("COMMENT", c("END"))
        print(IR_instruction)
        ret.append(IR_instruction)
    return ret
intermediate_representation = IR(rete,True)
# Out:
# y = input
# COMMENT(START)
# MOVE(TEMP(30),CONST(0))
# MOVE(TEMP(31),CONST(0))
# MOVE(TEMP(32),CONST(0))
# MOVE(TEMP(33),CONST(0))
# MOVE(TEMP(34),CONST(0))
# MOVE(TEMP(35),CONST(0))
# MOVE(TEMP(36),CONST(0))
# MOVE(TEMP(37),CONST(0))
# MOVE(TEMP(38),CONST(0))
# MOVE(TEMP(39),CONST(0))
# MOVE(TEMP(40),CONST(0))
# MOVE(TEMP(41),CONST(0))
# MOVE(TEMP(42),CONST(0))
# MOVE(TEMP(43),CONST(0))
# MOVE(TEMP(44),CONST(0))
# MOVE(TEMP(45),CONST(0))
# MOVE(TEMP(46),CONST(0))
# MOVE(TEMP(47),CONST(0))
# MOVE(TEMP(48),CONST(0))
# MOVE(TEMP(49),CONST(0))
# MOVE(TEMP(50),CONST(0))
# MOVE(TEMP(51),CONST(0))
# MOVE(TEMP(52),CONST(0))
# MOVE(TEMP(53),CONST(0))
# MOVE(TEMP(54),CONST(0))
# MOVE(TEMP(55),CONST(0))
# MOVE(TEMP(56),CONST(0))
# MOVE(TEMP(57),CONST(0))
# MOVE(TEMP(58),CONST(0))
# MOVE(TEMP(59),CONST(0))
# MOVE(TEMP(30),BINOP(ADD,TEMP(30),BINOP(MUL,CONST(1.1216929757922613),TEMP(0))))
# MOVE(TEMP(30),BINOP(ADD,TEMP(30),BINOP(MUL,CONST(1.012059009043913),TEMP(0))))
# MOVE(TEMP(30),BINOP(ADD,TEMP(30),BINOP(MUL,CONST(4.265543653205302e-05),TEMP(0))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(30),BINOP(ADD,TEMP(30),BINOP(MUL,CONST(0.26742246871033903),TEMP(0))))
# MOVE(TEMP(31),BINOP(ADD,TEMP(31),BINOP(MUL,CONST(0.00010945647186304949),TEMP(1))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(31),BINOP(ADD,TEMP(31),BINOP(MUL,CONST(0.017951099648171244),TEMP(1))))
# MOVE(TEMP(31),BINOP(ADD,TEMP(31),BINOP(MUL,CONST(0.49389343198492014),TEMP(1))))
# MOVE(TEMP(31),BINOP(ADD,TEMP(31),BINOP(MUL,CONST(0.3632896828685664),TEMP(1))))
# MOVE(TEMP(32),BINOP(ADD,TEMP(32),BINOP(MUL,CONST(1.3834821139138238),TEMP(2))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(33),BINOP(ADD,TEMP(33),BINOP(MUL,CONST(0.029616996175500582),TEMP(3))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(33),BINOP(ADD,TEMP(33),BINOP(MUL,CONST(1.3277652245243436),TEMP(3))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(33),BINOP(ADD,TEMP(33),BINOP(MUL,CONST(0.7981799068323343),TEMP(3))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(34),BINOP(ADD,TEMP(34),BINOP(MUL,CONST(0.2069309310579088),TEMP(4))))
# MOVE(TEMP(34),BINOP(ADD,TEMP(34),BINOP(MUL,CONST(0.11269648941783353),TEMP(4))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(34),BINOP(ADD,TEMP(34),BINOP(MUL,CONST(0.592174149152645),TEMP(4))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(35),BINOP(ADD,TEMP(35),BINOP(MUL,CONST(0.048616846734440194),TEMP(5))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(36),BINOP(ADD,TEMP(36),BINOP(MUL,CONST(5.669426043320063),TEMP(6))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(36),BINOP(ADD,TEMP(36),BINOP(MUL,CONST(0.2172439381452574),TEMP(6))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(37),BINOP(ADD,TEMP(37),BINOP(MUL,CONST(8.06822907574454),TEMP(7))))
# MOVE(TEMP(37),BINOP(ADD,TEMP(37),BINOP(MUL,CONST(0.0010639354866935511),TEMP(7))))
# MOVE(TEMP(37),BINOP(ADD,TEMP(37),BINOP(MUL,CONST(5.181991051316486),TEMP(7))))
# MOVE(TEMP(37),BINOP(ADD,TEMP(37),BINOP(MUL,CONST(5.377659927540175),TEMP(7))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(38),BINOP(ADD,TEMP(38),BINOP(MUL,CONST(8.234334438188708e-05),TEMP(8))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(39),BINOP(ADD,TEMP(39),BINOP(MUL,CONST(1.3328530208042564),TEMP(9))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(39),BINOP(ADD,TEMP(39),BINOP(MUL,CONST(1.8169475684093035),TEMP(9))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(40),BINOP(ADD,TEMP(40),BINOP(MUL,CONST(4.098399689485429),TEMP(10))))
# MOVE(TEMP(40),BINOP(ADD,TEMP(40),BINOP(MUL,CONST(0.030327267275008993),TEMP(10))))
# MOVE(TEMP(41),BINOP(ADD,TEMP(41),BINOP(MUL,CONST(3.273677544381256),TEMP(11))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(41),BINOP(ADD,TEMP(41),BINOP(MUL,CONST(0.22540970079591938),TEMP(11))))
# MOVE(TEMP(41),BINOP(ADD,TEMP(41),BINOP(MUL,CONST(1.2768413097250366),TEMP(11))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(42),BINOP(ADD,TEMP(42),BINOP(MUL,CONST(1.3088030225989913),TEMP(12))))
# MOVE(TEMP(42),BINOP(ADD,TEMP(42),BINOP(MUL,CONST(1.1596639549962326),TEMP(12))))
# MOVE(TEMP(42),BINOP(ADD,TEMP(42),BINOP(MUL,CONST(2.0279033856397217),TEMP(12))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(44),BINOP(ADD,TEMP(44),BINOP(MUL,CONST(0.7661267665327256),TEMP(14))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(46),BINOP(ADD,TEMP(46),BINOP(MUL,CONST(0.4444218779240374),TEMP(16))))
# MOVE(TEMP(46),BINOP(ADD,TEMP(46),BINOP(MUL,CONST(6.040601613768404),TEMP(16))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(46),BINOP(ADD,TEMP(46),BINOP(MUL,CONST(0.2414140812084998),TEMP(16))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(47),BINOP(ADD,TEMP(47),BINOP(MUL,CONST(0.1661024969153114),TEMP(17))))
# MOVE(TEMP(47),BINOP(ADD,TEMP(47),BINOP(MUL,CONST(2.983377652424146),TEMP(17))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(48),BINOP(ADD,TEMP(48),BINOP(MUL,CONST(3.768284800416982),TEMP(18))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(49),BINOP(ADD,TEMP(49),BINOP(MUL,CONST(0.011349679770919184),TEMP(19))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(49),BINOP(ADD,TEMP(49),BINOP(MUL,CONST(0.44157294614373394),TEMP(19))))
# MOVE(TEMP(49),BINOP(ADD,TEMP(49),BINOP(MUL,CONST(3.79356116122707),TEMP(19))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(50),BINOP(ADD,TEMP(50),BINOP(MUL,CONST(0.47299484684519577),TEMP(20))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(50),BINOP(ADD,TEMP(50),BINOP(MUL,CONST(2.0573344643939477),TEMP(20))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(51),BINOP(ADD,TEMP(51),BINOP(MUL,CONST(0.09337288455909085),TEMP(21))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(52),BINOP(ADD,TEMP(52),BINOP(MUL,CONST(0.027462334798580002),TEMP(22))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(53),BINOP(ADD,TEMP(53),BINOP(MUL,CONST(4.715529942936126),TEMP(23))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(54),BINOP(ADD,TEMP(54),BINOP(MUL,CONST(6.359563875844166),TEMP(24))))
# MOVE(TEMP(54),BINOP(ADD,TEMP(54),BINOP(MUL,CONST(0.6504048593654779),TEMP(24))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(54),BINOP(ADD,TEMP(54),BINOP(MUL,CONST(0.6294766014484531),TEMP(24))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(55),BINOP(ADD,TEMP(55),BINOP(MUL,CONST(3.9277941636832336),TEMP(25))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(56),BINOP(ADD,TEMP(56),BINOP(MUL,CONST(0.04117168704399902),TEMP(26))))
# MOVE(TEMP(56),BINOP(ADD,TEMP(56),BINOP(MUL,CONST(2.035378865926082),TEMP(26))))
# MOVE(TEMP(56),BINOP(ADD,TEMP(56),BINOP(MUL,CONST(0.006753507425000088),TEMP(26))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(57),BINOP(ADD,TEMP(57),BINOP(MUL,CONST(3.6390814150874964),TEMP(27))))
# MOVE(TEMP(58),BINOP(ADD,TEMP(58),BINOP(MUL,CONST(0.5722342086253039),TEMP(28))))
# MOVE(TEMP(58),BINOP(ADD,TEMP(58),BINOP(MUL,CONST(9.685720454095283e-05),TEMP(28))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(58),BINOP(ADD,TEMP(58),BINOP(MUL,CONST(0.11847156476754699),TEMP(28))))
# MOVE(TEMP(59),BINOP(ADD,TEMP(59),BINOP(MUL,CONST(0.019753832614655204),TEMP(29))))
# MOVE(TEMP(59),BINOP(ADD,TEMP(59),BINOP(MUL,CONST(0.2888329193137727),TEMP(29))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(59),BINOP(ADD,TEMP(59),BINOP(MUL,CONST(1.687952241476853),TEMP(29))))
# MOVE(TEMP(59),BINOP(ADD,TEMP(59),BINOP(MUL,CONST(0.1678899606689465),TEMP(29))))
# MOVE(TEMP(0),BINOP(ADD,TEMP(30),CONST(0.256015065242912)))
# MOVE(TEMP(1),BINOP(ADD,TEMP(31),CONST(1.3148059796969678)))
# MOVE(TEMP(2),BINOP(ADD,TEMP(32),CONST(-0.26218310609528506)))
# MOVE(TEMP(3),BINOP(ADD,TEMP(33),CONST(-1.327361282237728)))
# MOVE(TEMP(4),BINOP(ADD,TEMP(34),CONST(-0.15413652371915224)))
# MOVE(TEMP(5),BINOP(ADD,TEMP(35),CONST(-0.5722773609908199)))
# MOVE(TEMP(6),BINOP(ADD,TEMP(36),CONST(1.1783377622446451)))
# MOVE(TEMP(7),BINOP(ADD,TEMP(37),CONST(0.03592572706768913)))
# MOVE(TEMP(8),BINOP(ADD,TEMP(38),CONST(1.0896416178019146)))
# MOVE(TEMP(9),BINOP(ADD,TEMP(39),CONST(0.48761636320924323)))
# MOVE(TEMP(10),BINOP(ADD,TEMP(40),CONST(0.4232641626346925)))
# MOVE(TEMP(11),BINOP(ADD,TEMP(41),CONST(-0.12168303620933481)))
# MOVE(TEMP(12),BINOP(ADD,TEMP(42),CONST(0.14868416135063767)))
# MOVE(TEMP(13),BINOP(ADD,TEMP(43),CONST(0.7145642856055262)))
# MOVE(TEMP(14),BINOP(ADD,TEMP(44),CONST(1.0369107737285266)))
# MOVE(TEMP(15),BINOP(ADD,TEMP(45),CONST(1.5071753267210812)))
# MOVE(TEMP(16),BINOP(ADD,TEMP(46),CONST(-0.037782269173422756)))
# MOVE(TEMP(17),BINOP(ADD,TEMP(47),CONST(0.0016815795427016769)))
# MOVE(TEMP(18),BINOP(ADD,TEMP(48),CONST(0.33722210273081576)))
# MOVE(TEMP(19),BINOP(ADD,TEMP(49),CONST(-0.5846171783750328)))
# MOVE(TEMP(20),BINOP(ADD,TEMP(50),CONST(2.1772369401213756)))
# MOVE(TEMP(21),BINOP(ADD,TEMP(51),CONST(1.4457897817655283)))
# MOVE(TEMP(22),BINOP(ADD,TEMP(52),CONST(-0.46299058680311744)))
# MOVE(TEMP(23),BINOP(ADD,TEMP(53),CONST(-0.37708887718856365)))
# MOVE(TEMP(24),BINOP(ADD,TEMP(54),CONST(-0.6854379065144068)))
# MOVE(TEMP(25),BINOP(ADD,TEMP(55),CONST(1.431421840191442)))
# MOVE(TEMP(26),BINOP(ADD,TEMP(56),CONST(-0.3237049656798949)))
# MOVE(TEMP(27),BINOP(ADD,TEMP(57),CONST(-0.19548192677103526)))
# MOVE(TEMP(28),BINOP(ADD,TEMP(58),CONST(1.0133490773021885)))
# MOVE(TEMP(29),BINOP(ADD,TEMP(59),CONST(-0.010789898084328415)))
# MOVE(TEMP(0),CALL(RELU,TEMP(0)))
# MOVE(TEMP(1),CALL(RELU,TEMP(1)))
# MOVE(TEMP(2),CALL(RELU,TEMP(2)))
# MOVE(TEMP(3),CALL(RELU,TEMP(3)))
# MOVE(TEMP(4),CALL(RELU,TEMP(4)))
# MOVE(TEMP(5),CALL(RELU,TEMP(5)))
# MOVE(TEMP(6),CALL(RELU,TEMP(6)))
# MOVE(TEMP(7),CALL(RELU,TEMP(7)))
# MOVE(TEMP(8),CALL(RELU,TEMP(8)))
# MOVE(TEMP(9),CALL(RELU,TEMP(9)))
# MOVE(TEMP(10),CALL(RELU,TEMP(10)))
# MOVE(TEMP(11),CALL(RELU,TEMP(11)))
# MOVE(TEMP(12),CALL(RELU,TEMP(12)))
# MOVE(TEMP(13),CALL(RELU,TEMP(13)))
# MOVE(TEMP(14),CALL(RELU,TEMP(14)))
# MOVE(TEMP(15),CALL(RELU,TEMP(15)))
# MOVE(TEMP(16),CALL(RELU,TEMP(16)))
# MOVE(TEMP(17),CALL(RELU,TEMP(17)))
# MOVE(TEMP(18),CALL(RELU,TEMP(18)))
# MOVE(TEMP(19),CALL(RELU,TEMP(19)))
# MOVE(TEMP(20),CALL(RELU,TEMP(20)))
# MOVE(TEMP(21),CALL(RELU,TEMP(21)))
# MOVE(TEMP(22),CALL(RELU,TEMP(22)))
# MOVE(TEMP(23),CALL(RELU,TEMP(23)))
# MOVE(TEMP(24),CALL(RELU,TEMP(24)))
# MOVE(TEMP(25),CALL(RELU,TEMP(25)))
# MOVE(TEMP(26),CALL(RELU,TEMP(26)))
# MOVE(TEMP(27),CALL(RELU,TEMP(27)))
# MOVE(TEMP(28),CALL(RELU,TEMP(28)))
# MOVE(TEMP(29),CALL(RELU,TEMP(29)))
# COMMENT(END)
# COMMENT(START)
# MOVE(TEMP(30),CONST(0))
# MOVE(TEMP(31),CONST(0))
# MOVE(TEMP(32),CONST(0))
# MOVE(TEMP(33),CONST(0))
# MOVE(TEMP(34),CONST(0))
# MOVE(TEMP(35),CONST(0))
# MOVE(TEMP(36),CONST(0))
# MOVE(TEMP(37),CONST(0))
# MOVE(TEMP(38),CONST(0))
# MOVE(TEMP(39),CONST(0))
# MOVE(TEMP(40),CONST(0))
# MOVE(TEMP(41),CONST(0))
# MOVE(TEMP(42),CONST(0))
# MOVE(TEMP(43),CONST(0))
# MOVE(TEMP(44),CONST(0))
# MOVE(TEMP(45),CONST(0))
# MOVE(TEMP(46),CONST(0))
# MOVE(TEMP(47),CONST(0))
# MOVE(TEMP(48),CONST(0))
# MOVE(TEMP(49),CONST(0))
# MOVE(TEMP(50),CONST(0))
# MOVE(TEMP(51),CONST(0))
# MOVE(TEMP(52),CONST(0))
# MOVE(TEMP(53),CONST(0))
# MOVE(TEMP(54),CONST(0))
# MOVE(TEMP(55),CONST(0))
# MOVE(TEMP(56),CONST(0))
# MOVE(TEMP(57),CONST(0))
# MOVE(TEMP(58),CONST(0))
# MOVE(TEMP(59),CONST(0))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(30),BINOP(ADD,TEMP(30),BINOP(MUL,CONST(1.5238483824347029),TEMP(0))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(30),BINOP(ADD,TEMP(30),BINOP(MUL,CONST(0.6912885799988087),TEMP(0))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(30),BINOP(ADD,TEMP(30),BINOP(MUL,CONST(0.0017848343873239948),TEMP(0))))
# MOVE(TEMP(30),BINOP(ADD,TEMP(30),BINOP(MUL,CONST(1.1943641457329617),TEMP(0))))
# MOVE(TEMP(30),BINOP(ADD,TEMP(30),BINOP(MUL,CONST(2.4775211718056758),TEMP(0))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(30),BINOP(ADD,TEMP(30),BINOP(MUL,CONST(0.23494880921680103),TEMP(0))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(30),BINOP(ADD,TEMP(30),BINOP(MUL,CONST(1.275232299790275),TEMP(0))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(30),BINOP(ADD,TEMP(30),BINOP(MUL,CONST(3.4432456848029767),TEMP(0))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(30),BINOP(ADD,TEMP(30),BINOP(MUL,CONST(1.672786357562842),TEMP(0))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(30),BINOP(ADD,TEMP(30),BINOP(MUL,CONST(1.0720237258297116),TEMP(0))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(30),BINOP(ADD,TEMP(30),BINOP(MUL,CONST(0.04717842743463985),TEMP(0))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(30),BINOP(ADD,TEMP(30),BINOP(MUL,CONST(0.033324000380262765),TEMP(0))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(30),BINOP(ADD,TEMP(30),BINOP(MUL,CONST(0.13756273839234742),TEMP(0))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(31),BINOP(ADD,TEMP(31),BINOP(MUL,CONST(3.6339838918853737),TEMP(1))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(31),BINOP(ADD,TEMP(31),BINOP(MUL,CONST(1.4299883951562706),TEMP(1))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(31),BINOP(ADD,TEMP(31),BINOP(MUL,CONST(0.6028364320918426),TEMP(1))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(31),BINOP(ADD,TEMP(31),BINOP(MUL,CONST(0.8751593695001032),TEMP(1))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(31),BINOP(ADD,TEMP(31),BINOP(MUL,CONST(0.0071833613321629925),TEMP(1))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(31),BINOP(ADD,TEMP(31),BINOP(MUL,CONST(0.17815446387784653),TEMP(1))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(31),BINOP(ADD,TEMP(31),BINOP(MUL,CONST(0.13265628110294894),TEMP(1))))
# MOVE(TEMP(31),BINOP(ADD,TEMP(31),BINOP(MUL,CONST(0.8049836030529843),TEMP(1))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(31),BINOP(ADD,TEMP(31),BINOP(MUL,CONST(3.03801677984328),TEMP(1))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(31),BINOP(ADD,TEMP(31),BINOP(MUL,CONST(1.3425109029792077),TEMP(1))))
# MOVE(TEMP(31),BINOP(ADD,TEMP(31),BINOP(MUL,CONST(0.003935875219048582),TEMP(1))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(32),BINOP(ADD,TEMP(32),BINOP(MUL,CONST(2.2766919797770595),TEMP(2))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(32),BINOP(ADD,TEMP(32),BINOP(MUL,CONST(2.9557303255635237),TEMP(2))))
# MOVE(TEMP(32),BINOP(ADD,TEMP(32),BINOP(MUL,CONST(0.4005674491843482),TEMP(2))))
# MOVE(TEMP(32),BINOP(ADD,TEMP(32),BINOP(MUL,CONST(2.3687040338223624),TEMP(2))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(32),BINOP(ADD,TEMP(32),BINOP(MUL,CONST(4.846569777078572),TEMP(2))))
# MOVE(TEMP(32),BINOP(ADD,TEMP(32),BINOP(MUL,CONST(0.8533933594154027),TEMP(2))))
# MOVE(TEMP(32),BINOP(ADD,TEMP(32),BINOP(MUL,CONST(2.649008419476967),TEMP(2))))
# MOVE(TEMP(32),BINOP(ADD,TEMP(32),BINOP(MUL,CONST(0.6043433577568047),TEMP(2))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(32),BINOP(ADD,TEMP(32),BINOP(MUL,CONST(1.86618823507435),TEMP(2))))
# MOVE(TEMP(32),BINOP(ADD,TEMP(32),BINOP(MUL,CONST(0.02960259063687538),TEMP(2))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(32),BINOP(ADD,TEMP(32),BINOP(MUL,CONST(0.7974296097901056),TEMP(2))))
# MOVE(TEMP(32),BINOP(ADD,TEMP(32),BINOP(MUL,CONST(6.128886874645462),TEMP(2))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(32),BINOP(ADD,TEMP(32),BINOP(MUL,CONST(1.9364480305434126),TEMP(2))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(32),BINOP(ADD,TEMP(32),BINOP(MUL,CONST(0.17287328952427058),TEMP(2))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(33),BINOP(ADD,TEMP(33),BINOP(MUL,CONST(0.5436588949361997),TEMP(3))))
# MOVE(TEMP(33),BINOP(ADD,TEMP(33),BINOP(MUL,CONST(3.697965365491287),TEMP(3))))
# MOVE(TEMP(33),BINOP(ADD,TEMP(33),BINOP(MUL,CONST(0.0011136697317699197),TEMP(3))))
# MOVE(TEMP(33),BINOP(ADD,TEMP(33),BINOP(MUL,CONST(0.7195563228004825),TEMP(3))))
# MOVE(TEMP(33),BINOP(ADD,TEMP(33),BINOP(MUL,CONST(2.2889923418534686),TEMP(3))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(33),BINOP(ADD,TEMP(33),BINOP(MUL,CONST(7.763324912192742),TEMP(3))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(33),BINOP(ADD,TEMP(33),BINOP(MUL,CONST(0.07399883149684043),TEMP(3))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(33),BINOP(ADD,TEMP(33),BINOP(MUL,CONST(0.43375202375232946),TEMP(3))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(33),BINOP(ADD,TEMP(33),BINOP(MUL,CONST(0.18273739326947508),TEMP(3))))
# MOVE(TEMP(33),BINOP(ADD,TEMP(33),BINOP(MUL,CONST(0.036831032019072785),TEMP(3))))
# MOVE(TEMP(33),BINOP(ADD,TEMP(33),BINOP(MUL,CONST(0.12337171843003536),TEMP(3))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(34),BINOP(ADD,TEMP(34),BINOP(MUL,CONST(0.11713533573327932),TEMP(4))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(34),BINOP(ADD,TEMP(34),BINOP(MUL,CONST(0.00035663326904786843),TEMP(4))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(34),BINOP(ADD,TEMP(34),BINOP(MUL,CONST(2.5514698558078903),TEMP(4))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(34),BINOP(ADD,TEMP(34),BINOP(MUL,CONST(0.005408117572836152),TEMP(4))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(34),BINOP(ADD,TEMP(34),BINOP(MUL,CONST(0.23556823461066664),TEMP(4))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(34),BINOP(ADD,TEMP(34),BINOP(MUL,CONST(1.2278006366726504),TEMP(4))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(34),BINOP(ADD,TEMP(34),BINOP(MUL,CONST(0.2878506080422076),TEMP(4))))
# MOVE(TEMP(34),BINOP(ADD,TEMP(34),BINOP(MUL,CONST(0.14864028822215203),TEMP(4))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(34),BINOP(ADD,TEMP(34),BINOP(MUL,CONST(0.0012656947817195644),TEMP(4))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(34),BINOP(ADD,TEMP(34),BINOP(MUL,CONST(4.301058704952072e-06),TEMP(4))))
# MOVE(TEMP(34),BINOP(ADD,TEMP(34),BINOP(MUL,CONST(0.9017348124857059),TEMP(4))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(35),BINOP(ADD,TEMP(35),BINOP(MUL,CONST(1.0925397544214064),TEMP(5))))
# MOVE(TEMP(35),BINOP(ADD,TEMP(35),BINOP(MUL,CONST(0.18830119829451986),TEMP(5))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(35),BINOP(ADD,TEMP(35),BINOP(MUL,CONST(0.08957084234698089),TEMP(5))))
# MOVE(TEMP(35),BINOP(ADD,TEMP(35),BINOP(MUL,CONST(1.0466689331063883),TEMP(5))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(35),BINOP(ADD,TEMP(35),BINOP(MUL,CONST(0.4791369883599495),TEMP(5))))
# MOVE(TEMP(35),BINOP(ADD,TEMP(35),BINOP(MUL,CONST(0.041024757050386565),TEMP(5))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(35),BINOP(ADD,TEMP(35),BINOP(MUL,CONST(0.05406963284463308),TEMP(5))))
# MOVE(TEMP(35),BINOP(ADD,TEMP(35),BINOP(MUL,CONST(0.12371283576532402),TEMP(5))))
# MOVE(TEMP(35),BINOP(ADD,TEMP(35),BINOP(MUL,CONST(1.6224179910056649),TEMP(5))))
# MOVE(TEMP(35),BINOP(ADD,TEMP(35),BINOP(MUL,CONST(0.16078613582056855),TEMP(5))))
# MOVE(TEMP(35),BINOP(ADD,TEMP(35),BINOP(MUL,CONST(0.4845589343910473),TEMP(5))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(35),BINOP(ADD,TEMP(35),BINOP(MUL,CONST(0.6427098099810183),TEMP(5))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(35),BINOP(ADD,TEMP(35),BINOP(MUL,CONST(0.46021145239454014),TEMP(5))))
# MOVE(TEMP(35),BINOP(ADD,TEMP(35),BINOP(MUL,CONST(0.8068943283575934),TEMP(5))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(36),BINOP(ADD,TEMP(36),BINOP(MUL,CONST(0.4865391426371376),TEMP(6))))
# MOVE(TEMP(36),BINOP(ADD,TEMP(36),BINOP(MUL,CONST(0.1694575892527415),TEMP(6))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(36),BINOP(ADD,TEMP(36),BINOP(MUL,CONST(3.5265052378248436),TEMP(6))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(36),BINOP(ADD,TEMP(36),BINOP(MUL,CONST(0.07180847916494228),TEMP(6))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(36),BINOP(ADD,TEMP(36),BINOP(MUL,CONST(0.016513487225270015),TEMP(6))))
# MOVE(TEMP(36),BINOP(ADD,TEMP(36),BINOP(MUL,CONST(0.3716219182413311),TEMP(6))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(36),BINOP(ADD,TEMP(36),BINOP(MUL,CONST(1.0522096903268874),TEMP(6))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(36),BINOP(ADD,TEMP(36),BINOP(MUL,CONST(0.17306447002559244),TEMP(6))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(37),BINOP(ADD,TEMP(37),BINOP(MUL,CONST(1.0957602540571028),TEMP(7))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(37),BINOP(ADD,TEMP(37),BINOP(MUL,CONST(1.0350152529860912),TEMP(7))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(37),BINOP(ADD,TEMP(37),BINOP(MUL,CONST(0.253130066735409),TEMP(7))))
# MOVE(TEMP(37),BINOP(ADD,TEMP(37),BINOP(MUL,CONST(0.2178418764640029),TEMP(7))))
# MOVE(TEMP(37),BINOP(ADD,TEMP(37),BINOP(MUL,CONST(4.663791798232878),TEMP(7))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(37),BINOP(ADD,TEMP(37),BINOP(MUL,CONST(1.8536851984807052),TEMP(7))))
# MOVE(TEMP(37),BINOP(ADD,TEMP(37),BINOP(MUL,CONST(0.05241139459873118),TEMP(7))))
# MOVE(TEMP(37),BINOP(ADD,TEMP(37),BINOP(MUL,CONST(1.7069079833776089),TEMP(7))))
# MOVE(TEMP(37),BINOP(ADD,TEMP(37),BINOP(MUL,CONST(3.0158215007355555),TEMP(7))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(37),BINOP(ADD,TEMP(37),BINOP(MUL,CONST(0.27503976866547414),TEMP(7))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(38),BINOP(ADD,TEMP(38),BINOP(MUL,CONST(2.6511398792325274),TEMP(8))))
# MOVE(TEMP(38),BINOP(ADD,TEMP(38),BINOP(MUL,CONST(0.3462068996138571),TEMP(8))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(38),BINOP(ADD,TEMP(38),BINOP(MUL,CONST(0.09732765527838509),TEMP(8))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(38),BINOP(ADD,TEMP(38),BINOP(MUL,CONST(0.0217952566060742),TEMP(8))))
# MOVE(TEMP(38),BINOP(ADD,TEMP(38),BINOP(MUL,CONST(0.12776702784036673),TEMP(8))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(38),BINOP(ADD,TEMP(38),BINOP(MUL,CONST(0.007516068413558887),TEMP(8))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(38),BINOP(ADD,TEMP(38),BINOP(MUL,CONST(0.051922997452844455),TEMP(8))))
# MOVE(TEMP(38),BINOP(ADD,TEMP(38),BINOP(MUL,CONST(1.2264795039227079),TEMP(8))))
# MOVE(TEMP(38),BINOP(ADD,TEMP(38),BINOP(MUL,CONST(0.00010617498529047299),TEMP(8))))
# MOVE(TEMP(38),BINOP(ADD,TEMP(38),BINOP(MUL,CONST(0.026260394329509266),TEMP(8))))
# MOVE(TEMP(38),BINOP(ADD,TEMP(38),BINOP(MUL,CONST(0.11903059602930319),TEMP(8))))
# MOVE(TEMP(38),BINOP(ADD,TEMP(38),BINOP(MUL,CONST(0.4718743520962221),TEMP(8))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(38),BINOP(ADD,TEMP(38),BINOP(MUL,CONST(1.941728736596005),TEMP(8))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(39),BINOP(ADD,TEMP(39),BINOP(MUL,CONST(2.6102310875577603),TEMP(9))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(39),BINOP(ADD,TEMP(39),BINOP(MUL,CONST(0.025295122519442277),TEMP(9))))
# MOVE(TEMP(39),BINOP(ADD,TEMP(39),BINOP(MUL,CONST(0.06277835471321952),TEMP(9))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(39),BINOP(ADD,TEMP(39),BINOP(MUL,CONST(0.1965090035866463),TEMP(9))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(39),BINOP(ADD,TEMP(39),BINOP(MUL,CONST(0.18833225427354777),TEMP(9))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(39),BINOP(ADD,TEMP(39),BINOP(MUL,CONST(1.9211545349040737),TEMP(9))))
# MOVE(TEMP(39),BINOP(ADD,TEMP(39),BINOP(MUL,CONST(0.11524364099802777),TEMP(9))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(39),BINOP(ADD,TEMP(39),BINOP(MUL,CONST(0.015753090010723562),TEMP(9))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(39),BINOP(ADD,TEMP(39),BINOP(MUL,CONST(1.383123519759653),TEMP(9))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(40),BINOP(ADD,TEMP(40),BINOP(MUL,CONST(0.10669848442205551),TEMP(10))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(40),BINOP(ADD,TEMP(40),BINOP(MUL,CONST(2.298834416667263),TEMP(10))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(40),BINOP(ADD,TEMP(40),BINOP(MUL,CONST(1.1681624701015454),TEMP(10))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(40),BINOP(ADD,TEMP(40),BINOP(MUL,CONST(0.3874485150974531),TEMP(10))))
# MOVE(TEMP(40),BINOP(ADD,TEMP(40),BINOP(MUL,CONST(1.269607376144054),TEMP(10))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(40),BINOP(ADD,TEMP(40),BINOP(MUL,CONST(0.5004555929254229),TEMP(10))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(40),BINOP(ADD,TEMP(40),BINOP(MUL,CONST(0.5766376560626268),TEMP(10))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(40),BINOP(ADD,TEMP(40),BINOP(MUL,CONST(3.244003697242405),TEMP(10))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(41),BINOP(ADD,TEMP(41),BINOP(MUL,CONST(0.18135089917139288),TEMP(11))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(41),BINOP(ADD,TEMP(41),BINOP(MUL,CONST(0.0006010745126146721),TEMP(11))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(41),BINOP(ADD,TEMP(41),BINOP(MUL,CONST(4.161523094563706),TEMP(11))))
# MOVE(TEMP(41),BINOP(ADD,TEMP(41),BINOP(MUL,CONST(3.6056890434143765),TEMP(11))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(41),BINOP(ADD,TEMP(41),BINOP(MUL,CONST(0.5438830831403637),TEMP(11))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(41),BINOP(ADD,TEMP(41),BINOP(MUL,CONST(4.00471759092987),TEMP(11))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(41),BINOP(ADD,TEMP(41),BINOP(MUL,CONST(0.35418997775167366),TEMP(11))))
# MOVE(TEMP(41),BINOP(ADD,TEMP(41),BINOP(MUL,CONST(1.5286842344247427),TEMP(11))))
# MOVE(TEMP(41),BINOP(ADD,TEMP(41),BINOP(MUL,CONST(0.2295453488352319),TEMP(11))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(41),BINOP(ADD,TEMP(41),BINOP(MUL,CONST(0.924559529782303),TEMP(11))))
# MOVE(TEMP(41),BINOP(ADD,TEMP(41),BINOP(MUL,CONST(1.8095905314788334),TEMP(11))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(42),BINOP(ADD,TEMP(42),BINOP(MUL,CONST(0.28102857508796897),TEMP(12))))
# MOVE(TEMP(42),BINOP(ADD,TEMP(42),BINOP(MUL,CONST(0.5945594081080122),TEMP(12))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(42),BINOP(ADD,TEMP(42),BINOP(MUL,CONST(0.4721248537080425),TEMP(12))))
# MOVE(TEMP(42),BINOP(ADD,TEMP(42),BINOP(MUL,CONST(0.3641177366672625),TEMP(12))))
# MOVE(TEMP(42),BINOP(ADD,TEMP(42),BINOP(MUL,CONST(0.13476810747440351),TEMP(12))))
# MOVE(TEMP(42),BINOP(ADD,TEMP(42),BINOP(MUL,CONST(0.885691792015051),TEMP(12))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(42),BINOP(ADD,TEMP(42),BINOP(MUL,CONST(0.3592303285385735),TEMP(12))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(42),BINOP(ADD,TEMP(42),BINOP(MUL,CONST(1.8197678023701314),TEMP(12))))
# MOVE(TEMP(42),BINOP(ADD,TEMP(42),BINOP(MUL,CONST(0.399314022707789),TEMP(12))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(42),BINOP(ADD,TEMP(42),BINOP(MUL,CONST(0.7346493672225339),TEMP(12))))
# MOVE(TEMP(42),BINOP(ADD,TEMP(42),BINOP(MUL,CONST(2.166911343209093),TEMP(12))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(42),BINOP(ADD,TEMP(42),BINOP(MUL,CONST(0.9079086008642219),TEMP(12))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(42),BINOP(ADD,TEMP(42),BINOP(MUL,CONST(0.40026244222489393),TEMP(12))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(42),BINOP(ADD,TEMP(42),BINOP(MUL,CONST(0.1474775032711053),TEMP(12))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(42),BINOP(ADD,TEMP(42),BINOP(MUL,CONST(0.10419041235404838),TEMP(12))))
# MOVE(TEMP(42),BINOP(ADD,TEMP(42),BINOP(MUL,CONST(0.6384762224413362),TEMP(12))))
# MOVE(TEMP(43),BINOP(ADD,TEMP(43),BINOP(MUL,CONST(0.12114271770371805),TEMP(13))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(43),BINOP(ADD,TEMP(43),BINOP(MUL,CONST(0.7253289458565041),TEMP(13))))
# MOVE(TEMP(43),BINOP(ADD,TEMP(43),BINOP(MUL,CONST(0.30618924103858),TEMP(13))))
# MOVE(TEMP(43),BINOP(ADD,TEMP(43),BINOP(MUL,CONST(0.10775008216454098),TEMP(13))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(43),BINOP(ADD,TEMP(43),BINOP(MUL,CONST(0.5483761964815571),TEMP(13))))
# MOVE(TEMP(43),BINOP(ADD,TEMP(43),BINOP(MUL,CONST(0.5220189484990637),TEMP(13))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(43),BINOP(ADD,TEMP(43),BINOP(MUL,CONST(2.3668724230691636),TEMP(13))))
# MOVE(TEMP(43),BINOP(ADD,TEMP(43),BINOP(MUL,CONST(0.04098809956396585),TEMP(13))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(43),BINOP(ADD,TEMP(43),BINOP(MUL,CONST(0.6645077978330417),TEMP(13))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(43),BINOP(ADD,TEMP(43),BINOP(MUL,CONST(0.08204142444751387),TEMP(13))))
# MOVE(TEMP(43),BINOP(ADD,TEMP(43),BINOP(MUL,CONST(0.04986576600491076),TEMP(13))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(43),BINOP(ADD,TEMP(43),BINOP(MUL,CONST(2.7031279741054233),TEMP(13))))
# MOVE(TEMP(43),BINOP(ADD,TEMP(43),BINOP(MUL,CONST(0.08741417225584522),TEMP(13))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(43),BINOP(ADD,TEMP(43),BINOP(MUL,CONST(0.48699125024732076),TEMP(13))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(43),BINOP(ADD,TEMP(43),BINOP(MUL,CONST(0.09110459839221877),TEMP(13))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(44),BINOP(ADD,TEMP(44),BINOP(MUL,CONST(0.4733702646423768),TEMP(14))))
# MOVE(TEMP(44),BINOP(ADD,TEMP(44),BINOP(MUL,CONST(5.138949348805607),TEMP(14))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(44),BINOP(ADD,TEMP(44),BINOP(MUL,CONST(0.08766860851893941),TEMP(14))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(44),BINOP(ADD,TEMP(44),BINOP(MUL,CONST(3.453286417464723),TEMP(14))))
# MOVE(TEMP(44),BINOP(ADD,TEMP(44),BINOP(MUL,CONST(0.28738130502711307),TEMP(14))))
# MOVE(TEMP(44),BINOP(ADD,TEMP(44),BINOP(MUL,CONST(0.284686443055201),TEMP(14))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(44),BINOP(ADD,TEMP(44),BINOP(MUL,CONST(0.10743212768817895),TEMP(14))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(44),BINOP(ADD,TEMP(44),BINOP(MUL,CONST(0.4141915018330138),TEMP(14))))
# MOVE(TEMP(44),BINOP(ADD,TEMP(44),BINOP(MUL,CONST(0.2558369268110459),TEMP(14))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(44),BINOP(ADD,TEMP(44),BINOP(MUL,CONST(2.084075342236782),TEMP(14))))
# MOVE(TEMP(44),BINOP(ADD,TEMP(44),BINOP(MUL,CONST(0.9398919154775625),TEMP(14))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(44),BINOP(ADD,TEMP(44),BINOP(MUL,CONST(0.015792731360260735),TEMP(14))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(45),BINOP(ADD,TEMP(45),BINOP(MUL,CONST(1.3928762174440843),TEMP(15))))
# MOVE(TEMP(45),BINOP(ADD,TEMP(45),BINOP(MUL,CONST(0.010746428700747395),TEMP(15))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(45),BINOP(ADD,TEMP(45),BINOP(MUL,CONST(0.04519689923928841),TEMP(15))))
# MOVE(TEMP(45),BINOP(ADD,TEMP(45),BINOP(MUL,CONST(0.7756691198967823),TEMP(15))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(45),BINOP(ADD,TEMP(45),BINOP(MUL,CONST(0.06963604125225054),TEMP(15))))
# MOVE(TEMP(45),BINOP(ADD,TEMP(45),BINOP(MUL,CONST(0.9119465061921505),TEMP(15))))
# MOVE(TEMP(45),BINOP(ADD,TEMP(45),BINOP(MUL,CONST(2.4401955826098916),TEMP(15))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(45),BINOP(ADD,TEMP(45),BINOP(MUL,CONST(0.008822757425878179),TEMP(15))))
# MOVE(TEMP(45),BINOP(ADD,TEMP(45),BINOP(MUL,CONST(2.555159338298247),TEMP(15))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(45),BINOP(ADD,TEMP(45),BINOP(MUL,CONST(0.09617187986304716),TEMP(15))))
# MOVE(TEMP(45),BINOP(ADD,TEMP(45),BINOP(MUL,CONST(0.026397011188029555),TEMP(15))))
# MOVE(TEMP(45),BINOP(ADD,TEMP(45),BINOP(MUL,CONST(0.2637125341028934),TEMP(15))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(46),BINOP(ADD,TEMP(46),BINOP(MUL,CONST(0.010592952316811883),TEMP(16))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(46),BINOP(ADD,TEMP(46),BINOP(MUL,CONST(0.9615958711488622),TEMP(16))))
# MOVE(TEMP(46),BINOP(ADD,TEMP(46),BINOP(MUL,CONST(0.33322250616127136),TEMP(16))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(46),BINOP(ADD,TEMP(46),BINOP(MUL,CONST(0.7473731980578849),TEMP(16))))
# MOVE(TEMP(46),BINOP(ADD,TEMP(46),BINOP(MUL,CONST(0.8188682173004166),TEMP(16))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(46),BINOP(ADD,TEMP(46),BINOP(MUL,CONST(0.27589231794458857),TEMP(16))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(46),BINOP(ADD,TEMP(46),BINOP(MUL,CONST(0.0001431055781611255),TEMP(16))))
# MOVE(TEMP(46),BINOP(ADD,TEMP(46),BINOP(MUL,CONST(0.0015086388510672153),TEMP(16))))
# MOVE(TEMP(46),BINOP(ADD,TEMP(46),BINOP(MUL,CONST(1.9321139275502655),TEMP(16))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(47),BINOP(ADD,TEMP(47),BINOP(MUL,CONST(0.8759868078151727),TEMP(17))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(47),BINOP(ADD,TEMP(47),BINOP(MUL,CONST(1.3408525169306702),TEMP(17))))
# MOVE(TEMP(47),BINOP(ADD,TEMP(47),BINOP(MUL,CONST(0.206438931204322),TEMP(17))))
# MOVE(TEMP(47),BINOP(ADD,TEMP(47),BINOP(MUL,CONST(0.1421334418361794),TEMP(17))))
# MOVE(TEMP(47),BINOP(ADD,TEMP(47),BINOP(MUL,CONST(0.6963949043856149),TEMP(17))))
# MOVE(TEMP(47),BINOP(ADD,TEMP(47),BINOP(MUL,CONST(3.9219542394668006),TEMP(17))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(47),BINOP(ADD,TEMP(47),BINOP(MUL,CONST(0.29216421184036634),TEMP(17))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(47),BINOP(ADD,TEMP(47),BINOP(MUL,CONST(0.19201690070723704),TEMP(17))))
# MOVE(TEMP(47),BINOP(ADD,TEMP(47),BINOP(MUL,CONST(0.24418370159947672),TEMP(17))))
# MOVE(TEMP(47),BINOP(ADD,TEMP(47),BINOP(MUL,CONST(2.4622875564210145),TEMP(17))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(47),BINOP(ADD,TEMP(47),BINOP(MUL,CONST(0.48997007208814214),TEMP(17))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(47),BINOP(ADD,TEMP(47),BINOP(MUL,CONST(2.560944244228005),TEMP(17))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(47),BINOP(ADD,TEMP(47),BINOP(MUL,CONST(1.5603730026681202),TEMP(17))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(48),BINOP(ADD,TEMP(48),BINOP(MUL,CONST(0.3996008379249278),TEMP(18))))
# MOVE(TEMP(48),BINOP(ADD,TEMP(48),BINOP(MUL,CONST(0.003568208302666102),TEMP(18))))
# MOVE(TEMP(48),BINOP(ADD,TEMP(48),BINOP(MUL,CONST(0.7833593593684299),TEMP(18))))
# MOVE(TEMP(48),BINOP(ADD,TEMP(48),BINOP(MUL,CONST(0.0005262344940382156),TEMP(18))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(48),BINOP(ADD,TEMP(48),BINOP(MUL,CONST(1.4347097399809774),TEMP(18))))
# MOVE(TEMP(48),BINOP(ADD,TEMP(48),BINOP(MUL,CONST(0.03332976595281671),TEMP(18))))
# MOVE(TEMP(48),BINOP(ADD,TEMP(48),BINOP(MUL,CONST(0.00421560973896488),TEMP(18))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(48),BINOP(ADD,TEMP(48),BINOP(MUL,CONST(0.7461320942808205),TEMP(18))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(48),BINOP(ADD,TEMP(48),BINOP(MUL,CONST(12.688020766990025),TEMP(18))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(48),BINOP(ADD,TEMP(48),BINOP(MUL,CONST(0.20124776034807165),TEMP(18))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(49),BINOP(ADD,TEMP(49),BINOP(MUL,CONST(1.0278197714922046),TEMP(19))))
# MOVE(TEMP(49),BINOP(ADD,TEMP(49),BINOP(MUL,CONST(0.3032723882602922),TEMP(19))))
# MOVE(TEMP(49),BINOP(ADD,TEMP(49),BINOP(MUL,CONST(2.422950369017189),TEMP(19))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(49),BINOP(ADD,TEMP(49),BINOP(MUL,CONST(0.20705953495475707),TEMP(19))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(49),BINOP(ADD,TEMP(49),BINOP(MUL,CONST(0.12241764889643893),TEMP(19))))
# MOVE(TEMP(49),BINOP(ADD,TEMP(49),BINOP(MUL,CONST(0.0031458793850363334),TEMP(19))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(49),BINOP(ADD,TEMP(49),BINOP(MUL,CONST(0.008926401326891589),TEMP(19))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(49),BINOP(ADD,TEMP(49),BINOP(MUL,CONST(2.6303926449726966),TEMP(19))))
# # here there was a 0 so we exploit sparsity
# ...
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(53),BINOP(ADD,TEMP(53),BINOP(MUL,CONST(3.0856005501729933),TEMP(23))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(53),BINOP(ADD,TEMP(53),BINOP(MUL,CONST(0.015437651406280487),TEMP(23))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(53),BINOP(ADD,TEMP(53),BINOP(MUL,CONST(1.070233919187626),TEMP(23))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(53),BINOP(ADD,TEMP(53),BINOP(MUL,CONST(0.5561935035916908),TEMP(23))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(53),BINOP(ADD,TEMP(53),BINOP(MUL,CONST(0.3354235434744379),TEMP(23))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(54),BINOP(ADD,TEMP(54),BINOP(MUL,CONST(0.13772707927233632),TEMP(24))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(54),BINOP(ADD,TEMP(54),BINOP(MUL,CONST(7.631310456476276),TEMP(24))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(54),BINOP(ADD,TEMP(54),BINOP(MUL,CONST(0.006615717952671718),TEMP(24))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(54),BINOP(ADD,TEMP(54),BINOP(MUL,CONST(0.32473400155038035),TEMP(24))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(54),BINOP(ADD,TEMP(54),BINOP(MUL,CONST(0.03334768079806366),TEMP(24))))
# MOVE(TEMP(54),BINOP(ADD,TEMP(54),BINOP(MUL,CONST(1.0234434554433647),TEMP(24))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(54),BINOP(ADD,TEMP(54),BINOP(MUL,CONST(0.0009860375520312813),TEMP(24))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(54),BINOP(ADD,TEMP(54),BINOP(MUL,CONST(2.4638589330595857),TEMP(24))))
# MOVE(TEMP(54),BINOP(ADD,TEMP(54),BINOP(MUL,CONST(0.05546417229369405),TEMP(24))))
# MOVE(TEMP(54),BINOP(ADD,TEMP(54),BINOP(MUL,CONST(0.003974987232781203),TEMP(24))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(54),BINOP(ADD,TEMP(54),BINOP(MUL,CONST(1.5432737389143827),TEMP(24))))
# MOVE(TEMP(54),BINOP(ADD,TEMP(54),BINOP(MUL,CONST(0.5950618631571469),TEMP(24))))
# MOVE(TEMP(54),BINOP(ADD,TEMP(54),BINOP(MUL,CONST(0.01515491351231838),TEMP(24))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(55),BINOP(ADD,TEMP(55),BINOP(MUL,CONST(0.8685170966521274),TEMP(25))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(55),BINOP(ADD,TEMP(55),BINOP(MUL,CONST(5.293471519568206),TEMP(25))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(55),BINOP(ADD,TEMP(55),BINOP(MUL,CONST(1.800046441217139),TEMP(25))))
# MOVE(TEMP(55),BINOP(ADD,TEMP(55),BINOP(MUL,CONST(0.15389134925199374),TEMP(25))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(55),BINOP(ADD,TEMP(55),BINOP(MUL,CONST(0.24334597494200594),TEMP(25))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(55),BINOP(ADD,TEMP(55),BINOP(MUL,CONST(0.1917379476996834),TEMP(25))))
# MOVE(TEMP(55),BINOP(ADD,TEMP(55),BINOP(MUL,CONST(0.9567224234068668),TEMP(25))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(55),BINOP(ADD,TEMP(55),BINOP(MUL,CONST(1.5839586622233401),TEMP(25))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(55),BINOP(ADD,TEMP(55),BINOP(MUL,CONST(0.38460430833898945),TEMP(25))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(56),BINOP(ADD,TEMP(56),BINOP(MUL,CONST(0.7154031123946059),TEMP(26))))
# MOVE(TEMP(56),BINOP(ADD,TEMP(56),BINOP(MUL,CONST(0.057666927163881436),TEMP(26))))
# MOVE(TEMP(56),BINOP(ADD,TEMP(56),BINOP(MUL,CONST(0.9033271004248122),TEMP(26))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(56),BINOP(ADD,TEMP(56),BINOP(MUL,CONST(1.1498583315861364),TEMP(26))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(56),BINOP(ADD,TEMP(56),BINOP(MUL,CONST(0.01598830103233673),TEMP(26))))
# MOVE(TEMP(56),BINOP(ADD,TEMP(56),BINOP(MUL,CONST(0.008095249273784726),TEMP(26))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(56),BINOP(ADD,TEMP(56),BINOP(MUL,CONST(0.00146143621531381),TEMP(26))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(56),BINOP(ADD,TEMP(56),BINOP(MUL,CONST(0.14687620568394952),TEMP(26))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(56),BINOP(ADD,TEMP(56),BINOP(MUL,CONST(0.616179672046756),TEMP(26))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(56),BINOP(ADD,TEMP(56),BINOP(MUL,CONST(3.066969396882072),TEMP(26))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(57),BINOP(ADD,TEMP(57),BINOP(MUL,CONST(1.2922232225299188),TEMP(27))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(57),BINOP(ADD,TEMP(57),BINOP(MUL,CONST(0.6150168699565279),TEMP(27))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(57),BINOP(ADD,TEMP(57),BINOP(MUL,CONST(0.03359927129710688),TEMP(27))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(57),BINOP(ADD,TEMP(57),BINOP(MUL,CONST(0.048824974204334536),TEMP(27))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(57),BINOP(ADD,TEMP(57),BINOP(MUL,CONST(0.9443402653123848),TEMP(27))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(58),BINOP(ADD,TEMP(58),BINOP(MUL,CONST(0.004378310245304139),TEMP(28))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(58),BINOP(ADD,TEMP(58),BINOP(MUL,CONST(2.2712091981128335),TEMP(28))))
# MOVE(TEMP(58),BINOP(ADD,TEMP(58),BINOP(MUL,CONST(0.82474847727024),TEMP(28))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(58),BINOP(ADD,TEMP(58),BINOP(MUL,CONST(0.3848241105493552),TEMP(28))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(58),BINOP(ADD,TEMP(58),BINOP(MUL,CONST(0.035893040818786824),TEMP(28))))
# MOVE(TEMP(58),BINOP(ADD,TEMP(58),BINOP(MUL,CONST(0.3490406837389326),TEMP(28))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(58),BINOP(ADD,TEMP(58),BINOP(MUL,CONST(4.959296940278981),TEMP(28))))
# MOVE(TEMP(58),BINOP(ADD,TEMP(58),BINOP(MUL,CONST(0.0027797431796188357),TEMP(28))))
# MOVE(TEMP(58),BINOP(ADD,TEMP(58),BINOP(MUL,CONST(0.19569390756339874),TEMP(28))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(58),BINOP(ADD,TEMP(58),BINOP(MUL,CONST(1.3723803561146881),TEMP(28))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(58),BINOP(ADD,TEMP(58),BINOP(MUL,CONST(0.15636141204573342),TEMP(28))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(59),BINOP(ADD,TEMP(59),BINOP(MUL,CONST(0.9772562790249077),TEMP(29))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(59),BINOP(ADD,TEMP(59),BINOP(MUL,CONST(0.9315392720872734),TEMP(29))))
# MOVE(TEMP(59),BINOP(ADD,TEMP(59),BINOP(MUL,CONST(0.12245576759440362),TEMP(29))))
# MOVE(TEMP(59),BINOP(ADD,TEMP(59),BINOP(MUL,CONST(0.005464169342248103),TEMP(29))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(59),BINOP(ADD,TEMP(59),BINOP(MUL,CONST(0.36077286165699657),TEMP(29))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(59),BINOP(ADD,TEMP(59),BINOP(MUL,CONST(0.5447903455131898),TEMP(29))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(59),BINOP(ADD,TEMP(59),BINOP(MUL,CONST(0.5962418331390021),TEMP(29))))
# MOVE(TEMP(59),BINOP(ADD,TEMP(59),BINOP(MUL,CONST(0.6018120972235544),TEMP(29))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(59),BINOP(ADD,TEMP(59),BINOP(MUL,CONST(0.0032878361428487876),TEMP(29))))
# MOVE(TEMP(59),BINOP(ADD,TEMP(59),BINOP(MUL,CONST(0.026047845207742393),TEMP(29))))
# MOVE(TEMP(59),BINOP(ADD,TEMP(59),BINOP(MUL,CONST(0.27328925160952505),TEMP(29))))
# MOVE(TEMP(0),BINOP(ADD,TEMP(30),CONST(-1.0095708414261975)))
# MOVE(TEMP(1),BINOP(ADD,TEMP(31),CONST(0.49506171928085)))
# MOVE(TEMP(2),BINOP(ADD,TEMP(32),CONST(-1.3943989608820324)))
# MOVE(TEMP(3),BINOP(ADD,TEMP(33),CONST(-0.9676655031021857)))
# MOVE(TEMP(4),BINOP(ADD,TEMP(34),CONST(-1.423850471636429)))
# MOVE(TEMP(5),BINOP(ADD,TEMP(35),CONST(0.06529833360313819)))
# MOVE(TEMP(6),BINOP(ADD,TEMP(36),CONST(0.5254141690766835)))
# MOVE(TEMP(7),BINOP(ADD,TEMP(37),CONST(0.046783390621828465)))
# MOVE(TEMP(8),BINOP(ADD,TEMP(38),CONST(-0.9507037341689842)))
# MOVE(TEMP(9),BINOP(ADD,TEMP(39),CONST(-1.2531068184518048)))
# MOVE(TEMP(10),BINOP(ADD,TEMP(40),CONST(-2.23040362756971)))
# MOVE(TEMP(11),BINOP(ADD,TEMP(41),CONST(1.1777309975678627)))
# MOVE(TEMP(12),BINOP(ADD,TEMP(42),CONST(0.0037255510002968824)))
# MOVE(TEMP(13),BINOP(ADD,TEMP(43),CONST(0.6382634652106646)))
# MOVE(TEMP(14),BINOP(ADD,TEMP(44),CONST(0.5289805780077146)))
# MOVE(TEMP(15),BINOP(ADD,TEMP(45),CONST(1.0338980480444375)))
# MOVE(TEMP(16),BINOP(ADD,TEMP(46),CONST(0.8266868322290969)))
# MOVE(TEMP(17),BINOP(ADD,TEMP(47),CONST(1.3838284862923584)))
# MOVE(TEMP(18),BINOP(ADD,TEMP(48),CONST(-0.5289419542278394)))
# MOVE(TEMP(19),BINOP(ADD,TEMP(49),CONST(-0.4694526196029311)))
# MOVE(TEMP(20),BINOP(ADD,TEMP(50),CONST(0.167598301164195)))
# MOVE(TEMP(21),BINOP(ADD,TEMP(51),CONST(-0.08488911818260186)))
# MOVE(TEMP(22),BINOP(ADD,TEMP(52),CONST(-0.7621557047439229)))
# MOVE(TEMP(23),BINOP(ADD,TEMP(53),CONST(0.2679705398686476)))
# MOVE(TEMP(24),BINOP(ADD,TEMP(54),CONST(0.24089647047445992)))
# MOVE(TEMP(25),BINOP(ADD,TEMP(55),CONST(0.5576656745671401)))
# MOVE(TEMP(26),BINOP(ADD,TEMP(56),CONST(-0.9528078849394902)))
# MOVE(TEMP(27),BINOP(ADD,TEMP(57),CONST(-1.279969817573937)))
# MOVE(TEMP(28),BINOP(ADD,TEMP(58),CONST(-1.0937224821899043)))
# MOVE(TEMP(29),BINOP(ADD,TEMP(59),CONST(0.856093754505877)))
# MOVE(TEMP(0),CALL(RELU,TEMP(0)))
# MOVE(TEMP(1),CALL(RELU,TEMP(1)))
# MOVE(TEMP(2),CALL(RELU,TEMP(2)))
# MOVE(TEMP(3),CALL(RELU,TEMP(3)))
# MOVE(TEMP(4),CALL(RELU,TEMP(4)))
# MOVE(TEMP(5),CALL(RELU,TEMP(5)))
# MOVE(TEMP(6),CALL(RELU,TEMP(6)))
# MOVE(TEMP(7),CALL(RELU,TEMP(7)))
# MOVE(TEMP(8),CALL(RELU,TEMP(8)))
# MOVE(TEMP(9),CALL(RELU,TEMP(9)))
# MOVE(TEMP(10),CALL(RELU,TEMP(10)))
# MOVE(TEMP(11),CALL(RELU,TEMP(11)))
# MOVE(TEMP(12),CALL(RELU,TEMP(12)))
# MOVE(TEMP(13),CALL(RELU,TEMP(13)))
# MOVE(TEMP(14),CALL(RELU,TEMP(14)))
# MOVE(TEMP(15),CALL(RELU,TEMP(15)))
# MOVE(TEMP(16),CALL(RELU,TEMP(16)))
# MOVE(TEMP(17),CALL(RELU,TEMP(17)))
# MOVE(TEMP(18),CALL(RELU,TEMP(18)))
# MOVE(TEMP(19),CALL(RELU,TEMP(19)))
# MOVE(TEMP(20),CALL(RELU,TEMP(20)))
# MOVE(TEMP(21),CALL(RELU,TEMP(21)))
# MOVE(TEMP(22),CALL(RELU,TEMP(22)))
# MOVE(TEMP(23),CALL(RELU,TEMP(23)))
# MOVE(TEMP(24),CALL(RELU,TEMP(24)))
# MOVE(TEMP(25),CALL(RELU,TEMP(25)))
# MOVE(TEMP(26),CALL(RELU,TEMP(26)))
# MOVE(TEMP(27),CALL(RELU,TEMP(27)))
# MOVE(TEMP(28),CALL(RELU,TEMP(28)))
# MOVE(TEMP(29),CALL(RELU,TEMP(29)))
# COMMENT(END)
# COMMENT(START)
# MOVE(TEMP(1),CONST(0))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(1),BINOP(ADD,TEMP(1),BINOP(MUL,CONST(1.410118214094354),TEMP(0))))
# MOVE(TEMP(1),BINOP(ADD,TEMP(1),BINOP(MUL,CONST(0.04225423021072284),TEMP(0))))
# MOVE(TEMP(1),BINOP(ADD,TEMP(1),BINOP(MUL,CONST(2.0251819055357934),TEMP(0))))
# MOVE(TEMP(1),BINOP(ADD,TEMP(1),BINOP(MUL,CONST(0.014055830643608627),TEMP(0))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(1),BINOP(ADD,TEMP(1),BINOP(MUL,CONST(0.5811088555178595),TEMP(0))))
# MOVE(TEMP(1),BINOP(ADD,TEMP(1),BINOP(MUL,CONST(0.3459242492933003),TEMP(0))))
# MOVE(TEMP(1),BINOP(ADD,TEMP(1),BINOP(MUL,CONST(0.22098726435365101),TEMP(0))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(1),BINOP(ADD,TEMP(1),BINOP(MUL,CONST(2.103544640570705),TEMP(0))))
# MOVE(TEMP(1),BINOP(ADD,TEMP(1),BINOP(MUL,CONST(3.1592988846246213),TEMP(0))))
# MOVE(TEMP(1),BINOP(ADD,TEMP(1),BINOP(MUL,CONST(0.15917175114957618),TEMP(0))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(1),BINOP(ADD,TEMP(1),BINOP(MUL,CONST(0.5536735715945471),TEMP(0))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(1),BINOP(ADD,TEMP(1),BINOP(MUL,CONST(0.4163178996515),TEMP(0))))
# MOVE(TEMP(1),BINOP(ADD,TEMP(1),BINOP(MUL,CONST(0.1711174144189767),TEMP(0))))
# MOVE(TEMP(1),BINOP(ADD,TEMP(1),BINOP(MUL,CONST(0.8612957832719826),TEMP(0))))
# # here there was a 0 so we exploit sparsity
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(1),BINOP(ADD,TEMP(1),BINOP(MUL,CONST(2.5451101443513973),TEMP(0))))
# # here there was a 0 so we exploit sparsity
# MOVE(TEMP(0),BINOP(ADD,TEMP(1),CONST(0.22734923667546503)))
# MOVE(TEMP(0),CALL(LINEAR,TEMP(0)))
# COMMENT(END)

# %% [markdown]
# # Simulated architecture
# We decided to buld a simulator of a simple architecture in order to be able to have a standardized context of execution straight in our python notebook.
# It has a basic instruction set; also the idea of having a "simpler machine" than our  laptop is useful in the context of interpreting the project as a tool to work with embedded systems

# %%
from enum import Enum
import numpy as np
    
class AsmInstruction:
    def __init__(self,cmd,A,B,C):
        self.cmd = cmd
        self.A   = A
        self.B   = B
        self.C   = C
        
class Arch:
    class ASM_INSTRUCTION_NAME(Enum):
        OUTPUT = 0
        ADD = 1
        SUB = 2
        MUL = 3
        DIV = 4
        ADDI = 5
        SUBI = 6
        MULI = 7
        DIVI = 8
        JZ   = 9   # JUMP IF EQUAL ELSE CONTINUE
        JNZ  = 10  # JUMP IF EQUAL ELSE CONTINUE
        JGT  = 11  # JUMP IF GREATER OR EQUAL ELSE CONTINUE
        LW   = 12  # LOAD  MEMORY VALUE
        SW   = 13  # STORE MEMORY VALUE
        
    def __init__(self, N_registers, Memory_size = 1024 * 8):
        self.N_registers = N_registers
        
        self.MEMORY_OFFSET = N_registers + 1
        self.PC_id       = N_registers              # id of the program counter register
        self.registers   = np.zeros(N_registers     # floating point registers
                                   + 1              # program counter
                                   + Memory_size    # memory cells treated as registers for the moment
                                   )
        
        self.instruction = {}
        # 
        self.instruction[self.ASM_INSTRUCTION_NAME.OUTPUT] = lambda b,c : self.registers[b] + (print("OUTPUT:\t" + str(self.registers[c])) == None)*0
        self.instruction[self.ASM_INSTRUCTION_NAME.ADD]  = lambda b,c : self.registers[b] + self.registers[c]
        self.instruction[self.ASM_INSTRUCTION_NAME.SUB]  = lambda b,c : self.registers[b] - self.registers[c]
        self.instruction[self.ASM_INSTRUCTION_NAME.MUL]  = lambda b,c : self.registers[b] * self.registers[c]
        self.instruction[self.ASM_INSTRUCTION_NAME.DIV]  = lambda b,c : self.registers[b] / self.registers[c]
        self.instruction[self.ASM_INSTRUCTION_NAME.ADDI] = lambda b,c : self.registers[b] + c
        self.instruction[self.ASM_INSTRUCTION_NAME.SUBI] = lambda b,c : self.registers[b] - c
        self.instruction[self.ASM_INSTRUCTION_NAME.MULI] = lambda b,c : self.registers[b] * c
        self.instruction[self.ASM_INSTRUCTION_NAME.DIVI] = lambda b,c : self.registers[b] / c
        self.instruction[self.ASM_INSTRUCTION_NAME.JZ]   = lambda b,c : (self.registers[b] == 0 ) * (c - 1)  + self.registers[self.PC_id]
        self.instruction[self.ASM_INSTRUCTION_NAME.JNZ]  = lambda b,c : (self.registers[b] != 0 ) * (c - 1)  + self.registers[self.PC_id]
        self.instruction[self.ASM_INSTRUCTION_NAME.JGT]  = lambda b,c : (self.registers[b] >= 0 ) * (c - 1)  + self.registers[self.PC_id]
        self.instruction[self.ASM_INSTRUCTION_NAME.LW]   = lambda b,c : self.registers[b]  # LW $dest $source
        self.instruction[self.ASM_INSTRUCTION_NAME.SW]   = lambda b,c : self.registers[b]  # SW $dest $source 
        
    def run(self,program):
        # program is a list of instructions
        self.registers[self.PC_id] = 0.
        while self.registers[self.PC_id] < len(program):
            p = program[self.registers[self.PC_id].astype(int)]
            self.registers[p.A] = self.instruction[p.cmd](p.B,p.C)
            self.registers[self.PC_id] += 1
    def print(self):
        print(self.registers[:self.N_registers])

# %%
def asm_addi(architettura, a,b,c):
    return AsmInstruction(architettura.ASM_INSTRUCTION_NAME.ADDI,a,b,c)
def asm_subi(architettura, a,b,c):
    return AsmInstruction(architettura.ASM_INSTRUCTION_NAME.SUBI,a,b,c)
def asm_muli(architettura, a,b,c):
    return AsmInstruction(architettura.ASM_INSTRUCTION_NAME.MULI,a,b,c)
def asm_divi(architettura, a,b,c):
    return AsmInstruction(architettura.ASM_INSTRUCTION_NAME.DIVI,a,b,c)
def asm_add(architettura, a,b,c):
    return AsmInstruction(architettura.ASM_INSTRUCTION_NAME.ADD,a,b,c)
def asm_sub(architettura, a,b,c):
    return AsmInstruction(architettura.ASM_INSTRUCTION_NAME.SUB,a,b,c)
def asm_mul(architettura, a,b,c):
    return AsmInstruction(architettura.ASM_INSTRUCTION_NAME.MUL,a,b,c)
def asm_div(architettura, a,b,c):
    return AsmInstruction(architettura.ASM_INSTRUCTION_NAME.DIV,a,b,c)
def asm_output(architettura,a):
    return AsmInstruction(architettura.ASM_INSTRUCTION_NAME.OUTPUT,0,0,a)
def asm_sw(architettura,dest,source):
    return AsmInstruction(architettura.ASM_INSTRUCTION_NAME.SW,dest + architettura.MEMORY_OFFSET,source,0)
def asm_lw(architettura,dest,source):
    return AsmInstruction(architettura.ASM_INSTRUCTION_NAME.LW,dest,source  + architettura.MEMORY_OFFSET,0)
def asm_jz(architettura,registro,salto):
    return AsmInstruction(architettura.ASM_INSTRUCTION_NAME.JZ, architettura.PC_id, registro, salto)
def asm_jnz(architettura,registro,salto):
    return AsmInstruction(architettura.ASM_INSTRUCTION_NAME.JNZ, architettura.PC_id, registro, salto)
def asm_jgt(architettura,registro,salto):
    return AsmInstruction(architettura.ASM_INSTRUCTION_NAME.JGT, architettura.PC_id, registro, salto)

# %%
architettura = Arch(16)
#programma = [
#    AsmInstruction(architettura.ASM_INSTRUCTION_NAME.ADDI,   0,0,1 ),
#    AsmInstruction(architettura.ASM_INSTRUCTION_NAME.ADDI,   1,1,2 ),  
#    AsmInstruction(architettura.ASM_INSTRUCTION_NAME.ADDI,   0,0,4 ),
#    AsmInstruction(architettura.ASM_INSTRUCTION_NAME.OUTPUT, 2,2,0 ),   
#    AsmInstruction(architettura.ASM_INSTRUCTION_NAME.SW,   124,1,0 ),   
#    AsmInstruction(architettura.ASM_INSTRUCTION_NAME.LW,   3,124,0 ),
#    AsmInstruction(architettura.ASM_INSTRUCTION_NAME.OUTPUT, 0,0,3 )     
#]

programma = [
    asm_addi(architettura,0,0,1),
    asm_addi(architettura,1,1,2),
    asm_addi(architettura,0,0,4),
    asm_output(architettura,0)  ,
    asm_jz(architettura,0, 3),
    asm_sw(architettura, 124, 0),
    asm_lw(architettura, 3, 124),
    asm_output(architettura,3)
]
architettura.run(programma)
# Out:
# OUTPUT:	5.0
# OUTPUT:	5.0

# %% [markdown]
# # Temporary Variable Usage
# Dal momento che la liveness viene definita a priori nella rappresentazione intermedia nel momento in cui c'é una sovrascrittura.
# In ogni coppia di layer $(layer_i, layer_{i+1})$ trovo le variabili temporali piu utilizzate.
# Queste diventeranno i miei registri.
# Step successivo : la posizione delle varibaili che invece vanno scritte in memoria va ottimizzata in modo da sfruttare il piu possibile la data locality

# %%
def most_used_register(ir):
    statistics_per_block = list()
    def add_usage_statistics(statistics_per_block, temp_name ):
        # takes the name of a temporary variabile and counts it as used in the statistics dictionary
        old_value = statistics_per_block[-1].get(temp_name)
        if old_value == None:
            old_value = 0
        statistics_per_block[-1][temp_name] = old_value + 1
    
    for ir_instruction in ir:
        if(ir_instruction.id == "COMMENT"):
            if(ir_instruction.sons[0].id == "START"):
                statistics_per_block.append({})  # we put a dictionary
            
        unrolled_ir = ir_instruction.flatten()
        temp_used   = list()
        for u,val in zip(unrolled_ir[:-1],unrolled_ir[1:]):
            if u == "TEMP":
                temp_used.append(val)
        for t in temp_used:
            add_usage_statistics(statistics_per_block, t)
    
    ret = list()
    for stat in statistics_per_block:
        arr = []
        for s in stat:
            arr.append( [ s, stat[s]] )
        arr = np.array(arr)
        arr = arr[ arr[:,1].argsort()[-1::-1] ]
        ret.append(arr)
    return ret


def register_allocation(statistics_list, register_names):
    ret = list()
    for stat in statistics_list:
        allocation = list()
        for s,r in zip(stat,register_names):
            allocation.append([s[0],r])
        for i in range(len(register_names), len(stat)):
            allocation.append([stat[i][0],"memory"])
        ret.append(np.array(allocation))
    return ret
    
stats = most_used_register(intermediate_representation)  
print(stats)
register_allocation(stats,["A","B","C","D","E","F"])
# Out:
# [array([[59, 10],
#        [37, 10],
#        [31, 10],
#        [30, 10],
#        [49,  8],
#        [46,  8],
#        [42,  8],
#        [54,  8],
#        [33,  8],
#        [34,  8],
#        [41,  8],
#        [56,  8],
#        [58,  8],
#        [ 1,  7],
#        [ 0,  7],
#        [ 7,  7],
#        [29,  7],
#        [36,  6],
#        [ 3,  6],
#        [50,  6],
#        [24,  6],
#        [19,  6],
#        [26,  6],
#        [40,  6],
#        [12,  6],
#        [39,  6],
#        [16,  6],
#        [ 4,  6],
#        [47,  6],
#        [28,  6],
#        [11,  6],
#        [17,  5],
#        [ 6,  5],
#        [20,  5],
#        [ 9,  5],
#        [10,  5],
#        [38,  4],
#        [35,  4],
#        [32,  4],
#        [44,  4],
#        [27,  4],
#        [57,  4],
#        [48,  4],
#        [51,  4],
#        [25,  4],
#        [23,  4],
#        [22,  4],
#        [21,  4],
#        [18,  4],
#        [14,  4],
#        [ 8,  4],
#        [ 5,  4],
#        [ 2,  4],
#        [55,  4],
#        [53,  4],
#        [52,  4],
#        [13,  3],
#        [15,  3],
#        [43,  2],
#        [45,  2]]), array([[42, 34],
#        [43, 32],
#        [32, 30],
#        [35, 30],
#        [38, 28],
#        [49, 28],
#        [47, 28],
#        [30, 28],
#        [54, 28],
#        [44, 26],
#        [45, 26],
#        [50, 26],
#        [41, 24],
#        [58, 24],
#        [34, 24],
#        [33, 24],
#        [31, 24],
#        [51, 24],
#        [59, 24],
#        [48, 22],
#        [52, 22],
#        [53, 22],
#        [37, 22],
#        [56, 22],
#        [46, 20],
#        [55, 20],
#        [39, 20],
#        [12, 19],
#        [13, 18],
#        [40, 18],
#        [36, 18],
#        [ 2, 17],
#        [ 5, 17],
#        [17, 16],
#        [19, 16],
#        [24, 16],
#        [ 8, 16],
#        [ 0, 16],
#        [15, 15],
#        [14, 15],
#        [20, 15],
#        [21, 14],
#        [29, 14],
#        [11, 14],
#        [28, 14],
#        [ 1, 14],
#        [ 3, 14],
#        [ 4, 14],
#        [22, 13],
#        [23, 13],
#        [18, 13],
#        [26, 13],
#        [ 7, 13],
#        [25, 12],
#        [16, 12],
#        [ 9, 12],
#        [57, 12],
#        [ 6, 11],
#        [10, 11],
#        [27,  8]]), array([[ 1, 32],
#        [ 0, 18]])]
# [array([['59', 'A'],
#         ['37', 'B'],
#         ['31', 'C'],
#         ['30', 'D'],
#         ['49', 'E'],
#         ['46', 'F'],
#         ['42', 'memory'],
#         ['54', 'memory'],
#         ['33', 'memory'],
#         ['34', 'memory'],
#         ['41', 'memory'],
#         ['56', 'memory'],
#         ['58', 'memory'],
#         ['1', 'memory'],
#         ['0', 'memory'],
#         ['7', 'memory'],
#         ['29', 'memory'],
#         ['36', 'memory'],
#         ['3', 'memory'],
#         ['50', 'memory'],
#         ['24', 'memory'],
#         ['19', 'memory'],
#         ['26', 'memory'],
#         ['40', 'memory'],
#         ['12', 'memory'],
#         ['39', 'memory'],
#         ['16', 'memory'],
#         ['4', 'memory'],
#         ['47', 'memory'],
#         ['28', 'memory'],
#         ['11', 'memory'],
#         ['17', 'memory'],
#         ['6', 'memory'],
#         ['20', 'memory'],
#         ['9', 'memory'],
#         ['10', 'memory'],
#         ['38', 'memory'],
#         ['35', 'memory'],
#         ['32', 'memory'],
#         ['44', 'memory'],
#         ['27', 'memory'],
#         ['57', 'memory'],
#         ['48', 'memory'],
#         ['51', 'memory'],
#         ['25', 'memory'],
#         ['23', 'memory'],
#         ['22', 'memory'],
#         ['21', 'memory'],
#         ['18', 'memory'],
#         ['14', 'memory'],
#         ['8', 'memory'],
#         ['5', 'memory'],
#         ['2', 'memory'],
#         ['55', 'memory'],
#         ['53', 'memory'],
#         ['52', 'memory'],
#         ['13', 'memory'],
#         ['15', 'memory'],
#         ['43', 'memory'],
#         ['45', 'memory']], dtype='<U21'),
#  array([['42', 'A'],
#         ['43', 'B'],
#         ['32', 'C'],
#         ['35', 'D'],
#         ['38', 'E'],
#         ['49', 'F'],
#         ['47', 'memory'],
#         ['30', 'memory'],
#         ['54', 'memory'],
#         ['44', 'memory'],
#         ['45', 'memory'],
#         ['50', 'memory'],
#         ['41', 'memory'],
#         ['58', 'memory'],
#         ['34', 'memory'],
#         ['33', 'memory'],
#         ['31', 'memory'],
#         ['51', 'memory'],
#         ['59', 'memory'],
#         ['48', 'memory'],
#         ['52', 'memory'],
#         ['53', 'memory'],
#         ['37', 'memory'],
#         ['56', 'memory'],
#         ['46', 'memory'],
#         ['55', 'memory'],
#         ['39', 'memory'],
#         ['12', 'memory'],
#         ['13', 'memory'],
#         ['40', 'memory'],
#         ['36', 'memory'],
#         ['2', 'memory'],
#         ['5', 'memory'],
#         ['17', 'memory'],
#         ['19', 'memory'],
#         ['24', 'memory'],
#         ['8', 'memory'],
#         ['0', 'memory'],
#         ['15', 'memory'],
#         ['14', 'memory'],
#         ['20', 'memory'],
#         ['21', 'memory'],
#         ['29', 'memory'],
#         ['11', 'memory'],
#         ['28', 'memory'],
#         ['1', 'memory'],
#         ['3', 'memory'],
#         ['4', 'memory'],
#         ['22', 'memory'],
#         ['23', 'memory'],
#         ['18', 'memory'],
#         ['26', 'memory'],
#         ['7', 'memory'],
#         ['25', 'memory'],
#         ['16', 'memory'],
#         ['9', 'memory'],
#         ['57', 'memory'],
#         ['6', 'memory'],
#         ['10', 'memory'],
#         ['27', 'memory']], dtype='<U21'),
#  array([['1', 'A'],
#         ['0', 'B']], dtype='<U21')]

# %% [markdown]
# # Memory allocation simulated annealing

# %% [markdown]
# ### Compute correlation between temp vars
# Build a vector of lists ${\bf v}$, indiced by the temporary variables.
# We iterate through the intermediate representation; for each instruction, we find the list of temporal variables used.
# Once this list is found, we add 1 to each element of $v$ in the lists associated with the temporal variables used, 0 to the others

# %%
def correlation_between_temps(ir, register_allocation_output):
    # takes as input an intermediate repr and a register allocation output
    
    signals_per_block = list()
    
    def add_tick(signals_per_block, temp_variables , all_temp_variables):
        # push 0 in the lists of unused temps and 1 in the list of the used temp
        for t in all_temp_variables:
            signals_per_block[-1][t].append(0)
        for t in temp_variables:
            signals_per_block[-1][t][-1] = 1.
        
    curr_register_allocation_output = 0
    all_temp_variables = []
    
    for ir_instruction in ir:
        if(ir_instruction.id == "COMMENT"):
            if(ir_instruction.sons[0].id == "START"):
                signals_per_block.append({})
                all_temp_variables = register_allocation_output[curr_register_allocation_output][
                    register_allocation_output[curr_register_allocation_output][:,1] == "memory"
                ][:,0]
                for t in all_temp_variables:
                    signals_per_block[-1][t] = list()
                    
                curr_register_allocation_output += 1

        unrolled_ir = ir_instruction.flatten()
        temp_used   = list()
        
        for u,val in zip(unrolled_ir[:-1],unrolled_ir[1:]):
            if u == "TEMP":
                temp_used.append(val)        
        add_tick(signals_per_block, np.intersect1d( temp_used,all_temp_variables) , all_temp_variables)
    return signals_per_block

stats = most_used_register(intermediate_representation)  
RA_data = register_allocation(stats,["A","B","C","D","E","F"])
signals = correlation_between_temps(intermediate_representation, RA_data)
plt.figure(figsize=(10,10))
p = 1
for i,s in enumerate(signals[p]):
    plt.annotate(s,(0,2 * i))
    plt.plot(np.array(signals[p][s]) + 2 * i, color = 'black' , alpha = 0.2,)

# %% [markdown]
# ### Distance matrix

# %%
def compute_distance_matrices(signals):
    Ds = list()
    for signals_block in signals:
        D = np.zeros((len(signals_block),len(signals_block)))
        for i,a in enumerate(signals_block):
            for j,b in enumerate(signals_block):  
                v_a = np.arange(len(signals_block[a]))[np.array(signals_block[a]) == 1.]
                v_b = np.arange(len(signals_block[b]))[np.array(signals_block[b]) == 1.]
                distanza = 0.5 * (np.mean([ np.min(np.abs(s_1 - v_b)) for s_1 in v_a]) + np.mean([ np.min(np.abs(s_2 - v_a)) for s_2 in v_b]))
                D[i,j] = distanza
        Ds.append(D)
    return Ds
D = compute_distance_matrices(signals)[0]

# %%
from sklearn.manifold import MDS
embedding = MDS( dissimilarity = 'precomputed',n_components = 1)
N = len(D)
X_proj    = embedding.fit_transform(D[:N,:N])
plt.scatter(X_proj[:,0][:N], 0 * X_proj[:,0][:N])
for i,s in enumerate(signals[0]):
    if i >= N:
        break
    plt.annotate(s, (X_proj[i,0],0))
plt.figure()
D_hat = np.array([
    [
            np.linalg.norm(x - x_)
        for x_ in X_proj
    ]
    for x in X_proj
])
plt.imshow(D_hat)

# %%
classifica = np.c_[X_proj, [s  for s in signals[0]]].astype(np.float16)
classifica = classifica[classifica[:,0].argsort()]
classifica = np.c_[classifica, np.arange(len(classifica))]
classifica
# Out:
# array([[-23.703125  ,  15.        ,   0.        ],
#        [-22.875     ,  13.        ,   1.        ],
#        [-18.34375   ,  27.        ,   2.        ],
#        [-18.0625    ,  29.        ,   3.        ],
#        [-17.640625  ,  28.        ,   4.        ],
#        [-16.65625   ,  25.        ,   5.        ],
#        [-16.34375   ,  26.        ,   6.        ],
#        [-15.0546875 ,  23.        ,   7.        ],
#        [-14.953125  ,  24.        ,   8.        ],
#        [-14.421875  ,  22.        ,   9.        ],
#        [-13.84375   ,  21.        ,  10.        ],
#        [-12.828125  ,  20.        ,  11.        ],
#        [-11.6640625 ,  19.        ,  12.        ],
#        [-11.3125    ,  18.        ,  13.        ],
#        [-10.3046875 ,  17.        ,  14.        ],
#        [ -9.0703125 ,  16.        ,  15.        ],
#        [ -8.34375   ,  14.        ,  16.        ],
#        [ -6.7421875 ,  12.        ,  17.        ],
#        [ -5.54296875,  11.        ,  18.        ],
#        [ -4.7578125 ,  10.        ,  19.        ],
#        [ -3.94140625,   9.        ,  20.        ],
#        [ -3.66992188,   8.        ,  21.        ],
#        [ -1.86914062,   7.        ,  22.        ],
#        [ -1.28710938,   5.        ,  23.        ],
#        [ -1.24121094,   6.        ,  24.        ],
#        [  0.51220703,   4.        ,  25.        ],
#        [  0.79833984,   2.        ,  26.        ],
#        [  1.96875   ,  58.        ,  27.        ],
#        [  2.328125  ,  56.        ,  28.        ],
#        [  2.38085938,   3.        ,  29.        ],
#        [  3.31054688,  54.        ,  30.        ],
#        [  3.66796875,  57.        ,  31.        ],
#        [  4.25390625,  55.        ,  32.        ],
#        [  5.1015625 ,   1.        ,  33.        ],
#        [  5.55078125,  53.        ,  34.        ],
#        [  6.01171875,  52.        ,  35.        ],
#        [  6.171875  ,  50.        ,  36.        ],
#        [  6.52734375,  51.        ,  37.        ],
#        [  8.1171875 ,  47.        ,  38.        ],
#        [  8.4140625 ,  48.        ,  39.        ],
#        [  8.8828125 ,   0.        ,  40.        ],
#        [ 11.25      ,  42.        ,  41.        ],
#        [ 11.625     ,  44.        ,  42.        ],
#        [ 12.328125  ,  41.        ,  43.        ],
#        [ 13.671875  ,  40.        ,  44.        ],
#        [ 14.4140625 ,  39.        ,  45.        ],
#        [ 15.7109375 ,  38.        ,  46.        ],
#        [ 16.75      ,  36.        ,  47.        ],
#        [ 17.59375   ,  34.        ,  48.        ],
#        [ 17.90625   ,  35.        ,  49.        ],
#        [ 18.515625  ,  33.        ,  50.        ],
#        [ 19.90625   ,  32.        ,  51.        ],
#        [ 20.15625   ,  45.        ,  52.        ],
#        [ 20.671875  ,  43.        ,  53.        ]])

# %% [markdown]
# ### Overall function
# Prende in input una rappresentazione intermedia e produce l'assegnazione dei registri e della memoria

# %%
def register_and_memory_allocation(ir, available_registers):
    # input  : una rappresentazione intermedia e un set di registri disponibili
    # output : the list of allocations
    stats     = most_used_register(ir)
    alloc_reg = register_allocation(stats, available_registers)
    signals   = correlation_between_temps(intermediate_representation, alloc_reg)
    distance_matrices = compute_distance_matrices(signals)
    addresses = list()
    for d in distance_matrices:
        if len(d) > 0:
            proj     =   MDS( dissimilarity = 'precomputed',n_components = 1).fit_transform(d).flatten()
            position = np.c_[proj, [s  for s in signals[0]]].astype(np.float16)
            position = position[position[:,0].argsort()]
            position = np.c_[position,np.arange(len(position))]
            addresses.append(position[:,1:].astype(int))
            
    for a,ind in zip(alloc_reg,addresses):
        a[a[:,1] == 'memory'] = ind
            
    return alloc_reg
register_and_memory_allocation(intermediate_representation, ['A','B','C','D'])
# Out:
# [array([['59', 'A'],
#         ['37', 'B'],
#         ['31', 'C'],
#         ['30', 'D'],
#         ['15', '0'],
#         ['13', '1'],
#         ['29', '2'],
#         ['27', '3'],
#         ['28', '4'],
#         ['25', '5'],
#         ['26', '6'],
#         ['23', '7'],
#         ['24', '8'],
#         ['22', '9'],
#         ['21', '10'],
#         ['20', '11'],
#         ['19', '12'],
#         ['18', '13'],
#         ['17', '14'],
#         ['16', '15'],
#         ['14', '16'],
#         ['12', '17'],
#         ['11', '18'],
#         ['10', '19'],
#         ['9', '20'],
#         ['8', '21'],
#         ['54', '22'],
#         ['56', '23'],
#         ['58', '24'],
#         ['57', '25'],
#         ['49', '26'],
#         ['5', '27'],
#         ['7', '28'],
#         ['6', '29'],
#         ['2', '30'],
#         ['4', '31'],
#         ['3', '32'],
#         ['55', '33'],
#         ['1', '34'],
#         ['53', '35'],
#         ['0', '36'],
#         ['52', '37'],
#         ['50', '38'],
#         ['51', '39'],
#         ['47', '40'],
#         ['48', '41'],
#         ['46', '42'],
#         ['42', '43'],
#         ['44', '44'],
#         ['41', '45'],
#         ['40', '46'],
#         ['39', '47'],
#         ['38', '48'],
#         ['36', '49'],
#         ['34', '50'],
#         ['45', '51'],
#         ['35', '52'],
#         ['33', '53'],
#         ['32', '54'],
#         ['43', '55']], dtype='<U21'),
#  array([['42', 'A'],
#         ['43', 'B'],
#         ['32', 'C'],
#         ['35', 'D'],
#         ['54', '0'],
#         ['29', '1'],
#         ['35', '2'],
#         ['23', '3'],
#         ['17', '4'],
#         ['7', '5'],
#         ['0', '6'],
#         ['22', '7'],
#         ['21', '8'],
#         ['6', '9'],
#         ['11', '10'],
#         ['26', '11'],
#         ['15', '12'],
#         ['2', '13'],
#         ['49', '14'],
#         ['38', '15'],
#         ['16', '16'],
#         ['28', '17'],
#         ['52', '18'],
#         ['58', '19'],
#         ['43', '20'],
#         ['51', '21'],
#         ['4', '22'],
#         ['3', '23'],
#         ['1', '24'],
#         ['13', '25'],
#         ['40', '26'],
#         ['39', '27'],
#         ['33', '28'],
#         ['34', '29'],
#         ['19', '30'],
#         ['41', '31'],
#         ['24', '32'],
#         ['47', '33'],
#         ['12', '34'],
#         ['44', '35'],
#         ['36', '36'],
#         ['42', '37'],
#         ['50', '38'],
#         ['56', '39'],
#         ['46', '40'],
#         ['32', '41'],
#         ['53', '42'],
#         ['20', '43'],
#         ['8', '44'],
#         ['9', '45'],
#         ['27', '46'],
#         ['57', '47'],
#         ['18', '48'],
#         ['14', '49'],
#         ['10', '50'],
#         ['55', '51'],
#         ['5', '52'],
#         ['45', '53'],
#         ['25', '54'],
#         ['48', '55']], dtype='<U21'),
#  array([['1', 'A'],
#         ['0', 'B']], dtype='<U21')]

# %% [markdown]
# # Unoptimized assembler
#
# Just translating the $\text{IR instructions}$ in $\text{ASM instructions}$

# %%
def assemble(IR_instruction):
    reg_mem_alloc = register_and_memory_allocation(ir, available_registers)
    program = list()
    for ir in IR_instruction:
        # do some stuff
        print(ir)
    return program

# %%
np.random.choice( 10, size = (5) , replace = False)
# Out:
# array([9, 8, 0, 3, 2])
