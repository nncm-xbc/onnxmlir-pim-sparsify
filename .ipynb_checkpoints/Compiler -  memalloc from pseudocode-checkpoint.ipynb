# %% [markdown]
# # Compiler

# %% [markdown]
# ## Network container class

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import jax
import jax.numpy as jnp

class Program:
    # this class contains in a structured manner matrices and biases
    # which encode the semantics of the program network, in the same fashion
    # of the source code of a program
    def __init__(self, topology , activation_functions_list):
        self.topology = topology
        self.activation_functions_list = activation_functions_list
        self.W = [ 0 for t in topology[:-1]]
        self.b = [ 0 for t in topology[:-1]]
        
        
        self.activation_functions = {}
        self.activation_functions['RELU']   = lambda x : jnp.maximum(0.,x)
        self.activation_functions['LINEAR'] = lambda x : x
        
    def random_init_weights(self):
        for layer in range(len(self.topology[:-1])):
            self.W[layer] = np.random.normal( size = (self.topology[layer + 1] , self.topology[layer] ) )**2
            size = self.W[layer].shape[0] * self.W[layer].shape[1] 
            for i in range(size - int(np.sqrt(size))):
                r = np.random.choice(len(self.W[layer]))
                c = np.random.choice(len(self.W[layer].T))
                self.W[layer][r,c] = 0.   # adding some sparsity
                
            self.b[layer] = np.random.normal( size = self.topology[layer + 1] )
    def print(self):
        for i,layer in enumerate(self.topology[:-1]):
            print("layer %d->%d "%(i,i+1))
            print("W.shape = %s \t b.shape = %s" % (str(self.W[i].shape),str(self.b[i].shape)))
    def visualize_weights(self):
        for w in self.W:
            print(w.shape)
            plt.figure(figsize=(10,10))
            plt.imshow(w > 0.)        
    
    def run(self, data):
        layer = data
        for f_name,weight,bias in zip(self.activation_functions_list,
                                      self.W,
                                      self.b):
            f     = self.activation_functions[f_name]
            layer = f(weight @ layer  + bias)
        return layer

programma = Program([10,20,30,2], ['RELU','RELU','LINEAR'])
programma.random_init_weights()
programma.run( np.random.randn(10))
# Out:
# DeviceArray([60.519363, 40.03862 ], dtype=float32)

# %% [markdown]
# ## Sparsification algorithm

# %% [markdown]
# ## IR production

# %% [markdown]
# ### Lightweight trees representation

# %%
class c:
    # every element is a node in the tree.
    # the first argument denotes the name of the node ; the possible next arguments are a list of the sons.
    # Note that nodes without sons are simply leaf (eg. ADD, MUL,...)
    def __init__(self, ID, *args):
        self.id   = ID
        self.sons = list()
        for arg in args:
            self.sons.append(arg)
    def print(self,level = 0):
        print( ("\t" * level) + str(self.id) )
        for s in self.sons:
            s.print(level + 1)
    def __str__(self):
        ret = str(self.id)
        if len(self.sons) > 0:
            ret += "("
            for s in self.sons:
                ret += str(s)
                if s != self.sons[-1]:
                    ret += ','
            ret += ")"
        return ret
    def flatten(self):
        ret = []
        ret += [self.id]
        for s in self.sons:
            ret += s.flatten()
        return ret

# %% [markdown]
# ### IR production function

# %%
def IR(program, compile_time_data = True):
    # for every layer
    ### print("y = input")
    ret = list()
    
    for layer,t in enumerate(program.topology[1:]):
        IR_instruction = c("COMMENT", c("START"))
        ### print(IR_instruction)
        ret.append(IR_instruction)
        
        f = program.activation_functions_list[layer]
        R_offset = program.topology[layer]
        for i in range(len(program.b[layer])): # for every row
            #print("R[%d] = 0" % (i))
            #print("MOVE( TEMP(%d) , CONST(0) )" % (i + R_offset))
            IR_instruction = c(
                    "MOVE",
                     c("TEMP" , c(i + R_offset) ),
                     c("CONST", c(0))
            )
            ### print(str(IR_instruction))
            ret.append(IR_instruction)
            
            
        for i in range(len(program.W[layer])): # for every row
            for j in range(len(program.W[layer].T)): # for every column
                if( program.W[layer][i,j] != 0):
                    # if there is zero is useless to compute the contribution
                    #print("->MOVE(TEMP(%d),BINOP(ADD,TEMP(%d),BINOP(MUL,CONST(%f),TEMP(%d)))) " % (i + R_offset,i + R_offset, program.W[layer][i,j],i )) # COMPILE DATA HYPOTHESIS
                    IR_instruction = c(
                        "MOVE",
                        c("TEMP",
                            c(i + R_offset)
                        ),
                        c("BINOP",
                            c("ADD"),
                            c("TEMP",
                                c(i + R_offset)
                            ),
                            c("BINOP",
                                c("MUL"),
                                c("CONST",
                                     c(program.W[layer][i,j])
                                 ),
                                c("TEMP",
                                 c(j)
                                 )
                            )
                        )
                    )
                    #print(IR_instruction)
                    ret.append(IR_instruction)
                else:
                    0
                    ### print("# here there was a 0 so we exploit sparsity ")
                    
        for i in range(len(program.b[layer])): # for every row
            # a priori in compile time since the amount of "repetitions" doens't scale quadratically , in opposite to weights
            #print("->MOVE(TEMP(%d),BINOP(ADD,TEMP(%d),CONST(%f)))" % (i, i + R_offset , program.b[layer][i]) )
            
            # For each output temporary i add the bias to it
            # Since after the add of the bias the only modification
            # That is performed on a temporary variable is the application of the 
            # activation function, i condensate the instructions
            # in order to avoid useless memory reads
            
            IR_instruction = c("MOVE",
                                c("CALL",
                                    c(f),
                                    c("TEMP",
                                     c(i + R_offset)
                                     ),
                                    c("BINOP",
                                     c("ADD"),
                                     c("TEMP",
                                       c(i + R_offset)
                                      ),
                                     c("CONST",
                                      c(program.b[layer][i])
                                      )
                                     )
                                 )
                                )
            ### print((IR_instruction))
            ret.append(IR_instruction)

        IR_instruction = c("COMMENT", c("END"))
        ### print(IR_instruction)
        ret.append(IR_instruction)
    return ret

# %% [markdown]
# ## Register and memory allocation

# %% [markdown]
# ### Temporary variables statistics class

# %%
class TemporaryVariablesStatistics:
    def __init__(self):
        self.temp_usage_map = {}
    def increment(self,temp_variable):
        old_value = self.temp_usage_map.get(temp_variable)
        if old_value == None:
            old_value = 0
        self.temp_usage_map[temp_variable] = old_value + 1
    def get_data(self):
        return self.temp_usage_map
    def vectorize(self):
        arr = []
        for s in self.get_data():
            arr.append( [ s, self.get_data()[s]] )
        arr = np.array(arr)                                                              # builds a tempstable [ temp | usage ]
        arr = arr[ arr[:,1].argsort()[-1::-1] ]                                          # sort the tempstable by usage  (decreasing)
        return arr
    
    def print(self):
        for t in self.temp_usage_map:
            print("%d --> %d" % (t , self.temp_usage_map[t]) )

# %% [markdown]
# ### Register allocation data class

# %%
"sx".startswith("x")
# Out:
# False

# %%
class RegisterAllocationData:
    def __init__(self):
        self.temp_reg_map = {}
    
    def get(self,temp_variable):
        return self.temp_reg_map[temp_variable]
    
    def insert(self,temp_variable, register):
        self.temp_reg_map[temp_variable] = register
    def get_data(self):
        return self.temp_reg_map
    
    def rename(self,old_reg_name, new_reg_name):
        for t in self.temp_reg_map:
            if self.temp_reg_map[t] == old_reg_name:
                self.temp_reg_map[t] = new_reg_name
    
    def get_unitialized_temps(self):
        # returns the list of temps that have a register starting with "register_"
        ret = list()
        for s in self.temp_reg_map:
            if self.temp_reg_map[s].startswith("register_"):
                ret.append(s)
        return ret
    
    def get_initialized_registers(self):
        # returns a list of the register ACTUALLY used (no place holder)
        ret = list()
        for s in self.temp_reg_map:
            if not self.temp_reg_map[s].startswith("register_"):
                ret.append(self.temp_reg_map[s])
        return ret
    
    def get_variables_list(self):
        ret = list()
        for s in self.temp_reg_map:
            ret.append(s)
        return ret
    
    def get_input_temps(self, prev_layer_size):
        all_vars = np.array(self.get_variables_list())
        ret      = list()
        for var in all_vars:
            if var < prev_layer_size:
                ret.append([var, self.temp_reg_map[var]])
        return np.array(ret)
    
    def get_output_temps(self, prev_layer_size):
        all_vars = np.array(self.get_variables_list())
        ret      = list()
        for var in all_vars:
            if var >= prev_layer_size:
                ret.append([var, self.temp_reg_map[var]])
        return np.array(ret)
    
    def print(self):
        for t in self.temp_reg_map:
            print(t , "\t", self.temp_reg_map[t] )
    def contains(self,tmp_name):
        return tmp_name in self.temp_reg_map

# %% [markdown]
# ### Memory allocation data class

# %%
class MemoryAllocationData:
    def __init__(self):
        self.temp_mem_map = {}
        
    def insert(self,temp_variable, address):
        self.temp_mem_map[temp_variable] = address
        
        
    def batch_set(self, list_of_temps, list_of_addresses):
        for tmp_id, mem_addr in zip(list_of_temps,list_of_addresses):
            self.temp_mem_map[tmp_id] = mem_addr
        
    def get_data(self):
        return self.temp_mem_map
    
    def get(self,x):
        return self.temp_mem_map[x]
    
    def get_variables_list(self):
        ret = list()
        for s in self.temp_mem_map:
            ret.append(s)
        return ret
    
    def get_input_temps(self, prev_layer_size):
        all_vars = np.array(self.get_variables_list())
        return all_vars[all_vars < prev_layer_size]
    
    def get_output_temps(self,prev_layer_size):
        all_vars = np.array(self.get_variables_list())
        return all_vars[all_vars >= prev_layer_size]
    
    def print(self):
        for t in self.temp_mem_map:
            print(t , "\t", self.temp_mem_map[t] )

# %% [markdown]
# ### Block Signals

# %%
class BlockSignals:
    def __init__(self, memory_allocation_object):
        # initialize an empty dictionary starting from the variables name
        self.memory_allocation_object = memory_allocation_object
        self.temp_signals_map = {}
        for t in memory_allocation_object.get_data():
            self.temp_signals_map[t] = []
        
    def add_tick(self, temp_variables):
        temp_variables          = np.intersect1d(temp_variables, self.memory_allocation_object.get_variables_list())
        all_temporary_variables = self.memory_allocation_object.get_variables_list()
        # push 0 in the lists of unused temps and 1 in the list of the used temp
        for t in all_temporary_variables:
            self.temp_signals_map[t].append(0)
        for t in temp_variables:
            self.temp_signals_map[t][-1] = 1.
            
    def get_data(self):
        return self.temp_signals_map

# %% [markdown]
# ### Interface Communication between blocks

# %%
class MemoryToRegisterFlow:
    # contains the information about the movement of information from a memory
    # cell to a register from a matrix mult to the next one
    def __init__(self, mem_address, register):
        self.mem_address = mem_address
        self.register    = register
    def print(self):
        print("M2R flow\t%s\t->\t%s" % (self.mem_address,self.register))
class RegisterToMemoryFlow:
    # contains the information about the movement of information from a register 
    # to a memory cell from a matrix mult to the next one
    def __init__(self, register, mem_address):
        self.mem_address = mem_address
        self.register    = register
    def print(self):
        print("R2M flow\t%s\t->\t%s" % (self.register,self.mem_address))

class RegisterRenameFlow:
    # contains the information about the movement of information from a register 
    # to a memory cell from a matrix mult to the next one
    def __init__(self, register_placeholder, register_name):
        self.register_placeholder = register_placeholder
        self.register_name        = register_name
    def print(self):
        print("R2R flow\t%s\t->\t%s" % (self.register_placeholder,self.register_name))

        
class InterfaceCommunication:
    # contains the list of movements "flows" between two matrix mult blocks
    def __init__(self):
        self.reg2memFlows = list()
        self.mem2regFlows = list()
        self.reg2regFlows = list()
    def insert(self,flow):
        if type(flow).__name__ == "RegisterToMemoryFlow":
            self.reg2memFlows.append(flow)
        else:
            if type(flow).__name__ == "MemoryToRegisterFlow":
                self.mem2regFlows.append(flow)
            else:
                if type(flow).__name__ == "RegisterRenameFlow":
                    self.reg2regFlows.append(flow)
                    
    def getReg2MemFlows(self):
        return self.reg2memFlows
    def getMem2RegFlows(self):
        return self.mem2regFlows
    def getReg2RegFlows(self):
        return self.reg2regFlows
    
    def print(self):
        reg2mem = self.getMem2RegFlows()
        mem2reg = self.getReg2MemFlows()
        reg2reg = self.getReg2RegFlows()
        for rm in reg2mem:
            rm.print()
        for mr in mem2reg:
            mr.print()
        for rr in reg2reg:
            rr.print()
        
# interface[layer_1,layer_2] = InterfaceCommunication()
# interface[layer_1,layer_2].insert( RegisterToInputFlow('AX', 0x1234))
# interface[layer_1,layer_2].insert( RegisterToInputFlow('BX', 0x1235))
# interface[layer_1,layer_2].insert( RegisterToInputFlow(0x1236, 'AX'))

A = InterfaceCommunication()
A.insert( RegisterToMemoryFlow("AX",0) )
A.insert( RegisterToMemoryFlow("BX",1) )
A.insert( MemoryToRegisterFlow(2, "AX") )
A.insert( RegisterRenameFlow("register_0", "AX") )
A.print()
# Out:
# M2R flow	2	->	AX
# R2M flow	AX	->	0
# R2M flow	BX	->	1
# R2R flow	register_0	->	AX

# %% [markdown]
# ### Theoretical argument : memory allocation

# %% [markdown]
# Suppose that we have some kind of distance between temporary variables in a <b>matrixmult</b>. <br>
# Therefore we have a collection of distance matrices $\{D_{1,2},D_{2,3},...,D_{N-1,N}\}$ <br>
# We can formulate the following optimization problem <br><br>
# $
#     \text{Find $\{P_{1,2},P_{2,3},...,P_{N-1,N}\}$ permutations of
#     $\{ [1,n_{1,2}], [1,n_{2,3}],... ,[1,n_{N-1,N}] \}$ }
# $ <br>
# $
# \text{such that
#     $D(P_{i,i+1}) \sim D_{i,i+1} \ \ \ \forall i$
# }
# $ <br>
# $
# \text{Subject to
#     $ (P_{i,i+1})_{\text{output (only memory)}} = (P_{i+1,i+2})_{\text{input (only memory)}}  \ \ \forall i$
# }
# $

# %% [markdown]
# ### Proposed algorithm

# %% [markdown]
# $
# \text{$P_0 \leftarrow$ Permutation$(Temp_{\mathcal l,\mathcal l + 1})$ optimal}\\
# \text{${\bf for } \ \ \ i,(layer,layer+1) \in temps $ : } \\
# \hspace{2em} \text{$ P_i \leftarrow $ Permutation$(Temp_{\mathcal l_i,\mathcal l_{i+1}})$ optimal subject to $P_i^{input} = P_{i-1}^{output}$ }
# $

# %% [markdown]
# ### Constrained Permutation Class

# %%
class constrainedPermutation:
    def __init__(self, constraint, trivial_init = True, init_vector = None):
        # constraint = vector of -1, with the exception of the "fixed points" of the permutations
        #              e.g.   -1 -1 4 3 -1
        #              reads as "all the permutations of 01234" such that the third element is 4 and the fourth is 3
        self.constraint = constraint
        if trivial_init == True:
            self.value      = np.arange(len(constraint))
            for i in np.arange(len(constraint))[constraint != -1]:
                # find the value at the position i
                to_swap_A = i                                      # position 1
                to_swap_B = np.argmax(self.value == constraint[i]) # position 2
                tmp       = self.value[to_swap_A]
                self.value[to_swap_A] = self.value[to_swap_B]
                self.value[to_swap_B] = tmp
        else:
            self.value = init_vector.copy()
    
    def get_neighbor(self):
        feasible = np.arange(len(self.constraint))[self.constraint == -1]
        old = self.value[feasible]
        a        = np.random.choice(len(feasible))
        b        = np.random.choice(len(feasible))
        temp     = feasible[a]
        feasible[a] = feasible[b]
        feasible[b] = temp
        ret = self.value.copy()
        ret[feasible] = old
        return constrainedPermutation(self.constraint,False,ret)
    
    def get_indexes(self):
        return self.value
    
    def distance_matrix(self):
        return np.array([
            [
                    np.linalg.norm(a - b)
                for b in self.value
            ]
            for a in self.value
        ])
    
    def print(self):
        print(self.value)
ret = list()
for i in range(10000):
    ret.append( constrainedPermutation(np.array([-1.,-1.,2,3,4,-1,-1,-1])).get_neighbor().value )
ret = np.array(ret)
ret.mean(axis = 0)
# Out:
# array([1.4891, 2.1188, 2.    , 3.    , 4.    , 4.4977, 5.1476, 5.7468])

# %%
def affinity(permutation, distance_matrix):
    # compute the permutation distance matrix
    d_hat = permutation.distance_matrix()
    return np.linalg.norm( d_hat - distance_matrix.argsort(axis = 1) )

# %% [markdown]
# ### Allocator class

# %%
def compute_temporary_mapping_table_and_table_inv(temps_input, temps_input_name_at_previous_block):
    temporary_mapping_table =  {}
    temporary_mapping_table_inv = {}
    for a,b in zip(temps_input,temps_input_name_at_previous_block):
        temporary_mapping_table[b] = a
        temporary_mapping_table_inv[a] = b   
    return temporary_mapping_table,temporary_mapping_table_inv

# %%
def compute_output_prev_block_register_mapping(temps_in_reg_output, regs_output):
    print("OUTPUT TEMPORARIES IN PREVIOUS LAYER IN REGISTERS")
    output_prev_block_register_mapping = {}
    print("output_{i-1}\tREG")
    for tro in np.c_[temps_in_reg_output, regs_output]:
        print("%s\t\t%s" % (tro[0],tro[1]))
        output_prev_block_register_mapping[int(tro[0])] = tro[1]
    return output_prev_block_register_mapping

# %%
def print_table(temps_in_mem_input, 
                mems_input,
                temps_in_mem_output,
                mems_output,
                temps_in_reg_input,
                regs_input,
                temps_in_reg_output,
                regs_output,
                i
               ):
                print("### [%d] INPUT TEMPS MEMORY TABLE ###" % 0)
                for r in np.c_[temps_in_mem_input, mems_input]:
                    print("%d\t%d" % (r[0],r[1]))
                print("### [%d] OUTPUT TEMPS MEMORY TABLE ###" % 0)
                for r in np.c_[temps_in_mem_output, mems_output]:
                    print("%d\t%d" % (r[0],r[1]))
                print("### [%d] INPUT TEMPS REGISTER TABLE ###" % 0)
                for r in np.c_[temps_in_reg_input, regs_input]:
                    print("%s\t%s" % (r[0],r[1]))
                print("### [%d] OUTPUT TEMPS REGISTER TABLE ###" % 0)
                for r in np.c_[temps_in_reg_output, regs_output]:
                    print("%s\t%s" % (r[0],r[1]))

# %%
from sklearn.manifold import MDS
import seaborn as sns

class Allocator:
    def __init__(self, ir, program, register_names):
        self.register_allocation_data = []  # register allocations for every matrix multiplication operation
        self.memory_allocation_data   = []  # memory allocations for every matrix multiplication operation
        self.interfaces               = {}
        self.register_names           = register_names
        self.program                  = program
        # ------------------------------
        # Register allocation subroutine
        
        # compute the usage of each temp
        temp_statistics = self.most_used_temps(ir)   # produces a list of register statistics objects
        
        # 
        self.register_allocation_and_memory_alloc_init(temp_statistics, register_names)
        self.memory_allocation(
                self.compute_signals_distance_matrix(
                    self.compute_signals(ir)
                )
        )
    ########################################################################################
    # Register allocation
    ########################################################################################
    
    def most_used_temps(self, ir):
        # IN   : takes as input an intermediate representation
        # OUT  : produces a list of TemporaryVariableStatistics objects, one for each matrix mult
        statistics_per_block = list()
        
        for ir_instruction in ir:                                                            # iterate over the IR statements
            if(ir_instruction.id == "COMMENT"):                                              # 
                if(ir_instruction.sons[0].id == "START"):
                    statistics_per_block.append(TemporaryVariablesStatistics())              # i create a temporaryvariablestatistcs
            else:
                unrolled_ir = ir_instruction.flatten()                                       # unroll the statemenet
                temps_in_statement   = list()                                                # container for temps variables in the current statement
                for u,val in zip(unrolled_ir[:-1],unrolled_ir[1:]):  
                    if u == "TEMP": 
                        temps_in_statement.append(val)                                       
                                                                                             # now "temps_in_statement" contains only the values of the temporary variables
                for t in temps_in_statement:                                                 # count the usage of each temporal 
                    statistics_per_block[-1].increment(t)                                       # the current temporary variable statistics is updated 
        return statistics_per_block
    
    def register_allocation_and_memory_alloc_init(self, statistics_list , register_names):
        # IN  : a statistics list obtained from  most_used_temps , register names
        # OUT : a registerAllocation object
        
        # convert the dictionary to an array
        temp_stats_per_block = list()
        first_block = True
        for stat in statistics_list:
            # I transform the dictitonary in a sorted-by-usage vector
            arr = stat.vectorize()
            #print(arr)
            
            # I initialize a Registerallocation  object
            reg_data = RegisterAllocationData()   
            
            # for every register i take an element, starting from the beginning, of the array
            temp_var_count = 0
            for r_id,r in enumerate(register_names):
                if temp_var_count >= len(arr):
                    break
                if first_block:     # registers are decided a priori only in the first block
                    reg_data.insert(arr[temp_var_count,0],r)                                  # i add as a used register the temporary variables with more usage
                else:
                    reg_data.insert(arr[temp_var_count,0],"register_%d" % r_id)
                temp_var_count += 1
            self.register_allocation_data.append(reg_data)                                    # i append the register allocation data obtained to the list of RAD
            
            # I also initialize the "slots" for the memory allocation data
            mem_data = MemoryAllocationData()                                                 
            for t in range(temp_var_count, len(arr)):
                mem_data.insert(arr[t,0], -1)                                                 # initializa with -1
            self.memory_allocation_data.append(mem_data)                                      # i add them to the list
            first_block = False
        
        ###for r in self.register_allocation_data:
        ###    print("+---------+")
        ###    r.print()
        
        return 0
    
    ########################################################################################
    # Memory allocation
    ########################################################################################

    def compute_signals(self, ir):
        # takes as input an intermediate repr and a register allocation output
        signals_per_block = list()
 
        curr_alloc_block = 0
    
        for ir_instruction in ir:
            if(ir_instruction.id == "COMMENT"):
                if(ir_instruction.sons[0].id == "START"):
                    curr_memory_alloc_block = self.memory_allocation_data[curr_alloc_block]
                    signals_per_block.append(BlockSignals(curr_memory_alloc_block))                       
                    curr_alloc_block += 1

            unrolled_ir = ir_instruction.flatten()
            temps_in_statement   = list()
            for u,val in zip(unrolled_ir[:-1],unrolled_ir[1:]):
                if u == "TEMP":
                    temps_in_statement.append(val)      
                    
            signals_per_block[-1].add_tick(temps_in_statement)
        return signals_per_block
    
    def compute_signals_distance_matrix(self, signals):
        # IN   : takes as input a collection of TempVarSignals
        # OUT  : produces a 
        inverse_mappings = list()
        mappings = list()          # mapping between the rows of the matrix and the temp_var
        Ds = list()                # list of matrices
        
        for signals_block in signals:
            D = np.zeros((len(signals_block.get_data()),len(signals_block.get_data())))
            mapping = {}
            inverse_mapping = {}
            for i,a in enumerate(signals_block.get_data()):
                mapping[i] = a
                inverse_mapping[a] = i
                for j,b in enumerate(signals_block.get_data()):  
                    v_a = np.arange(len(signals_block.get_data()[a]))[np.array(signals_block.get_data()[a]) == 1.]
                    v_b = np.arange(len(signals_block.get_data()[b]))[np.array(signals_block.get_data()[b]) == 1.]
                    distanza = 0.5 * (np.mean([ np.min(np.abs(s_1 - v_b)) for s_1 in v_a]) + np.mean([ np.min(np.abs(s_2 - v_a)) for s_2 in v_b]))
                    D[i,j] = distanza
            Ds.append(D)
            mappings.append(mapping)
            inverse_mappings.append(inverse_mapping)
        return Ds, mappings, inverse_mappings
    
    def anneal(self,
               unconstrainedTemps,     # temporary unconstrained
               addresses,              # list of available memory addresses
               Ds,                     # distance matrix
               inverse_mapping):       # mapping between rows of the distance matrix and temps
        ####print(inverse_mapping)
        # initialize a random association
        
        association = []
        for u,a in zip(unconstrainedTemps,addresses):
            association.append([u,a])
        association = np.array(association)
        
        # nothing to optimize actually...
        if(len(unconstrainedTemps) == 1):
            return association
        
        decay = 1e-3
        T = 10.
        T_end = 1e-3
        
        inverse_mapping_unconstrained = {}
        for i,u in enumerate(unconstrainedTemps):
            inverse_mapping_unconstrained[u] = i
        
        Ds_unconstrained = Ds[
            [ inverse_mapping[u] for u in unconstrainedTemps], :
        ][ :, [ inverse_mapping[u] for u in unconstrainedTemps]]
        
        
        def build_D_reconstructed(association):
            D_reconstructed = np.zeros(Ds_unconstrained.shape)
            for a in association:
                for b in association:
                    D_reconstructed[inverse_mapping_unconstrained[a[0]], inverse_mapping_unconstrained[b[0]]] = np.abs( a[1] - b[1] )
            return D_reconstructed
        
        def std(M):
            return (M - M.min(axis = 1)[:,None]) / (M.max(axis = 1) - M.min(axis = 1))[:,None]
        
        def cost(association):
            D_reconstructed = build_D_reconstructed(association)
            return np.linalg.norm(
                std(D_reconstructed) - std(Ds_unconstrained)
            )
        # ANNEALING
        
        anneal_iterations = (np.log(T_end) - np.log(T)) / np.log(1 - decay)
        anneal_count = 0
        while T > T_end:
            T = (1. - decay) * T

            mossa            = np.arange(len(association)).astype(int)
            # swap two random
            a = np.random.choice(len(mossa))
            b = np.random.choice(len(mossa))
            tmp = mossa[a]
            mossa[a] = mossa[b]
            mossa[b] = tmp
            new_association      = association.copy()
            new_association[:,1] = association[:,1][mossa]
            
            dE = cost(new_association) - cost(association)
            
            if dE <= 0.:
                association = new_association
            else:
                if( np.random.uniform() > np.exp( - T)):
                    association = new_association
            
            if anneal_count % int( anneal_iterations / 10 ) == 0:
                print("cost = %.2f" % cost(association))
                
            anneal_count += 1
            
        axs = plt.figure(figsize=(10,5)).subplots(1,2).flatten()
        sns.heatmap(  Ds_unconstrained, annot = True, ax = axs[0])
        sns.heatmap( build_D_reconstructed(association), annot = True, ax = axs[1] )
        
        return association
    
    
    
    def density_optimizer_memory_subset_for_output(self,
                                                   memory,
                                                   constrained, 
                                                   m_i,
                                                   unconstrained_temps_size):
        # i get the already allocated addresses
        m_i_on_constraint = [ 
                m_i.get(c)
            for c in constrained
        ]
        ###print("|unconstrained| = %d" % unconstrained_temps_size)
        ###print("constrained addresses = ", m_i_on_constraint)
        memory_mask = np.arange(len(memory))[ [ not(x in m_i_on_constraint ) for x in np.arange(len(memory))] ]
        ###print("MEMORY MASK =" , memory_mask)
        
        rows = list()
        densities = list()
        
        for j in range( len(memory) - len(m_i_on_constraint) - unconstrained_temps_size + 1):
            row = np.zeros(len(memory))
            
            for mem_add_const in m_i_on_constraint:
                row[mem_add_const] = -1.
            
            row[memory_mask[j:j+unconstrained_temps_size]] = 1.
            
            density = lambda r : (r != 0 )[ (r != 0).argmax() : (len(r) - (r != 0)[-1::-1].argmax())].mean()
            rows.append(row)
            densities.append(density(row))
            
        if(len(rows) == 1):
            return memory[rows[0] > 0.]
        else:
            densities = np.array(densities)
            rows      = np.array(rows)
            #plt.figure()
            #plt.imshow(rows)
            # choose the best
            # among the maximal densities
            ###print("@@@",rows)
            ###print("###",densities)
            ###print("***",densities == densities.max())
            available_configurations = rows[densities == densities.max()]
            # choose the one where the first unconstrained address is closer to the last constrained address
            ###print(available_configurations)
            configuration = available_configurations[0]
            for a in available_configurations:
                first_one     = configuration.argmax()
                last_minusone = len(configuration) - configuration[-1::-1].argmax() 
                distance_conf = np.abs(last_minusone - first_one)

                afirst_one     = a.argmax()
                alast_minusone = len(a) - a[-1::-1].argmax()
                adistance_conf = np.abs(alast_minusone - afirst_one)
                
                if adistance_conf < distance_conf:
                    configuration = a


            ####print("CHOSEN = ", configuration)
            ####print( m_i_on_constraint )
            ####print( memory[configuration > 0.] )
            return memory[configuration > 0.]
        

####################################################################################################################
#####                  #############################################################################################
#####   huge function  #############################################################################################
#####                  #############################################################################################
####################################################################################################################

    def memory_allocation(self, DS_MAPPINGS):
        
                   

        
        # i define a fake memory just for debug
        memory = np.arange(
            np.max(
                [
                       np.max(len(m.get_variables_list()))
                    for m in self.memory_allocation_data 
                ]
            )
        )
        
        ####print("MEMORY = ", memory)
        ####print("\nMEM ALLOC DATA [len DS = %d]\n" % len(DS_MAPPINGS[0]))
        
        # compute m1
        # every memory temp is an unconstrained temp
        print("\tMatrix Multiplication %d" % 0)
        T_mem_1       = self.memory_allocation_data[0].get_variables_list()
        mem_addresses = np.arange(0, len(T_mem_1))
        Ds_1                      = DS_MAPPINGS[0][0]
        mapping_1                 = DS_MAPPINGS[1][0]
        inverse_mapping_1         = DS_MAPPINGS[2][0]
        # optimize the                 
        if len(T_mem_1) > 0:
            print("Optimizing memory allocation of unconstrained temps...")
            temp_addr_mapping = self.anneal( T_mem_1, 
                                        mem_addresses,
                                        Ds_1,
                                        inverse_mapping_1
                                      )
            for mappa in temp_addr_mapping:
                self.memory_allocation_data[0].insert(
                    mappa[0],
                    mappa[1]
                )
        
        T                       =  np.arange( self.program.topology[0] + self.program.topology[1] )
        T_in_curr, T_out_curr   = T_in_prev , T_out_prev  =  set(T[T < self.program.topology[0]]) , set(T[T >= self.program.topology[0]])
        T_mem_curr, T_reg_curr  = T_mem_prev , T_reg_prev =  set(self.memory_allocation_data[0].get_variables_list()), set(self.register_allocation_data[0].get_variables_list())
        

        for i in range(1, len(DS_MAPPINGS[0]) ): 
            print("\n\tMatrix Multiplication %d" % i)
            ##############
            
            T                       = np.arange( self.program.topology[i] + self.program.topology[i + 1] )
            # Define the IO partition
            T_in_curr , T_out_curr  = set(T[T < self.program.topology[i]]) , set(T[T >= self.program.topology[i]])
            # Define the MR partition
            T_mem_curr , T_reg_curr = set(self.memory_allocation_data[i].get_variables_list()), set(self.register_allocation_data[i].get_variables_list())    
        
            ### Define the mappings when the input is batch
            
            # define the mapping from curr input to previous layer output
            phi_inv      = lambda t_in_curr  : set((len(T_in_prev) + np.array(list(t_in_curr))))
            # define the mapping from previous layer output to curr input
            phi          = lambda t_out_prev : set((np.array(list(t_out_prev)) - len(T_in_prev)))
            
            ### Redefine the mapping when the input is single
            # define the mapping from curr input to previous layer output
            single_phi_inv      = lambda t_in_curr  : len(T_in_prev) + t_in_curr
            # define the mapping from previous layer output to curr input
            single_phi          = lambda t_out_prev : t_out_prev - len(T_in_prev)
            
            
            # define the flows
            self.interfaces[i-1,i] = InterfaceCommunication()
           
            # FreeRegisters
            freeRegisters = set()
            for r in self.register_names:
                freeRegisters.add(r)
            ####print(freeRegisters)
            
            
            # if some output stays in registers when it becomes input we dont want to move it
            for t in T_in_curr.intersection(T_reg_curr):
                if single_phi_inv(t) in ( T_out_prev.intersection(T_reg_prev)):
                    r  = self.register_allocation_data[i - 1].get(
                                                               single_phi_inv(t)
                                                           )
                    self.register_allocation_data[i].insert(t, 
                                                            r
                                                           )
                    freeRegisters.remove(r)
                    
            # from memory to registers
            for t in T_in_curr.intersection(T_reg_curr):
                if single_phi_inv(t) in T_out_prev.intersection(T_mem_prev):
                    r = list(freeRegisters)[0]
                    self.register_allocation_data[i].insert(t, r)
                    freeRegisters.remove(r)
                    self.interfaces[i-1,i].insert(
                        MemoryToRegisterFlow(
                            self.memory_allocation_data[i - 1].get(single_phi_inv(t)),
                            r
                        )
                    )
                    
            # outputs that go into registers
            for t in T_out_curr.intersection(T_reg_curr):
                r = list(freeRegisters)[0]
                self.register_allocation_data[i].insert(t, r)
                freeRegisters.remove(r)
            
            
            # Memory
            
            UnconstrainedTemps = T_mem_curr.copy()
            ConstrainedTemps   = set()
            
            for t in T_in_curr.intersection(T_mem_curr):
                if single_phi_inv(t) in T_out_prev.intersection(T_mem_prev):
                    self.memory_allocation_data[i].insert( 
                        t , 
                        self.memory_allocation_data[i - 1].get(single_phi_inv(t))
                    )       
                    UnconstrainedTemps.remove(t)
                    ConstrainedTemps.add(t)
                    
            if len(UnconstrainedTemps) > 0:
                print("Optimizing memory allocation of unconstrained temps...")
                
                MemoryAddressImageOfMi = self.density_optimizer_memory_subset_for_output(
                    memory,                           # memory object
                    ConstrainedTemps,                 # set temporaries that are constrained
                    self.memory_allocation_data[i],   # funzione m_i
                    len(UnconstrainedTemps)           # length of the unconstrained temps to place  
                ) # returns a list of addresses that suit the unconstrained variables

                
                Ds              = DS_MAPPINGS[0][i]
                mapping         = DS_MAPPINGS[1][i]
                inverse_mapping = DS_MAPPINGS[2][i]
                
            
                temp_addr_mapping = self.anneal(    UnconstrainedTemps, 
                                                    MemoryAddressImageOfMi,
                                                    Ds,
                                                    inverse_mapping
                                                  )
                for a in temp_addr_mapping:
                    self.memory_allocation_data[i].insert(a[0],a[1])
            
            
            for t in T_in_curr.intersection(T_mem_curr):
                if single_phi_inv(t) in T_out_prev.intersection(T_reg_prev):
                    self.interfaces[i-1,i].insert(
                        RegisterToMemoryFlow(
                            self.register_allocation_data[i-1].get(
                                single_phi_inv(t)
                            ),
                            self.memory_allocation_data[i].get(t)
                        )
                    )
            
            
            # save the previous partitions
            T_in_prev , T_out_prev   = T_in_curr  , T_out_curr  
            T_mem_prev , T_reg_prev  = T_mem_curr , T_reg_curr  
            
            
            ## DEBUG REGISTER ALLOC DATA
            #print("$$$ REG %d" % i)
            #for R in self.register_allocation_data:
            #    print("----")
            #    R.print()
            #    print("-----")
            #print("$$$ MEM %d" % i)
            #for M in self.memory_allocation_data:
            #    print("----")
            #    M.print()
            #    print("-----")
            #print("$$$ INTERFACE %d" % i )
            #self.interfaces[i-1,i].print()
    
#compiler(0, ['a','b','c','d','e','f']) # QUESTA ROBA NON FUNZIONA TOGLIERE E' SOLO PER FARE DEBUG ORA

# %%
set(1 + np.array(list({1,2,3})))
# Out:
# {2, 3, 4}

# %% [markdown]
# ## Code generator

# %% [markdown]
# ## Assembler

# %% [markdown]
# ## Orchestrator function

# %%
def compiler(file_name, registers, sparsify = False):
    
    reg_0 = registers[0]
    reg_1 = registers[1]
    
    # debug, we don't actually read a file but we generate it randomly
    rete = Program([1,20,20,5], ["RELU","RELU","LINEAR"])
    rete.random_init_weights()
    intermediate_representation = IR(rete)
    for i in intermediate_representation:
        print(i.flatten())
    
    allocator = Allocator(intermediate_representation , rete , registers[3:])
    asm_code = []

    print("\n" * 10)
    print("##### GENERATED ASSEMBLER #####")
    print("\n" * 10)
    
    zero_register     = registers[0]
    buffer_register_1 = registers[1]
    buffer_register_2 = registers[2]
    print("MOV r7,0x0 \t ; # address offset")
    print("VSUB.F32 %s,%s,%s \t ; # initalize the zero register"
         % (
             zero_register,
             zero_register,
             zero_register
         )
         )
    
    #for m in allocator.memory_allocation_data:
    #    m.print()
    #    print("----")
    
    cursor_allocator = 0
    label_counter = 0
    
    for ir_statement in intermediate_representation:
        flattened = ir_statement.flatten()
        #print(flattened)
        if(flattened[0] == "COMMENT"):
            if(flattened[1] == "END"):
                #print("\n # NUOVO BLOCCO \n")
                print("######################################## HERE GOES THE INTERFACE")
                cursor_allocator += 1
        
        if(flattened[0] == "MOVE" 
           and 
           flattened[3] == "CONST"
          ): # set the temporary variable
            tmp_name =  flattened[2]
            val       = flattened[4]
            # we have to understand if tmp_name is a register or not
            if(allocator.register_allocation_data[cursor_allocator].contains(tmp_name)):
                # variable is in registers
                register = allocator.register_allocation_data[cursor_allocator].get_data()[tmp_name]
                #print("MOV TO $%s THE VALUE #%f" % (
                #      register,
                #      val)
                #     )
                print("VMOV.F32 %s, %s\t ; # set the register to 0 " % (register,zero_register))
            else:
                # variable is in memory
                address = allocator.memory_allocation_data[cursor_allocator].get_data()[tmp_name]
                #print("STORE THE VALUE 0 IN ADDRESS %d" % address)
                print("FSTS %s, [r7,#%d]" % (zero_register,address) )
                
                
        if(flattened[0] == "MOVE"
           and
           flattened[3] == "BINOP"
           and 
           len(flattened ) == 13
          ): # addition and multiply
            neuron_dest   = flattened[2]
            neuron_source = flattened[12]
            weight        = flattened[10]
            
            
            if(allocator.register_allocation_data[cursor_allocator].contains(neuron_source)):
                register = allocator.register_allocation_data[cursor_allocator].get_data()[neuron_source]
                weight_bytes = struct.pack('f', weight)
                weight_bytes_upper = struct.unpack('H',weight_bytes[:2])
                weight_bytes_lower = struct.unpack('H',weight_bytes[2:])
                
                print("MOVW r3,#%d \t ; # move the most significative bits in r3" % weight_bytes_upper[0])
                print("MOVT r3,#%d \t ; # move the least significative bits in r3" % weight_bytes_lower[0])
                print("VMOV.F32 %s,r3 \t ; # copy r3 in buffer_register_1" % (buffer_register_1))
                print("VMUL.F32 %s,%s,%s \t ; # save in buffer_register_2 the multiplication " % (
                        buffer_register_2,
                        buffer_register_1,
                        register
                ))
                #print("MULT $%s BY #%f AND SAVE IT IN $%s" % (
                #      allocator.register_allocation_data[cursor_allocator].get_data()[neuron_source],
                #      weight,
                #      reg_0)
                #     )
            else:
                # variable is in memory
                address = allocator.memory_allocation_data[cursor_allocator].get_data()[neuron_source]
                print("FLDS %s,[r7, #%d] \t ; # copy the value in the address on the buffer_register_2" % (buffer_register_2, address))
                print("MOVW r3,#%d \t ; # move the most significative bits in r3" % weight_bytes_upper[0])
                print("MOVT r3,#%d \t ; # move the least significative bits in r3" % weight_bytes_lower[0])
                print("VMOV.F32 %s,r3 \t ; # copy r3 in buffer_register_1" % (buffer_register_1))
                print("VMUL.F32 %s,%s,%s \t ; # save in buffer_register_2 the multiplication " % (
                        buffer_register_2,
                        buffer_register_1,
                        buffer_register_2
                ))    
                #print("LOAD IN REGISTER $%s THE ADDRESS %d"  % (
                #            reg_0,
                #            allocator.memory_allocation_data[cursor_allocator].get_data()[neuron_source])
                #     )
                #print("MULT $%s BY #%f AND SAVE IT IN $%s" % (
                #      reg_0,
                #      weight,
                #      reg_0
                #      )
                 #    )
                    
            # NOW BUFFER_REGISTER_2 CONTAINS weight * input
        
            if(allocator.register_allocation_data[cursor_allocator].contains(neuron_dest)):
                #print("ADD $%s to $%s" % (
                #      reg_0,
                #      allocator.register_allocation_data[cursor_allocator].get_data()[neuron_dest])
                #     )
                
                # dest += weight * input
                print("VADD.F32 %s,%s,%s \t ; # " %( 
                    allocator.register_allocation_data[cursor_allocator].get_data()[neuron_dest],
                    buffer_register_2,
                    allocator.register_allocation_data[cursor_allocator].get_data()[neuron_dest]))
                
            else:
                # variable is in memory
                address = allocator.memory_allocation_data[cursor_allocator].get_data()[neuron_dest]
                #print("LOAD IN REGISTER $ %s THE ADDRESS %d" % (reg_1,address) )               
                print("FLDS %s,[r7, #%d] \t ; # load the content of the output neuron in buffer_register_1 " % (buffer_register_1, address))
                print("VADD.F32 %s,%s,%s \t ; # buffer_register_1 += weight * input"  % (buffer_register_1, buffer_register_2, buffer_register_1))
                print("FSTF %s,[r7, #%d] " % (buffer_register_1, address))
                
        if(flattened[0] == "MOVE"
           and
           flattened[1] == "CALL"
          ): # adding the bias and applying the activation function
            
            tmp_name = flattened[4]  # name of the temporary variable
            f_name   = flattened[2]  # name of the activation function
            bias     = flattened[-1] # bias
            
            if(allocator.register_allocation_data[cursor_allocator].contains(tmp_name)):
                # the variable is in a register
                register = allocator.register_allocation_data[cursor_allocator].get_data()[tmp_name]
                #print("ADD TO $%s VALUE #%f " %
                #             (
                #                 register,
                #                 bias
                #             )
                #         )              
                
                register = allocator.register_allocation_data[cursor_allocator].get_data()[tmp_name]
                bias_bytes = struct.pack('f', bias)
                bias_bytes_upper = struct.unpack('H',bias_bytes[:2])
                bias_bytes_lower = struct.unpack('H',bias_bytes[2:])
                
                print("MOVW r3,#%d \t ; # move the most significative bits in r3" % bias_bytes_upper[0])
                print("MOVT r3,#%d \t ; # move the least significative bits in r3" % bias_bytes_lower[0])
                print("VMOV.F32 %s,r3 \t ; # copy r3 in buffer_register_1" % (buffer_register_1))
                print("VADD.F32 %s,%s,%s \t ; # add the bias" % (
                        register,
                        buffer_register_1,
                        register
                ))
                
                
                if f_name == 'RELU':
                    #the function is RELU
                    #print("GTZ $%s TO $%s" %   # if greater than 0 save 1 in $0 else 0 in $0
                    #         (
                    #             register,
                    #             reg_0
                    #         )
                    #     )
                    #print("MULT $%s, $%s, $%s" %
                    #         (
                    #             register,
                    #             reg_0,
                    #             register
                    #         )
                    #     )
                    print("# RELU")
                    print("vcmpe.f32  %s, #0 ; \t # compare the register with 0  " % (register))
                    print("vmrs    APSR_nzcv, FPSCR ")
                    print("bgt     .L%d ; \t # jump to the next label if the value is >= 0" % (label_counter) )
                    print("vmov.f32 %s,%s  ; \t # put the value to 0 if less than 0" % (register,zero_register))
                    print(".L%d: " % (label_counter))
                    label_counter += 1
                    
                if f_name == 'LINEAR':
                    #the function is Linear activation  function
                    0 # do nothing 
            else:
                # the variable is in memory
                address = allocator.memory_allocation_data[cursor_allocator].get_data()[tmp_name]
                #print("LOAD ADDRESS #%d INTO REGISTER $%s " %
                # (
                #     address,
                #     reg_1
                # )
                #)
                print("FLDS %s,[r7, #%d] \t ; # load the content of the output neuron in buffer_register_2 " % (buffer_register_2, address))
                print("MOVW r3,#%d \t ; # move the most significative bits in r3" % bias_bytes_upper[0])
                print("MOVT r3,#%d \t ; # move the least significative bits in r3" % bias_bytes_lower[0])
                print("VMOV.F32 %s,r3 \t ; # copy r3 in buffer_register_1" % (buffer_register_1))
                print("VADD.F32 %s,%s,%s \t ; # add the bias" % (
                        buffer_register_2,
                        buffer_register_1,
                        buffer_register_2
                ))
                
                #print("ADDI $%s,$%s,#%f" %
                #      (
                #          reg_1,
                #          reg_1,
                #          bias
                #      ))
                if f_name == 'RELU':
                    #the function is RELU
                    #print("GTZ $%s TO $%s" %   # if greater than 0 save 1 in $0 else 0 in $0
                    #         (
                    #             reg_1,
                    #             reg_0
                    #         )
                    #     )
                    #print("MULT $%s, $%s, $%s" %
                    #         (
                    #             reg_1,
                    #             reg_0,
                    #             reg_1
                    #         )
                    #     )
                    print("# RELU")
                    print("vcmpe.f32  %s, #0 ; \t # compare the register with 0  " % (buffer_register_2))
                    print("vmrs    APSR_nzcv, FPSCR ")
                    print("bgt     .L%d ; \t # jump to the next label if the value is >= 0" % (label_counter) )
                    print("vmov.f32 %s,%s  ; \t # put the value to 0 if less than 0" % (buffer_register_2,zero_register))
                    print(".L%d: " % (label_counter))
                    label_counter += 1
                    
                if f_name == 'LINEAR':
                    #the function is Linear activation  function
                    0
                
                #print("STORE  $%s  INTO ADDRESS #%d" %
                # (
                #     reg_1,
                #     address
                # )
                #)
                print("FSTF %s,[r7, #%d] " % (buffer_register_2, address))
                
compiler(0, [ 's' + str(i) for i in range(16)])
# Out:
# ['COMMENT', 'START']
# ['MOVE', 'TEMP', 1, 'CONST', 0]
# ['MOVE', 'TEMP', 2, 'CONST', 0]
# ['MOVE', 'TEMP', 3, 'CONST', 0]
# ['MOVE', 'TEMP', 4, 'CONST', 0]
# ['MOVE', 'TEMP', 5, 'CONST', 0]
# ['MOVE', 'TEMP', 6, 'CONST', 0]
# ['MOVE', 'TEMP', 7, 'CONST', 0]
# ['MOVE', 'TEMP', 8, 'CONST', 0]
# ['MOVE', 'TEMP', 9, 'CONST', 0]
# ['MOVE', 'TEMP', 10, 'CONST', 0]
# ['MOVE', 'TEMP', 11, 'CONST', 0]
# ['MOVE', 'TEMP', 12, 'CONST', 0]
# ['MOVE', 'TEMP', 13, 'CONST', 0]
# ['MOVE', 'TEMP', 14, 'CONST', 0]
# ['MOVE', 'TEMP', 15, 'CONST', 0]
# ['MOVE', 'TEMP', 16, 'CONST', 0]
# ['MOVE', 'TEMP', 17, 'CONST', 0]
# ['MOVE', 'TEMP', 18, 'CONST', 0]
# ['MOVE', 'TEMP', 19, 'CONST', 0]
# ['MOVE', 'TEMP', 20, 'CONST', 0]
# ['MOVE', 'TEMP', 1, 'BINOP', 'ADD', 'TEMP', 1, 'BINOP', 'MUL', 'CONST', 0.4635085759452793, 'TEMP', 0]
# ['MOVE', 'TEMP', 2, 'BINOP', 'ADD', 'TEMP', 2, 'BINOP', 'MUL', 'CONST', 1.5734235538328702, 'TEMP', 0]
# ['MOVE', 'TEMP', 4, 'BINOP', 'ADD', 'TEMP', 4, 'BINOP', 'MUL', 'CONST', 0.009097325011263898, 'TEMP', 0]
# ['MOVE', 'TEMP', 5, 'BINOP', 'ADD', 'TEMP', 5, 'BINOP', 'MUL', 'CONST', 0.09429349322271444, 'TEMP', 0]
# ['MOVE', 'TEMP', 6, 'BINOP', 'ADD', 'TEMP', 6, 'BINOP', 'MUL', 'CONST', 0.016786144763525634, 'TEMP', 0]
# ['MOVE', 'TEMP', 7, 'BINOP', 'ADD', 'TEMP', 7, 'BINOP', 'MUL', 'CONST', 0.06920938636388282, 'TEMP', 0]
# ['MOVE', 'TEMP', 8, 'BINOP', 'ADD', 'TEMP', 8, 'BINOP', 'MUL', 'CONST', 3.8237431306249015, 'TEMP', 0]
# ['MOVE', 'TEMP', 11, 'BINOP', 'ADD', 'TEMP', 11, 'BINOP', 'MUL', 'CONST', 0.007995453105650372, 'TEMP', 0]
# ['MOVE', 'TEMP', 15, 'BINOP', 'ADD', 'TEMP', 15, 'BINOP', 'MUL', 'CONST', 0.5499946818710428, 'TEMP', 0]
# ['MOVE', 'TEMP', 18, 'BINOP', 'ADD', 'TEMP', 18, 'BINOP', 'MUL', 'CONST', 0.31067982373606073, 'TEMP', 0]
# ['MOVE', 'TEMP', 19, 'BINOP', 'ADD', 'TEMP', 19, 'BINOP', 'MUL', 'CONST', 0.029301930997409666, 'TEMP', 0]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 1, 'BINOP', 'ADD', 'TEMP', 1, 'CONST', -0.6414908544025055]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 2, 'BINOP', 'ADD', 'TEMP', 2, 'CONST', 0.21203061668651904]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 3, 'BINOP', 'ADD', 'TEMP', 3, 'CONST', -1.0247865900478577]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 4, 'BINOP', 'ADD', 'TEMP', 4, 'CONST', 0.053431709209537756]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 5, 'BINOP', 'ADD', 'TEMP', 5, 'CONST', 1.4829640947702722]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 6, 'BINOP', 'ADD', 'TEMP', 6, 'CONST', 0.42079253293333685]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 7, 'BINOP', 'ADD', 'TEMP', 7, 'CONST', -2.718972838414689]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 8, 'BINOP', 'ADD', 'TEMP', 8, 'CONST', 1.6238811921879042]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 9, 'BINOP', 'ADD', 'TEMP', 9, 'CONST', 0.556087701783426]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 10, 'BINOP', 'ADD', 'TEMP', 10, 'CONST', -0.3085012225345597]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 11, 'BINOP', 'ADD', 'TEMP', 11, 'CONST', 0.08230302330893718]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 12, 'BINOP', 'ADD', 'TEMP', 12, 'CONST', -0.09963878433330173]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 13, 'BINOP', 'ADD', 'TEMP', 13, 'CONST', 0.492726510893871]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 14, 'BINOP', 'ADD', 'TEMP', 14, 'CONST', -1.1957952969760441]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 15, 'BINOP', 'ADD', 'TEMP', 15, 'CONST', 0.35851145766323517]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 16, 'BINOP', 'ADD', 'TEMP', 16, 'CONST', 0.5301004859500159]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 17, 'BINOP', 'ADD', 'TEMP', 17, 'CONST', -1.6775094843734386]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 18, 'BINOP', 'ADD', 'TEMP', 18, 'CONST', 0.9738538233223171]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 19, 'BINOP', 'ADD', 'TEMP', 19, 'CONST', 0.714510751194304]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'CONST', 0.9376412526727118]
# ['COMMENT', 'END']
# ['COMMENT', 'START']
# ['MOVE', 'TEMP', 20, 'CONST', 0]
# ['MOVE', 'TEMP', 21, 'CONST', 0]
# ['MOVE', 'TEMP', 22, 'CONST', 0]
# ['MOVE', 'TEMP', 23, 'CONST', 0]
# ['MOVE', 'TEMP', 24, 'CONST', 0]
# ['MOVE', 'TEMP', 25, 'CONST', 0]
# ['MOVE', 'TEMP', 26, 'CONST', 0]
# ['MOVE', 'TEMP', 27, 'CONST', 0]
# ['MOVE', 'TEMP', 28, 'CONST', 0]
# ['MOVE', 'TEMP', 29, 'CONST', 0]
# ['MOVE', 'TEMP', 30, 'CONST', 0]
# ['MOVE', 'TEMP', 31, 'CONST', 0]
# ['MOVE', 'TEMP', 32, 'CONST', 0]
# ['MOVE', 'TEMP', 33, 'CONST', 0]
# ['MOVE', 'TEMP', 34, 'CONST', 0]
# ['MOVE', 'TEMP', 35, 'CONST', 0]
# ['MOVE', 'TEMP', 36, 'CONST', 0]
# ['MOVE', 'TEMP', 37, 'CONST', 0]
# ['MOVE', 'TEMP', 38, 'CONST', 0]
# ['MOVE', 'TEMP', 39, 'CONST', 0]
# ['MOVE', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'BINOP', 'MUL', 'CONST', 0.0032242929786200376, 'TEMP', 1]
# ['MOVE', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'BINOP', 'MUL', 'CONST', 5.721420296665363, 'TEMP', 3]
# ['MOVE', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'BINOP', 'MUL', 'CONST', 3.8633562464384976, 'TEMP', 6]
# ['MOVE', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'BINOP', 'MUL', 'CONST', 0.43316720211640936, 'TEMP', 8]
# ['MOVE', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'BINOP', 'MUL', 'CONST', 0.07555688058108918, 'TEMP', 9]
# ['MOVE', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'BINOP', 'MUL', 'CONST', 0.4280736698201264, 'TEMP', 12]
# ['MOVE', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'BINOP', 'MUL', 'CONST', 0.1956875599545072, 'TEMP', 16]
# ['MOVE', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'BINOP', 'MUL', 'CONST', 0.04558128802400243, 'TEMP', 17]
# ['MOVE', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'BINOP', 'MUL', 'CONST', 0.28561464927770336, 'TEMP', 18]
# ['MOVE', 'TEMP', 21, 'BINOP', 'ADD', 'TEMP', 21, 'BINOP', 'MUL', 'CONST', 0.0022916688209134372, 'TEMP', 3]
# ['MOVE', 'TEMP', 21, 'BINOP', 'ADD', 'TEMP', 21, 'BINOP', 'MUL', 'CONST', 0.0816582054528264, 'TEMP', 4]
# ['MOVE', 'TEMP', 21, 'BINOP', 'ADD', 'TEMP', 21, 'BINOP', 'MUL', 'CONST', 3.4330657904919133, 'TEMP', 5]
# ['MOVE', 'TEMP', 21, 'BINOP', 'ADD', 'TEMP', 21, 'BINOP', 'MUL', 'CONST', 4.142423077293671, 'TEMP', 7]
# ['MOVE', 'TEMP', 21, 'BINOP', 'ADD', 'TEMP', 21, 'BINOP', 'MUL', 'CONST', 2.25218023795578, 'TEMP', 9]
# ['MOVE', 'TEMP', 21, 'BINOP', 'ADD', 'TEMP', 21, 'BINOP', 'MUL', 'CONST', 1.1201188799217772, 'TEMP', 10]
# ['MOVE', 'TEMP', 21, 'BINOP', 'ADD', 'TEMP', 21, 'BINOP', 'MUL', 'CONST', 1.4744621642242748, 'TEMP', 11]
# ['MOVE', 'TEMP', 21, 'BINOP', 'ADD', 'TEMP', 21, 'BINOP', 'MUL', 'CONST', 1.1336710627800126, 'TEMP', 15]
# ['MOVE', 'TEMP', 21, 'BINOP', 'ADD', 'TEMP', 21, 'BINOP', 'MUL', 'CONST', 0.13800581122423813, 'TEMP', 16]
# ['MOVE', 'TEMP', 21, 'BINOP', 'ADD', 'TEMP', 21, 'BINOP', 'MUL', 'CONST', 0.8865538588882663, 'TEMP', 17]
# ['MOVE', 'TEMP', 22, 'BINOP', 'ADD', 'TEMP', 22, 'BINOP', 'MUL', 'CONST', 2.7283621930052746, 'TEMP', 1]
# ['MOVE', 'TEMP', 22, 'BINOP', 'ADD', 'TEMP', 22, 'BINOP', 'MUL', 'CONST', 0.00023214284524945998, 'TEMP', 2]
# ['MOVE', 'TEMP', 22, 'BINOP', 'ADD', 'TEMP', 22, 'BINOP', 'MUL', 'CONST', 0.7023510025228984, 'TEMP', 3]
# ['MOVE', 'TEMP', 22, 'BINOP', 'ADD', 'TEMP', 22, 'BINOP', 'MUL', 'CONST', 3.370497427572949, 'TEMP', 4]
# ['MOVE', 'TEMP', 22, 'BINOP', 'ADD', 'TEMP', 22, 'BINOP', 'MUL', 'CONST', 0.040994987672305, 'TEMP', 12]
# ['MOVE', 'TEMP', 22, 'BINOP', 'ADD', 'TEMP', 22, 'BINOP', 'MUL', 'CONST', 0.5637558282528649, 'TEMP', 17]
# ['MOVE', 'TEMP', 22, 'BINOP', 'ADD', 'TEMP', 22, 'BINOP', 'MUL', 'CONST', 0.26321051511463855, 'TEMP', 18]
# ['MOVE', 'TEMP', 22, 'BINOP', 'ADD', 'TEMP', 22, 'BINOP', 'MUL', 'CONST', 0.7015541000655421, 'TEMP', 19]
# ['MOVE', 'TEMP', 23, 'BINOP', 'ADD', 'TEMP', 23, 'BINOP', 'MUL', 'CONST', 0.2415799518032806, 'TEMP', 3]
# ['MOVE', 'TEMP', 23, 'BINOP', 'ADD', 'TEMP', 23, 'BINOP', 'MUL', 'CONST', 0.5235782741225502, 'TEMP', 6]
# ['MOVE', 'TEMP', 23, 'BINOP', 'ADD', 'TEMP', 23, 'BINOP', 'MUL', 'CONST', 1.5388684813742401, 'TEMP', 7]
# ['MOVE', 'TEMP', 23, 'BINOP', 'ADD', 'TEMP', 23, 'BINOP', 'MUL', 'CONST', 4.261181080790247, 'TEMP', 8]
# ['MOVE', 'TEMP', 23, 'BINOP', 'ADD', 'TEMP', 23, 'BINOP', 'MUL', 'CONST', 0.09361441668561236, 'TEMP', 9]
# ['MOVE', 'TEMP', 23, 'BINOP', 'ADD', 'TEMP', 23, 'BINOP', 'MUL', 'CONST', 0.2595734886831769, 'TEMP', 16]
# ['MOVE', 'TEMP', 24, 'BINOP', 'ADD', 'TEMP', 24, 'BINOP', 'MUL', 'CONST', 0.09403427282648436, 'TEMP', 0]
# ['MOVE', 'TEMP', 24, 'BINOP', 'ADD', 'TEMP', 24, 'BINOP', 'MUL', 'CONST', 0.057097193637477214, 'TEMP', 3]
# ['MOVE', 'TEMP', 24, 'BINOP', 'ADD', 'TEMP', 24, 'BINOP', 'MUL', 'CONST', 0.00019997173926046018, 'TEMP', 4]
# ['MOVE', 'TEMP', 24, 'BINOP', 'ADD', 'TEMP', 24, 'BINOP', 'MUL', 'CONST', 0.7883488904664679, 'TEMP', 6]
# ['MOVE', 'TEMP', 24, 'BINOP', 'ADD', 'TEMP', 24, 'BINOP', 'MUL', 'CONST', 0.01791137990005096, 'TEMP', 8]
# ['MOVE', 'TEMP', 24, 'BINOP', 'ADD', 'TEMP', 24, 'BINOP', 'MUL', 'CONST', 6.16373806103516, 'TEMP', 18]
# ['MOVE', 'TEMP', 25, 'BINOP', 'ADD', 'TEMP', 25, 'BINOP', 'MUL', 'CONST', 3.841004380632072, 'TEMP', 0]
# ['MOVE', 'TEMP', 25, 'BINOP', 'ADD', 'TEMP', 25, 'BINOP', 'MUL', 'CONST', 6.411211378299519, 'TEMP', 2]
# ['MOVE', 'TEMP', 25, 'BINOP', 'ADD', 'TEMP', 25, 'BINOP', 'MUL', 'CONST', 1.7877987384922427, 'TEMP', 3]
# ['MOVE', 'TEMP', 25, 'BINOP', 'ADD', 'TEMP', 25, 'BINOP', 'MUL', 'CONST', 0.13846609814733024, 'TEMP', 5]
# ['MOVE', 'TEMP', 25, 'BINOP', 'ADD', 'TEMP', 25, 'BINOP', 'MUL', 'CONST', 0.8817228538059649, 'TEMP', 7]
# ['MOVE', 'TEMP', 25, 'BINOP', 'ADD', 'TEMP', 25, 'BINOP', 'MUL', 'CONST', 0.6284016159796881, 'TEMP', 8]
# ['MOVE', 'TEMP', 25, 'BINOP', 'ADD', 'TEMP', 25, 'BINOP', 'MUL', 'CONST', 1.119758633460383, 'TEMP', 11]
# ['MOVE', 'TEMP', 25, 'BINOP', 'ADD', 'TEMP', 25, 'BINOP', 'MUL', 'CONST', 1.4914726907940459, 'TEMP', 13]
# ['MOVE', 'TEMP', 25, 'BINOP', 'ADD', 'TEMP', 25, 'BINOP', 'MUL', 'CONST', 0.662922311969767, 'TEMP', 16]
# ['MOVE', 'TEMP', 26, 'BINOP', 'ADD', 'TEMP', 26, 'BINOP', 'MUL', 'CONST', 0.03961279090294068, 'TEMP', 2]
# ['MOVE', 'TEMP', 26, 'BINOP', 'ADD', 'TEMP', 26, 'BINOP', 'MUL', 'CONST', 5.424566548499625, 'TEMP', 5]
# ['MOVE', 'TEMP', 26, 'BINOP', 'ADD', 'TEMP', 26, 'BINOP', 'MUL', 'CONST', 0.46761443849015316, 'TEMP', 10]
# ['MOVE', 'TEMP', 26, 'BINOP', 'ADD', 'TEMP', 26, 'BINOP', 'MUL', 'CONST', 6.960649480988444, 'TEMP', 12]
# ['MOVE', 'TEMP', 26, 'BINOP', 'ADD', 'TEMP', 26, 'BINOP', 'MUL', 'CONST', 0.9816464417318784, 'TEMP', 13]
# ['MOVE', 'TEMP', 26, 'BINOP', 'ADD', 'TEMP', 26, 'BINOP', 'MUL', 'CONST', 0.18027108574914083, 'TEMP', 18]
# ['MOVE', 'TEMP', 27, 'BINOP', 'ADD', 'TEMP', 27, 'BINOP', 'MUL', 'CONST', 0.0014993754936268482, 'TEMP', 0]
# ['MOVE', 'TEMP', 27, 'BINOP', 'ADD', 'TEMP', 27, 'BINOP', 'MUL', 'CONST', 1.0196192774610449, 'TEMP', 1]
# ['MOVE', 'TEMP', 27, 'BINOP', 'ADD', 'TEMP', 27, 'BINOP', 'MUL', 'CONST', 0.30289616634876665, 'TEMP', 7]
# ['MOVE', 'TEMP', 27, 'BINOP', 'ADD', 'TEMP', 27, 'BINOP', 'MUL', 'CONST', 4.399009270009195, 'TEMP', 9]
# ['MOVE', 'TEMP', 27, 'BINOP', 'ADD', 'TEMP', 27, 'BINOP', 'MUL', 'CONST', 1.068533000342279, 'TEMP', 10]
# ['MOVE', 'TEMP', 27, 'BINOP', 'ADD', 'TEMP', 27, 'BINOP', 'MUL', 'CONST', 2.6001112991697064, 'TEMP', 13]
# ['MOVE', 'TEMP', 28, 'BINOP', 'ADD', 'TEMP', 28, 'BINOP', 'MUL', 'CONST', 0.41486933998115605, 'TEMP', 6]
# ['MOVE', 'TEMP', 28, 'BINOP', 'ADD', 'TEMP', 28, 'BINOP', 'MUL', 'CONST', 0.7531937334430342, 'TEMP', 7]
# ['MOVE', 'TEMP', 28, 'BINOP', 'ADD', 'TEMP', 28, 'BINOP', 'MUL', 'CONST', 0.20682194593392444, 'TEMP', 8]
# ['MOVE', 'TEMP', 28, 'BINOP', 'ADD', 'TEMP', 28, 'BINOP', 'MUL', 'CONST', 0.3399962997551521, 'TEMP', 9]
# ['MOVE', 'TEMP', 28, 'BINOP', 'ADD', 'TEMP', 28, 'BINOP', 'MUL', 'CONST', 1.411133774510724, 'TEMP', 12]
# ['MOVE', 'TEMP', 28, 'BINOP', 'ADD', 'TEMP', 28, 'BINOP', 'MUL', 'CONST', 0.8468071683027354, 'TEMP', 13]
# ['MOVE', 'TEMP', 28, 'BINOP', 'ADD', 'TEMP', 28, 'BINOP', 'MUL', 'CONST', 1.317315121341333, 'TEMP', 19]
# ['MOVE', 'TEMP', 29, 'BINOP', 'ADD', 'TEMP', 29, 'BINOP', 'MUL', 'CONST', 1.1903294638851796, 'TEMP', 1]
# ['MOVE', 'TEMP', 29, 'BINOP', 'ADD', 'TEMP', 29, 'BINOP', 'MUL', 'CONST', 0.08606939131274763, 'TEMP', 2]
# ['MOVE', 'TEMP', 29, 'BINOP', 'ADD', 'TEMP', 29, 'BINOP', 'MUL', 'CONST', 0.09029850059013607, 'TEMP', 5]
# ['MOVE', 'TEMP', 29, 'BINOP', 'ADD', 'TEMP', 29, 'BINOP', 'MUL', 'CONST', 2.3300296314922213, 'TEMP', 7]
# ['MOVE', 'TEMP', 29, 'BINOP', 'ADD', 'TEMP', 29, 'BINOP', 'MUL', 'CONST', 0.6390893195632525, 'TEMP', 8]
# ['MOVE', 'TEMP', 29, 'BINOP', 'ADD', 'TEMP', 29, 'BINOP', 'MUL', 'CONST', 0.43144565865232987, 'TEMP', 10]
# ['MOVE', 'TEMP', 29, 'BINOP', 'ADD', 'TEMP', 29, 'BINOP', 'MUL', 'CONST', 2.0156431924166682, 'TEMP', 11]
# ['MOVE', 'TEMP', 29, 'BINOP', 'ADD', 'TEMP', 29, 'BINOP', 'MUL', 'CONST', 0.09735584044264188, 'TEMP', 12]
# ['MOVE', 'TEMP', 29, 'BINOP', 'ADD', 'TEMP', 29, 'BINOP', 'MUL', 'CONST', 1.4049896247429914, 'TEMP', 14]
# ['MOVE', 'TEMP', 29, 'BINOP', 'ADD', 'TEMP', 29, 'BINOP', 'MUL', 'CONST', 0.08809632132217504, 'TEMP', 15]
# ['MOVE', 'TEMP', 30, 'BINOP', 'ADD', 'TEMP', 30, 'BINOP', 'MUL', 'CONST', 0.037345500896519675, 'TEMP', 2]
# ['MOVE', 'TEMP', 30, 'BINOP', 'ADD', 'TEMP', 30, 'BINOP', 'MUL', 'CONST', 0.04229664191934677, 'TEMP', 3]
# ['MOVE', 'TEMP', 30, 'BINOP', 'ADD', 'TEMP', 30, 'BINOP', 'MUL', 'CONST', 0.006730542882007657, 'TEMP', 7]
# ['MOVE', 'TEMP', 30, 'BINOP', 'ADD', 'TEMP', 30, 'BINOP', 'MUL', 'CONST', 0.22796414083091956, 'TEMP', 9]
# ['MOVE', 'TEMP', 30, 'BINOP', 'ADD', 'TEMP', 30, 'BINOP', 'MUL', 'CONST', 0.006366549599429054, 'TEMP', 11]
# ['MOVE', 'TEMP', 30, 'BINOP', 'ADD', 'TEMP', 30, 'BINOP', 'MUL', 'CONST', 0.36423245049874137, 'TEMP', 13]
# ['MOVE', 'TEMP', 30, 'BINOP', 'ADD', 'TEMP', 30, 'BINOP', 'MUL', 'CONST', 1.9894244174770943, 'TEMP', 15]
# ['MOVE', 'TEMP', 30, 'BINOP', 'ADD', 'TEMP', 30, 'BINOP', 'MUL', 'CONST', 0.2834546738655142, 'TEMP', 18]
# ['MOVE', 'TEMP', 31, 'BINOP', 'ADD', 'TEMP', 31, 'BINOP', 'MUL', 'CONST', 3.552412005020745, 'TEMP', 1]
# ['MOVE', 'TEMP', 31, 'BINOP', 'ADD', 'TEMP', 31, 'BINOP', 'MUL', 'CONST', 0.15606707604533676, 'TEMP', 4]
# ['MOVE', 'TEMP', 31, 'BINOP', 'ADD', 'TEMP', 31, 'BINOP', 'MUL', 'CONST', 0.041675925492372354, 'TEMP', 7]
# ['MOVE', 'TEMP', 31, 'BINOP', 'ADD', 'TEMP', 31, 'BINOP', 'MUL', 'CONST', 4.768358347650237e-05, 'TEMP', 9]
# ['MOVE', 'TEMP', 31, 'BINOP', 'ADD', 'TEMP', 31, 'BINOP', 'MUL', 'CONST', 1.152688561883815, 'TEMP', 14]
# ['MOVE', 'TEMP', 31, 'BINOP', 'ADD', 'TEMP', 31, 'BINOP', 'MUL', 'CONST', 0.14647311239013766, 'TEMP', 18]
# ['MOVE', 'TEMP', 32, 'BINOP', 'ADD', 'TEMP', 32, 'BINOP', 'MUL', 'CONST', 0.24864221937027212, 'TEMP', 1]
# ['MOVE', 'TEMP', 32, 'BINOP', 'ADD', 'TEMP', 32, 'BINOP', 'MUL', 'CONST', 0.04713531573976172, 'TEMP', 3]
# ['MOVE', 'TEMP', 32, 'BINOP', 'ADD', 'TEMP', 32, 'BINOP', 'MUL', 'CONST', 1.0194729745281108, 'TEMP', 9]
# ['MOVE', 'TEMP', 32, 'BINOP', 'ADD', 'TEMP', 32, 'BINOP', 'MUL', 'CONST', 0.4472063031009405, 'TEMP', 11]
# ['MOVE', 'TEMP', 32, 'BINOP', 'ADD', 'TEMP', 32, 'BINOP', 'MUL', 'CONST', 1.1176189025978578, 'TEMP', 14]
# ['MOVE', 'TEMP', 32, 'BINOP', 'ADD', 'TEMP', 32, 'BINOP', 'MUL', 'CONST', 0.8169309932346156, 'TEMP', 16]
# ['MOVE', 'TEMP', 32, 'BINOP', 'ADD', 'TEMP', 32, 'BINOP', 'MUL', 'CONST', 0.9885554653516674, 'TEMP', 17]
# ['MOVE', 'TEMP', 32, 'BINOP', 'ADD', 'TEMP', 32, 'BINOP', 'MUL', 'CONST', 0.8879014114345695, 'TEMP', 18]
# ['MOVE', 'TEMP', 33, 'BINOP', 'ADD', 'TEMP', 33, 'BINOP', 'MUL', 'CONST', 0.0016839022682129442, 'TEMP', 2]
# ['MOVE', 'TEMP', 33, 'BINOP', 'ADD', 'TEMP', 33, 'BINOP', 'MUL', 'CONST', 0.08253109923440677, 'TEMP', 3]
# ['MOVE', 'TEMP', 33, 'BINOP', 'ADD', 'TEMP', 33, 'BINOP', 'MUL', 'CONST', 0.09733110723172979, 'TEMP', 4]
# ['MOVE', 'TEMP', 33, 'BINOP', 'ADD', 'TEMP', 33, 'BINOP', 'MUL', 'CONST', 3.802414895815559, 'TEMP', 10]
# ['MOVE', 'TEMP', 33, 'BINOP', 'ADD', 'TEMP', 33, 'BINOP', 'MUL', 'CONST', 2.0899940523054914, 'TEMP', 11]
# ['MOVE', 'TEMP', 33, 'BINOP', 'ADD', 'TEMP', 33, 'BINOP', 'MUL', 'CONST', 0.8274470275141572, 'TEMP', 12]
# ['MOVE', 'TEMP', 33, 'BINOP', 'ADD', 'TEMP', 33, 'BINOP', 'MUL', 'CONST', 1.1695089733551498, 'TEMP', 13]
# ['MOVE', 'TEMP', 33, 'BINOP', 'ADD', 'TEMP', 33, 'BINOP', 'MUL', 'CONST', 0.15576733711902913, 'TEMP', 14]
# ['MOVE', 'TEMP', 33, 'BINOP', 'ADD', 'TEMP', 33, 'BINOP', 'MUL', 'CONST', 2.348326787575861, 'TEMP', 15]
# ['MOVE', 'TEMP', 33, 'BINOP', 'ADD', 'TEMP', 33, 'BINOP', 'MUL', 'CONST', 0.026972518391325195, 'TEMP', 16]
# ['MOVE', 'TEMP', 33, 'BINOP', 'ADD', 'TEMP', 33, 'BINOP', 'MUL', 'CONST', 0.009856747788019373, 'TEMP', 19]
# ['MOVE', 'TEMP', 34, 'BINOP', 'ADD', 'TEMP', 34, 'BINOP', 'MUL', 'CONST', 0.7200494278547002, 'TEMP', 2]
# ['MOVE', 'TEMP', 34, 'BINOP', 'ADD', 'TEMP', 34, 'BINOP', 'MUL', 'CONST', 3.201307196630617, 'TEMP', 5]
# ['MOVE', 'TEMP', 34, 'BINOP', 'ADD', 'TEMP', 34, 'BINOP', 'MUL', 'CONST', 1.1202649672591285, 'TEMP', 10]
# ['MOVE', 'TEMP', 34, 'BINOP', 'ADD', 'TEMP', 34, 'BINOP', 'MUL', 'CONST', 3.8835479467755323, 'TEMP', 12]
# ['MOVE', 'TEMP', 34, 'BINOP', 'ADD', 'TEMP', 34, 'BINOP', 'MUL', 'CONST', 0.8750413411930837, 'TEMP', 13]
# ['MOVE', 'TEMP', 34, 'BINOP', 'ADD', 'TEMP', 34, 'BINOP', 'MUL', 'CONST', 0.047949742292442886, 'TEMP', 16]
# ['MOVE', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'BINOP', 'MUL', 'CONST', 0.027591072963382878, 'TEMP', 2]
# ['MOVE', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'BINOP', 'MUL', 'CONST', 0.7347181929761636, 'TEMP', 3]
# ['MOVE', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'BINOP', 'MUL', 'CONST', 0.0003303199474755473, 'TEMP', 5]
# ['MOVE', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'BINOP', 'MUL', 'CONST', 0.0027598237544896654, 'TEMP', 6]
# ['MOVE', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'BINOP', 'MUL', 'CONST', 2.8358303111385834, 'TEMP', 7]
# ['MOVE', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'BINOP', 'MUL', 'CONST', 0.003170466501527688, 'TEMP', 11]
# ['MOVE', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'BINOP', 'MUL', 'CONST', 1.417285164562893, 'TEMP', 13]
# ['MOVE', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'BINOP', 'MUL', 'CONST', 0.12405529222649679, 'TEMP', 14]
# ['MOVE', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'BINOP', 'MUL', 'CONST', 5.904337812375403, 'TEMP', 15]
# ['MOVE', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'BINOP', 'MUL', 'CONST', 0.1276154440033543, 'TEMP', 17]
# ['MOVE', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'BINOP', 'MUL', 'CONST', 0.007157349022172668, 'TEMP', 18]
# ['MOVE', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'BINOP', 'MUL', 'CONST', 0.8242771584457275, 'TEMP', 19]
# ['MOVE', 'TEMP', 36, 'BINOP', 'ADD', 'TEMP', 36, 'BINOP', 'MUL', 'CONST', 1.5243353251015428, 'TEMP', 0]
# ['MOVE', 'TEMP', 36, 'BINOP', 'ADD', 'TEMP', 36, 'BINOP', 'MUL', 'CONST', 1.4017583168506913, 'TEMP', 1]
# ['MOVE', 'TEMP', 36, 'BINOP', 'ADD', 'TEMP', 36, 'BINOP', 'MUL', 'CONST', 0.22480809795392503, 'TEMP', 2]
# ['MOVE', 'TEMP', 36, 'BINOP', 'ADD', 'TEMP', 36, 'BINOP', 'MUL', 'CONST', 4.411486717961647, 'TEMP', 3]
# ['MOVE', 'TEMP', 36, 'BINOP', 'ADD', 'TEMP', 36, 'BINOP', 'MUL', 'CONST', 1.6847991515752954, 'TEMP', 7]
# ['MOVE', 'TEMP', 36, 'BINOP', 'ADD', 'TEMP', 36, 'BINOP', 'MUL', 'CONST', 4.496491456745426, 'TEMP', 14]
# ['MOVE', 'TEMP', 36, 'BINOP', 'ADD', 'TEMP', 36, 'BINOP', 'MUL', 'CONST', 0.006488645151571454, 'TEMP', 16]
# ['MOVE', 'TEMP', 36, 'BINOP', 'ADD', 'TEMP', 36, 'BINOP', 'MUL', 'CONST', 0.8618444161602612, 'TEMP', 19]
# ['MOVE', 'TEMP', 37, 'BINOP', 'ADD', 'TEMP', 37, 'BINOP', 'MUL', 'CONST', 0.5612275583650592, 'TEMP', 2]
# ['MOVE', 'TEMP', 37, 'BINOP', 'ADD', 'TEMP', 37, 'BINOP', 'MUL', 'CONST', 3.7290040907927486, 'TEMP', 4]
# ['MOVE', 'TEMP', 37, 'BINOP', 'ADD', 'TEMP', 37, 'BINOP', 'MUL', 'CONST', 0.2317450463784333, 'TEMP', 5]
# ['MOVE', 'TEMP', 37, 'BINOP', 'ADD', 'TEMP', 37, 'BINOP', 'MUL', 'CONST', 0.35955890412042746, 'TEMP', 7]
# ['MOVE', 'TEMP', 37, 'BINOP', 'ADD', 'TEMP', 37, 'BINOP', 'MUL', 'CONST', 0.7590463866258905, 'TEMP', 9]
# ['MOVE', 'TEMP', 37, 'BINOP', 'ADD', 'TEMP', 37, 'BINOP', 'MUL', 'CONST', 0.7154017936913019, 'TEMP', 13]
# ['MOVE', 'TEMP', 38, 'BINOP', 'ADD', 'TEMP', 38, 'BINOP', 'MUL', 'CONST', 0.29368265599860705, 'TEMP', 0]
# ['MOVE', 'TEMP', 38, 'BINOP', 'ADD', 'TEMP', 38, 'BINOP', 'MUL', 'CONST', 0.04525509156410038, 'TEMP', 2]
# ['MOVE', 'TEMP', 38, 'BINOP', 'ADD', 'TEMP', 38, 'BINOP', 'MUL', 'CONST', 0.24556086098644064, 'TEMP', 4]
# ['MOVE', 'TEMP', 38, 'BINOP', 'ADD', 'TEMP', 38, 'BINOP', 'MUL', 'CONST', 0.39817875466850244, 'TEMP', 8]
# ['MOVE', 'TEMP', 38, 'BINOP', 'ADD', 'TEMP', 38, 'BINOP', 'MUL', 'CONST', 0.12548238719830568, 'TEMP', 16]
# ['MOVE', 'TEMP', 38, 'BINOP', 'ADD', 'TEMP', 38, 'BINOP', 'MUL', 'CONST', 0.9875860908574126, 'TEMP', 18]
# ['MOVE', 'TEMP', 38, 'BINOP', 'ADD', 'TEMP', 38, 'BINOP', 'MUL', 'CONST', 2.9373155563280235, 'TEMP', 19]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 0.011473694127940698, 'TEMP', 1]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 0.6738504375040552, 'TEMP', 2]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 0.05238077186048076, 'TEMP', 8]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 0.0055528389462783725, 'TEMP', 11]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 3.3014582112339563, 'TEMP', 13]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 0.28521034523725686, 'TEMP', 14]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 0.03128369532988128, 'TEMP', 15]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 0.2185430120451787, 'TEMP', 18]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 0.3347205619405057, 'TEMP', 19]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'CONST', 1.8730582396695545]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 21, 'BINOP', 'ADD', 'TEMP', 21, 'CONST', -0.7772863067568756]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 22, 'BINOP', 'ADD', 'TEMP', 22, 'CONST', -0.18540189519205197]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 23, 'BINOP', 'ADD', 'TEMP', 23, 'CONST', -0.7714259943188856]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 24, 'BINOP', 'ADD', 'TEMP', 24, 'CONST', 0.017965653145597196]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 25, 'BINOP', 'ADD', 'TEMP', 25, 'CONST', -0.9722271243492832]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 26, 'BINOP', 'ADD', 'TEMP', 26, 'CONST', -0.877190993904541]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 27, 'BINOP', 'ADD', 'TEMP', 27, 'CONST', 0.27953716146496815]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 28, 'BINOP', 'ADD', 'TEMP', 28, 'CONST', 1.2864490480031847]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 29, 'BINOP', 'ADD', 'TEMP', 29, 'CONST', 0.22999510364454734]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 30, 'BINOP', 'ADD', 'TEMP', 30, 'CONST', 0.4932045787028291]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 31, 'BINOP', 'ADD', 'TEMP', 31, 'CONST', 0.49681799179733377]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 32, 'BINOP', 'ADD', 'TEMP', 32, 'CONST', -1.2000072936232211]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 33, 'BINOP', 'ADD', 'TEMP', 33, 'CONST', 0.9073085028706052]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 34, 'BINOP', 'ADD', 'TEMP', 34, 'CONST', -0.7292696985681862]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'CONST', 0.1831386089791053]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 36, 'BINOP', 'ADD', 'TEMP', 36, 'CONST', 1.1125921247231874]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 37, 'BINOP', 'ADD', 'TEMP', 37, 'CONST', 1.462014587529446]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 38, 'BINOP', 'ADD', 'TEMP', 38, 'CONST', -0.16065082454421223]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'CONST', 1.24850000783909]
# ['COMMENT', 'END']
# ['COMMENT', 'START']
# ['MOVE', 'TEMP', 20, 'CONST', 0]
# ['MOVE', 'TEMP', 21, 'CONST', 0]
# ['MOVE', 'TEMP', 22, 'CONST', 0]
# ['MOVE', 'TEMP', 23, 'CONST', 0]
# ['MOVE', 'TEMP', 24, 'CONST', 0]
# ['MOVE', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'BINOP', 'MUL', 'CONST', 0.025061019144849383, 'TEMP', 0]
# ['MOVE', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'BINOP', 'MUL', 'CONST', 0.26598324496859077, 'TEMP', 1]
# ['MOVE', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'BINOP', 'MUL', 'CONST', 1.280889991566665, 'TEMP', 3]
# ['MOVE', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'BINOP', 'MUL', 'CONST', 0.37854662058675076, 'TEMP', 4]
# ['MOVE', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'BINOP', 'MUL', 'CONST', 6.1729472740271785, 'TEMP', 6]
# ['MOVE', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'BINOP', 'MUL', 'CONST', 1.6558549149752249, 'TEMP', 7]
# ['MOVE', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'BINOP', 'MUL', 'CONST', 0.026221676516361186, 'TEMP', 9]
# ['MOVE', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'BINOP', 'MUL', 'CONST', 1.2814823714226677, 'TEMP', 11]
# ['MOVE', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'BINOP', 'MUL', 'CONST', 0.0032515019709402067, 'TEMP', 13]
# ['MOVE', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'BINOP', 'MUL', 'CONST', 0.2486586555799326, 'TEMP', 16]
# ['MOVE', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'BINOP', 'MUL', 'CONST', 1.8130122199274916, 'TEMP', 19]
# ['MOVE', 'TEMP', 21, 'BINOP', 'ADD', 'TEMP', 21, 'BINOP', 'MUL', 'CONST', 0.41791714922729195, 'TEMP', 0]
# ['MOVE', 'TEMP', 21, 'BINOP', 'ADD', 'TEMP', 21, 'BINOP', 'MUL', 'CONST', 1.257827281112283, 'TEMP', 4]
# ['MOVE', 'TEMP', 21, 'BINOP', 'ADD', 'TEMP', 21, 'BINOP', 'MUL', 'CONST', 0.07995491542382763, 'TEMP', 18]
# ['MOVE', 'TEMP', 22, 'BINOP', 'ADD', 'TEMP', 22, 'BINOP', 'MUL', 'CONST', 1.5924891580859426, 'TEMP', 2]
# ['MOVE', 'TEMP', 22, 'BINOP', 'ADD', 'TEMP', 22, 'BINOP', 'MUL', 'CONST', 1.9921245565521999, 'TEMP', 6]
# ['MOVE', 'TEMP', 22, 'BINOP', 'ADD', 'TEMP', 22, 'BINOP', 'MUL', 'CONST', 0.07280892712836647, 'TEMP', 11]
# ['MOVE', 'TEMP', 22, 'BINOP', 'ADD', 'TEMP', 22, 'BINOP', 'MUL', 'CONST', 0.8707815160494957, 'TEMP', 12]
# ['MOVE', 'TEMP', 22, 'BINOP', 'ADD', 'TEMP', 22, 'BINOP', 'MUL', 'CONST', 0.17313777482167397, 'TEMP', 14]
# ['MOVE', 'TEMP', 22, 'BINOP', 'ADD', 'TEMP', 22, 'BINOP', 'MUL', 'CONST', 0.0500540523149244, 'TEMP', 15]
# ['MOVE', 'TEMP', 22, 'BINOP', 'ADD', 'TEMP', 22, 'BINOP', 'MUL', 'CONST', 0.023763994782081608, 'TEMP', 18]
# ['MOVE', 'TEMP', 22, 'BINOP', 'ADD', 'TEMP', 22, 'BINOP', 'MUL', 'CONST', 1.6630847366496564, 'TEMP', 19]
# ['MOVE', 'TEMP', 23, 'BINOP', 'ADD', 'TEMP', 23, 'BINOP', 'MUL', 'CONST', 3.327032677499219, 'TEMP', 0]
# ['MOVE', 'TEMP', 23, 'BINOP', 'ADD', 'TEMP', 23, 'BINOP', 'MUL', 'CONST', 1.2614946652871892, 'TEMP', 1]
# ['MOVE', 'TEMP', 23, 'BINOP', 'ADD', 'TEMP', 23, 'BINOP', 'MUL', 'CONST', 0.44090712291718, 'TEMP', 3]
# ['MOVE', 'TEMP', 23, 'BINOP', 'ADD', 'TEMP', 23, 'BINOP', 'MUL', 'CONST', 0.34684316447904784, 'TEMP', 6]
# ['MOVE', 'TEMP', 23, 'BINOP', 'ADD', 'TEMP', 23, 'BINOP', 'MUL', 'CONST', 4.216515217157877, 'TEMP', 15]
# ['MOVE', 'TEMP', 23, 'BINOP', 'ADD', 'TEMP', 23, 'BINOP', 'MUL', 'CONST', 0.5492350309621977, 'TEMP', 16]
# ['MOVE', 'TEMP', 23, 'BINOP', 'ADD', 'TEMP', 23, 'BINOP', 'MUL', 'CONST', 0.2708774137468361, 'TEMP', 17]
# ['MOVE', 'TEMP', 24, 'BINOP', 'ADD', 'TEMP', 24, 'BINOP', 'MUL', 'CONST', 0.00013427204785735665, 'TEMP', 1]
# ['MOVE', 'TEMP', 24, 'BINOP', 'ADD', 'TEMP', 24, 'BINOP', 'MUL', 'CONST', 2.9116562458348305, 'TEMP', 2]
# ['MOVE', 'TEMP', 24, 'BINOP', 'ADD', 'TEMP', 24, 'BINOP', 'MUL', 'CONST', 0.0002763363765774659, 'TEMP', 3]
# ['MOVE', 'TEMP', 24, 'BINOP', 'ADD', 'TEMP', 24, 'BINOP', 'MUL', 'CONST', 0.5240780414941386, 'TEMP', 5]
# ['MOVE', 'TEMP', 24, 'BINOP', 'ADD', 'TEMP', 24, 'BINOP', 'MUL', 'CONST', 0.23696498205740224, 'TEMP', 6]
# ['MOVE', 'TEMP', 24, 'BINOP', 'ADD', 'TEMP', 24, 'BINOP', 'MUL', 'CONST', 0.2885042016016957, 'TEMP', 9]
# ['MOVE', 'TEMP', 24, 'BINOP', 'ADD', 'TEMP', 24, 'BINOP', 'MUL', 'CONST', 0.0051283909423899335, 'TEMP', 10]
# ['MOVE', 'TEMP', 24, 'BINOP', 'ADD', 'TEMP', 24, 'BINOP', 'MUL', 'CONST', 0.22962430989147806, 'TEMP', 11]
# ['MOVE', 'TEMP', 24, 'BINOP', 'ADD', 'TEMP', 24, 'BINOP', 'MUL', 'CONST', 1.2964699089681369, 'TEMP', 14]
# ['MOVE', 'TEMP', 24, 'BINOP', 'ADD', 'TEMP', 24, 'BINOP', 'MUL', 'CONST', 0.7073920400745846, 'TEMP', 15]
# ['MOVE', 'TEMP', 24, 'BINOP', 'ADD', 'TEMP', 24, 'BINOP', 'MUL', 'CONST', 0.5580927574651129, 'TEMP', 19]
# ['MOVE', 'CALL', 'LINEAR', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'CONST', -1.3655609702333857]
# ['MOVE', 'CALL', 'LINEAR', 'TEMP', 21, 'BINOP', 'ADD', 'TEMP', 21, 'CONST', 0.6677645130667956]
# ['MOVE', 'CALL', 'LINEAR', 'TEMP', 22, 'BINOP', 'ADD', 'TEMP', 22, 'CONST', 0.2860249380599192]
# ['MOVE', 'CALL', 'LINEAR', 'TEMP', 23, 'BINOP', 'ADD', 'TEMP', 23, 'CONST', -0.14994995927461718]
# ['MOVE', 'CALL', 'LINEAR', 'TEMP', 24, 'BINOP', 'ADD', 'TEMP', 24, 'CONST', -0.1434084885972423]
# ['COMMENT', 'END']
# 	Matrix Multiplication 0
# Optimizing memory allocation of unconstrained temps...
# cost = 2.83
# cost = 3.37
# cost = 3.27
# cost = 2.75
# cost = 3.11
# cost = 1.67
# cost = 2.66
# cost = 1.04
# cost = 2.13
# cost = 1.04
# cost = 1.04
#
# 	Matrix Multiplication 1
# Optimizing memory allocation of unconstrained temps...
# cost = 6.30
# cost = 7.07
# cost = 6.69
# cost = 6.03
# cost = 6.97
# cost = 5.95
# cost = 4.96
# cost = 5.24
# cost = 4.69
# cost = 4.15
# cost = 4.22
#
# 	Matrix Multiplication 2
# Optimizing memory allocation of unconstrained temps...
# cost = 3.32
# cost = 2.92
# cost = 3.15
# cost = 2.93
# cost = 1.86
# cost = 2.34
# cost = 2.14
# cost = 1.28
# cost = 1.28
# cost = 1.28
# cost = 1.28
#
#
#
#
#
#
#
#
#
#
#
# ##### GENERATED ASSEMBLER #####
#
#
#
#
#
#
#
#
#
#
#
# MOV r7,0x0 	 ; # address offset
# VSUB.F32 s0,s0,s0 	 ; # initalize the zero register
# VMOV.F32 s14, s0	 ; # set the register to 0
# VMOV.F32 s5, s0	 ; # set the register to 0
# FSTS s0, [r7,#0]
# VMOV.F32 s6, s0	 ; # set the register to 0
# VMOV.F32 s7, s0	 ; # set the register to 0
# VMOV.F32 s8, s0	 ; # set the register to 0
# VMOV.F32 s9, s0	 ; # set the register to 0
# VMOV.F32 s4, s0	 ; # set the register to 0
# FSTS s0, [r7,#1]
# FSTS s0, [r7,#2]
# VMOV.F32 s10, s0	 ; # set the register to 0
# FSTS s0, [r7,#3]
# VMOV.F32 s15, s0	 ; # set the register to 0
# FSTS s0, [r7,#4]
# VMOV.F32 s11, s0	 ; # set the register to 0
# FSTS s0, [r7,#5]
# FSTS s0, [r7,#6]
# VMOV.F32 s12, s0	 ; # set the register to 0
# VMOV.F32 s13, s0	 ; # set the register to 0
# FSTS s0, [r7,#7]
# MOVW r3,#20735 	 ; # move the most significative bits in r3
# MOVT r3,#16109 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s3 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s14,s2,s14 	 ; #
# MOVW r3,#26097 	 ; # move the most significative bits in r3
# MOVT r3,#16329 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s3 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s5,s2,s5 	 ; #
# MOVW r3,#3314 	 ; # move the most significative bits in r3
# MOVT r3,#15381 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s3 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s6,s2,s6 	 ; #
# MOVW r3,#7410 	 ; # move the most significative bits in r3
# MOVT r3,#15809 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s3 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s7,s2,s7 	 ; #
# MOVW r3,#33561 	 ; # move the most significative bits in r3
# MOVT r3,#15497 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s3 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s8,s2,s8 	 ; #
# MOVW r3,#48551 	 ; # move the most significative bits in r3
# MOVT r3,#15757 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s3 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s9,s2,s9 	 ; #
# MOVW r3,#47157 	 ; # move the most significative bits in r3
# MOVT r3,#16500 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s3 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s4,s2,s4 	 ; #
# MOVW r3,#65372 	 ; # move the most significative bits in r3
# MOVT r3,#15362 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s3 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s10,s2,s10 	 ; #
# MOVW r3,#52340 	 ; # move the most significative bits in r3
# MOVT r3,#16140 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s3 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s11,s2,s11 	 ; #
# MOVW r3,#4461 	 ; # move the most significative bits in r3
# MOVT r3,#16031 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s3 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s12,s2,s12 	 ; #
# MOVW r3,#2714 	 ; # move the most significative bits in r3
# MOVT r3,#15600 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s3 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s13,s2,s13 	 ; #
# MOVW r3,#14527 	 ; # move the most significative bits in r3
# MOVT r3,#48932 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s14,s1,s14 	 ; # add the bias
# # RELU
# vcmpe.f32  s14, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L0 ; 	 # jump to the next label if the value is >= 0
# vmov.f32 s14,s0  ; 	 # put the value to 0 if less than 0
# .L0:
# MOVW r3,#7822 	 ; # move the most significative bits in r3
# MOVT r3,#15961 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s5,s1,s5 	 ; # add the bias
# # RELU
# vcmpe.f32  s5, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L1 ; 	 # jump to the next label if the value is >= 0
# vmov.f32 s5,s0  ; 	 # put the value to 0 if less than 0
# .L1:
# FLDS s2,[r7, #0] 	 ; # load the content of the output neuron in buffer_register_2
# MOVW r3,#7822 	 ; # move the most significative bits in r3
# MOVT r3,#15961 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s2,s1,s2 	 ; # add the bias
# # RELU
# vcmpe.f32  s2, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L2 ; 	 # jump to the next label if the value is >= 0
# vmov.f32 s2,s0  ; 	 # put the value to 0 if less than 0
# .L2:
# FSTF s2,[r7, #0]
# MOVW r3,#56117 	 ; # move the most significative bits in r3
# MOVT r3,#15706 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s6,s1,s6 	 ; # add the bias
# # RELU
# vcmpe.f32  s6, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L3 ; 	 # jump to the next label if the value is >= 0
# vmov.f32 s6,s0  ; 	 # put the value to 0 if less than 0
# .L3:
# MOVW r3,#53700 	 ; # move the most significative bits in r3
# MOVT r3,#16317 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s7,s1,s7 	 ; # add the bias
# # RELU
# vcmpe.f32  s7, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L4 ; 	 # jump to the next label if the value is >= 0
# vmov.f32 s7,s0  ; 	 # put the value to 0 if less than 0
# .L4:
# MOVW r3,#29214 	 ; # move the most significative bits in r3
# MOVT r3,#16087 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s8,s1,s8 	 ; # add the bias
# # RELU
# vcmpe.f32  s8, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L5 ; 	 # jump to the next label if the value is >= 0
# vmov.f32 s8,s0  ; 	 # put the value to 0 if less than 0
# .L5:
# MOVW r3,#935 	 ; # move the most significative bits in r3
# MOVT r3,#49198 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s9,s1,s9 	 ; # add the bias
# # RELU
# vcmpe.f32  s9, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L6 ; 	 # jump to the next label if the value is >= 0
# vmov.f32 s9,s0  ; 	 # put the value to 0 if less than 0
# .L6:
# MOVW r3,#56151 	 ; # move the most significative bits in r3
# MOVT r3,#16335 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s4,s1,s4 	 ; # add the bias
# # RELU
# vcmpe.f32  s4, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L7 ; 	 # jump to the next label if the value is >= 0
# vmov.f32 s4,s0  ; 	 # put the value to 0 if less than 0
# .L7:
# FLDS s2,[r7, #1] 	 ; # load the content of the output neuron in buffer_register_2
# MOVW r3,#56151 	 ; # move the most significative bits in r3
# MOVT r3,#16335 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s2,s1,s2 	 ; # add the bias
# # RELU
# vcmpe.f32  s2, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L8 ; 	 # jump to the next label if the value is >= 0
# vmov.f32 s2,s0  ; 	 # put the value to 0 if less than 0
# .L8:
# FSTF s2,[r7, #1]
# FLDS s2,[r7, #2] 	 ; # load the content of the output neuron in buffer_register_2
# MOVW r3,#56151 	 ; # move the most significative bits in r3
# MOVT r3,#16335 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s2,s1,s2 	 ; # add the bias
# # RELU
# vcmpe.f32  s2, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L9 ; 	 # jump to the next label if the value is >= 0
# vmov.f32 s2,s0  ; 	 # put the value to 0 if less than 0
# .L9:
# FSTF s2,[r7, #2]
# MOVW r3,#36477 	 ; # move the most significative bits in r3
# MOVT r3,#15784 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s10,s1,s10 	 ; # add the bias
# # RELU
# vcmpe.f32  s10, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L10 ; 	 # jump to the next label if the value is >= 0
# vmov.f32 s10,s0  ; 	 # put the value to 0 if less than 0
# .L10:
# FLDS s2,[r7, #3] 	 ; # load the content of the output neuron in buffer_register_2
# MOVW r3,#36477 	 ; # move the most significative bits in r3
# MOVT r3,#15784 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s2,s1,s2 	 ; # add the bias
# # RELU
# vcmpe.f32  s2, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L11 ; 	 # jump to the next label if the value is >= 0
# vmov.f32 s2,s0  ; 	 # put the value to 0 if less than 0
# .L11:
# FSTF s2,[r7, #3]
# MOVW r3,#18086 	 ; # move the most significative bits in r3
# MOVT r3,#16124 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s15,s1,s15 	 ; # add the bias
# # RELU
# vcmpe.f32  s15, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L12 ; 	 # jump to the next label if the value is >= 0
# vmov.f32 s15,s0  ; 	 # put the value to 0 if less than 0
# .L12:
# FLDS s2,[r7, #4] 	 ; # load the content of the output neuron in buffer_register_2
# MOVW r3,#18086 	 ; # move the most significative bits in r3
# MOVT r3,#16124 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s2,s1,s2 	 ; # add the bias
# # RELU
# vcmpe.f32  s2, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L13 ; 	 # jump to the next label if the value is >= 0
# vmov.f32 s2,s0  ; 	 # put the value to 0 if less than 0
# .L13:
# FSTF s2,[r7, #4]
# MOVW r3,#36560 	 ; # move the most significative bits in r3
# MOVT r3,#16055 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s11,s1,s11 	 ; # add the bias
# # RELU
# vcmpe.f32  s11, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L14 ; 	 # jump to the next label if the value is >= 0
# vmov.f32 s11,s0  ; 	 # put the value to 0 if less than 0
# .L14:
# FLDS s2,[r7, #5] 	 ; # load the content of the output neuron in buffer_register_2
# MOVW r3,#36560 	 ; # move the most significative bits in r3
# MOVT r3,#16055 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s2,s1,s2 	 ; # add the bias
# # RELU
# vcmpe.f32  s2, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L15 ; 	 # jump to the next label if the value is >= 0
# vmov.f32 s2,s0  ; 	 # put the value to 0 if less than 0
# .L15:
# FSTF s2,[r7, #5]
# FLDS s2,[r7, #6] 	 ; # load the content of the output neuron in buffer_register_2
# MOVW r3,#36560 	 ; # move the most significative bits in r3
# MOVT r3,#16055 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s2,s1,s2 	 ; # add the bias
# # RELU
# vcmpe.f32  s2, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L16 ; 	 # jump to the next label if the value is >= 0
# vmov.f32 s2,s0  ; 	 # put the value to 0 if less than 0
# .L16:
# FSTF s2,[r7, #6]
# MOVW r3,#20092 	 ; # move the most significative bits in r3
# MOVT r3,#16249 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s12,s1,s12 	 ; # add the bias
# # RELU
# vcmpe.f32  s12, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L17 ; 	 # jump to the next label if the value is >= 0
# vmov.f32 s12,s0  ; 	 # put the value to 0 if less than 0
# .L17:
# MOVW r3,#59949 	 ; # move the most significative bits in r3
# MOVT r3,#16182 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s13,s1,s13 	 ; # add the bias
# # RELU
# vcmpe.f32  s13, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L18 ; 	 # jump to the next label if the value is >= 0
# vmov.f32 s13,s0  ; 	 # put the value to 0 if less than 0
# .L18:
# FLDS s2,[r7, #7] 	 ; # load the content of the output neuron in buffer_register_2
# MOVW r3,#59949 	 ; # move the most significative bits in r3
# MOVT r3,#16182 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s2,s1,s2 	 ; # add the bias
# # RELU
# vcmpe.f32  s2, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L19 ; 	 # jump to the next label if the value is >= 0
# vmov.f32 s2,s0  ; 	 # put the value to 0 if less than 0
# .L19:
# FSTF s2,[r7, #7]
# ######################################## HERE GOES THE INTERFACE
# VMOV.F32 s5, s0	 ; # set the register to 0
# VMOV.F32 s3, s0	 ; # set the register to 0
# VMOV.F32 s14, s0	 ; # set the register to 0
# FSTS s0, [r7,#25]
# FSTS s0, [r7,#24]
# VMOV.F32 s10, s0	 ; # set the register to 0
# FSTS s0, [r7,#22]
# FSTS s0, [r7,#23]
# VMOV.F32 s13, s0	 ; # set the register to 0
# VMOV.F32 s15, s0	 ; # set the register to 0
# VMOV.F32 s11, s0	 ; # set the register to 0
# FSTS s0, [r7,#8]
# VMOV.F32 s7, s0	 ; # set the register to 0
# VMOV.F32 s9, s0	 ; # set the register to 0
# FSTS s0, [r7,#9]
# VMOV.F32 s12, s0	 ; # set the register to 0
# VMOV.F32 s4, s0	 ; # set the register to 0
# FSTS s0, [r7,#26]
# VMOV.F32 s8, s0	 ; # set the register to 0
# VMOV.F32 s6, s0	 ; # set the register to 0
# FLDS s2,[r7, #16] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#2714 	 ; # move the most significative bits in r3
# MOVT r3,#15600 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s5,s2,s5 	 ; #
# FLDS s2,[r7, #15] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#2714 	 ; # move the most significative bits in r3
# MOVT r3,#15600 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s5,s2,s5 	 ; #
# FLDS s2,[r7, #20] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#2714 	 ; # move the most significative bits in r3
# MOVT r3,#15600 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s5,s2,s5 	 ; #
# FLDS s2,[r7, #1] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#2714 	 ; # move the most significative bits in r3
# MOVT r3,#15600 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s5,s2,s5 	 ; #
# FLDS s2,[r7, #2] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#2714 	 ; # move the most significative bits in r3
# MOVT r3,#15600 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s5,s2,s5 	 ; #
# FLDS s2,[r7, #12] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#2714 	 ; # move the most significative bits in r3
# MOVT r3,#15600 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s5,s2,s5 	 ; #
# FLDS s2,[r7, #6] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#2714 	 ; # move the most significative bits in r3
# MOVT r3,#15600 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s5,s2,s5 	 ; #
# FLDS s2,[r7, #13] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#2714 	 ; # move the most significative bits in r3
# MOVT r3,#15600 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s5,s2,s5 	 ; #
# FLDS s2,[r7, #19] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#2714 	 ; # move the most significative bits in r3
# MOVT r3,#15600 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s5,s2,s5 	 ; #
# FLDS s2,[r7, #15] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#2714 	 ; # move the most significative bits in r3
# MOVT r3,#15600 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s3,s2,s3 	 ; #
# FLDS s2,[r7, #14] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#2714 	 ; # move the most significative bits in r3
# MOVT r3,#15600 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s3,s2,s3 	 ; #
# FLDS s2,[r7, #18] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#2714 	 ; # move the most significative bits in r3
# MOVT r3,#15600 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s3,s2,s3 	 ; #
# FLDS s2,[r7, #17] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#2714 	 ; # move the most significative bits in r3
# MOVT r3,#15600 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s3,s2,s3 	 ; #
# FLDS s2,[r7, #2] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#2714 	 ; # move the most significative bits in r3
# MOVT r3,#15600 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s3,s2,s3 	 ; #
# FLDS s2,[r7, #11] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#2714 	 ; # move the most significative bits in r3
# MOVT r3,#15600 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s3,s2,s3 	 ; #
# FLDS s2,[r7, #3] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#2714 	 ; # move the most significative bits in r3
# MOVT r3,#15600 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s3,s2,s3 	 ; #
# FLDS s2,[r7, #5] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#2714 	 ; # move the most significative bits in r3
# ...
# MOVT r3,#16232 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s2,s1,s2 	 ; # add the bias
# # RELU
# vcmpe.f32  s2, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L34 ; 	 # jump to the next label if the value is >= 0
# vmov.f32 s2,s0  ; 	 # put the value to 0 if less than 0
# .L34:
# FSTF s2,[r7, #9]
# MOVW r3,#34992 	 ; # move the most significative bits in r3
# MOVT r3,#15931 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s12,s1,s12 	 ; # add the bias
# # RELU
# vcmpe.f32  s12, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L35 ; 	 # jump to the next label if the value is >= 0
# vmov.f32 s12,s0  ; 	 # put the value to 0 if less than 0
# .L35:
# MOVW r3,#26987 	 ; # move the most significative bits in r3
# MOVT r3,#16270 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s4,s1,s4 	 ; # add the bias
# # RELU
# vcmpe.f32  s4, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L36 ; 	 # jump to the next label if the value is >= 0
# vmov.f32 s4,s0  ; 	 # put the value to 0 if less than 0
# .L36:
# FLDS s2,[r7, #26] 	 ; # load the content of the output neuron in buffer_register_2
# MOVW r3,#26987 	 ; # move the most significative bits in r3
# MOVT r3,#16270 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s2,s1,s2 	 ; # add the bias
# # RELU
# vcmpe.f32  s2, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L37 ; 	 # jump to the next label if the value is >= 0
# vmov.f32 s2,s0  ; 	 # put the value to 0 if less than 0
# .L37:
# FSTF s2,[r7, #26]
# MOVW r3,#33190 	 ; # move the most significative bits in r3
# MOVT r3,#48676 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s8,s1,s8 	 ; # add the bias
# # RELU
# vcmpe.f32  s8, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L38 ; 	 # jump to the next label if the value is >= 0
# vmov.f32 s8,s0  ; 	 # put the value to 0 if less than 0
# .L38:
# MOVW r3,#52953 	 ; # move the most significative bits in r3
# MOVT r3,#16287 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s6,s1,s6 	 ; # add the bias
# # RELU
# vcmpe.f32  s6, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L39 ; 	 # jump to the next label if the value is >= 0
# vmov.f32 s6,s0  ; 	 # put the value to 0 if less than 0
# .L39:
# ######################################## HERE GOES THE INTERFACE
# VMOV.F32 s14, s0	 ; # set the register to 0
# VMOV.F32 s10, s0	 ; # set the register to 0
# VMOV.F32 s13, s0	 ; # set the register to 0
# VMOV.F32 s15, s0	 ; # set the register to 0
# VMOV.F32 s11, s0	 ; # set the register to 0
# MOVW r3,#19652 	 ; # move the most significative bits in r3
# MOVT r3,#15565 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s5 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s14,s2,s14 	 ; #
# MOVW r3,#12021 	 ; # move the most significative bits in r3
# MOVT r3,#16008 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s3 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s14,s2,s14 	 ; #
# MOVW r3,#62516 	 ; # move the most significative bits in r3
# MOVT r3,#16291 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s7 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s14,s2,s14 	 ; #
# MOVW r3,#53469 	 ; # move the most significative bits in r3
# MOVT r3,#16065 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s9 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s14,s2,s14 	 ; #
# MOVW r3,#35017 	 ; # move the most significative bits in r3
# MOVT r3,#16581 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s4 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s14,s2,s14 	 ; #
# FLDS s2,[r7, #23] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#35017 	 ; # move the most significative bits in r3
# MOVT r3,#16581 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s14,s2,s14 	 ; #
# FLDS s2,[r7, #12] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#35017 	 ; # move the most significative bits in r3
# MOVT r3,#16581 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s14,s2,s14 	 ; #
# MOVW r3,#1949 	 ; # move the most significative bits in r3
# MOVT r3,#16292 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s8 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s14,s2,s14 	 ; #
# FLDS s2,[r7, #17] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#1949 	 ; # move the most significative bits in r3
# MOVT r3,#16292 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s14,s2,s14 	 ; #
# FLDS s2,[r7, #14] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#1949 	 ; # move the most significative bits in r3
# MOVT r3,#16292 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s14,s2,s14 	 ; #
# MOVW r3,#4297 	 ; # move the most significative bits in r3
# MOVT r3,#16360 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s6 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s14,s2,s14 	 ; #
# MOVW r3,#63805 	 ; # move the most significative bits in r3
# MOVT r3,#16085 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s5 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s10,s2,s10 	 ; #
# MOVW r3,#124 	 ; # move the most significative bits in r3
# MOVT r3,#16289 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s9 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s10,s2,s10 	 ; #
# FLDS s2,[r7, #15] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#124 	 ; # move the most significative bits in r3
# MOVT r3,#16289 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s10,s2,s10 	 ; #
# FLDS s2,[r7, #13] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#124 	 ; # move the most significative bits in r3
# MOVT r3,#16289 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s13,s2,s13 	 ; #
# MOVW r3,#65008 	 ; # move the most significative bits in r3
# MOVT r3,#16382 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s4 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s13,s2,s13 	 ; #
# MOVW r3,#7385 	 ; # move the most significative bits in r3
# MOVT r3,#15765 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s8 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s13,s2,s13 	 ; #
# FLDS s2,[r7, #16] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#7385 	 ; # move the most significative bits in r3
# MOVT r3,#15765 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s13,s2,s13 	 ; #
# FLDS s2,[r7, #9] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#7385 	 ; # move the most significative bits in r3
# MOVT r3,#15765 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s13,s2,s13 	 ; #
# MOVW r3,#1402 	 ; # move the most significative bits in r3
# MOVT r3,#15693 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s12 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s13,s2,s13 	 ; #
# FLDS s2,[r7, #15] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#1402 	 ; # move the most significative bits in r3
# MOVT r3,#15693 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s13,s2,s13 	 ; #
# MOVW r3,#57334 	 ; # move the most significative bits in r3
# MOVT r3,#16340 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s6 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s13,s2,s13 	 ; #
# MOVW r3,#60954 	 ; # move the most significative bits in r3
# MOVT r3,#16468 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s5 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s15,s2,s15 	 ; #
# MOVW r3,#30888 	 ; # move the most significative bits in r3
# MOVT r3,#16289 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s3 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s15,s2,s15 	 ; #
# MOVW r3,#48788 	 ; # move the most significative bits in r3
# MOVT r3,#16097 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s7 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s15,s2,s15 	 ; #
# MOVW r3,#38253 	 ; # move the most significative bits in r3
# MOVT r3,#16049 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s4 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s15,s2,s15 	 ; #
# MOVW r3,#60849 	 ; # move the most significative bits in r3
# MOVT r3,#16518 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s12 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s15,s2,s15 	 ; #
# FLDS s2,[r7, #14] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#60849 	 ; # move the most significative bits in r3
# MOVT r3,#16518 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s15,s2,s15 	 ; #
# FLDS s2,[r7, #26] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#60849 	 ; # move the most significative bits in r3
# MOVT r3,#16518 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s15,s2,s15 	 ; #
# MOVW r3,#52065 	 ; # move the most significative bits in r3
# MOVT r3,#14604 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s3 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s11,s2,s11 	 ; #
# FLDS s2,[r7, #13] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#52065 	 ; # move the most significative bits in r3
# MOVT r3,#14604 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s11,s2,s11 	 ; #
# MOVW r3,#57662 	 ; # move the most significative bits in r3
# MOVT r3,#14736 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s7 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s11,s2,s11 	 ; #
# FLDS s2,[r7, #11] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#57662 	 ; # move the most significative bits in r3
# MOVT r3,#14736 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s11,s2,s11 	 ; #
# MOVW r3,#42739 	 ; # move the most significative bits in r3
# MOVT r3,#15986 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s4 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s11,s2,s11 	 ; #
# FLDS s2,[r7, #12] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#42739 	 ; # move the most significative bits in r3
# MOVT r3,#15986 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s11,s2,s11 	 ; #
# FLDS s2,[r7, #10] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#42739 	 ; # move the most significative bits in r3
# MOVT r3,#15986 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s11,s2,s11 	 ; #
# MOVW r3,#8867 	 ; # move the most significative bits in r3
# MOVT r3,#15979 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s8 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s11,s2,s11 	 ; #
# FLDS s2,[r7, #9] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r3,#8867 	 ; # move the most significative bits in r3
# MOVT r3,#15979 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s11,s2,s11 	 ; #
# MOVW r3,#6053 	 ; # move the most significative bits in r3
# MOVT r3,#16181 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s12 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s11,s2,s11 	 ; #
# MOVW r3,#57131 	 ; # move the most significative bits in r3
# MOVT r3,#16142 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s6 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s11,s2,s11 	 ; #
# MOVW r3,#51892 	 ; # move the most significative bits in r3
# MOVT r3,#49070 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s14,s1,s14 	 ; # add the bias
# MOVW r3,#62109 	 ; # move the most significative bits in r3
# MOVT r3,#16170 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s10,s1,s10 	 ; # add the bias
# MOVW r3,#29148 	 ; # move the most significative bits in r3
# MOVT r3,#16018 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s13,s1,s13 	 ; # add the bias
# MOVW r3,#35963 	 ; # move the most significative bits in r3
# MOVT r3,#48665 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s15,s1,s15 	 ; # add the bias
# MOVW r3,#55725 	 ; # move the most significative bits in r3
# MOVT r3,#48658 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r3 	 ; # copy r3 in buffer_register_1
# VADD.F32 s11,s1,s11 	 ; # add the bias
# ######################################## HERE GOES THE INTERFACE

# %% [markdown]
# # Test

# %% [markdown]
# ## Unicorn emulator

# %%
from unicorn import *
from unicorn.x86_const import *
from unicorn.mips_const import *
from unicorn.arm_const import *
import struct
from keystone import *

def assemble(codice):
    # in  : assembly code
    # out : machine code
    CODE = """         
        # ENABLE FLOATING POINT OPERATIONS
        mov.w r0, #0xf00000
        mcr p15, #0x0, r0, c1, c0, #0x2
        isb sy
        mov.w r3, #0x40000000
        vmsr fpexc, r3
        """ + codice                           # enabler for FLOAT operations
    try:
        # Initialize engine in X86-32bit mode
        ks = Ks(KS_ARCH_ARM, KS_MODE_ARM)
        encoding, count = ks.asm(CODE)
        print("%s = %s (number of statements: %u)" %(CODE, encoding, count))

    except KsError as e:
        print("ERROR: %s" %e)
        return 0
    return b''.join( e.to_bytes(1,'little') for e  in encoding)


def run(X86_CODE32):
     # memory address where emulation starts
        ADDRESS = 0x0000000  # TODO : fix offset in mappings
        print(type(repr(X86_CODE32)))
        print("Emulate ARM code")
        try:
            # Initialize emulator in X86-32bit mode
            mu = Uc(UC_ARCH_ARM, UC_MODE_ARM)

            # map 2MB memory for this emulation
            mu.mem_map(ADDRESS, 2 * 1024 * 1024)

            # write machine code to be emulated to memory
            mu.mem_write(ADDRESS , (X86_CODE32))

            # initialize machine registers
            mu.reg_write(UC_ARM_REG_S0 , 0x2)
            mu.reg_write(UC_ARM_REG_S15, 0x1)
        
            # emulate code in infinite time & unlimited instructions
            mu.emu_start( ADDRESS,  ADDRESS + len(X86_CODE32))

            # now print out some registers
            print("Emulation done. Below is the CPU context")

            r_s0 = mu.reg_read(UC_ARM_REG_S0)
            r_s15 = mu.reg_read(UC_ARM_REG_S15)
            r_0 = mu.reg_read(UC_ARM_REG_R0)
            print(">>> s0  = %f" % struct.unpack('f', r_s0.to_bytes(4,'little')) )
            print(">>> s15 = %f" % struct.unpack('f', r_s15.to_bytes(4,'little')) )
            print(">>> r0 =  0x%x" % r_0)

        except UcError as e:
            print("ERROR: %s" % e)

def assemble_and_run(codice):
        X86_CODE32 = assemble(codice)
        if X86_CODE32 == 0:
            return
        run(X86_CODE32)
    
assemble_and_run(
    """
# PROGRAM
MOV r7,0x0       ; # address offset
VSUB.F32 s0,s0,s0; # initalize the zero register
VMOV.F32 s8, s0	 ; # set the register to 0 
VMOV.F32 s13, s0 ; # set the register to 0 
VMOV.F32 s12, s0 ; # set the register to 0 
VMOV.F32 s11, s0 ; # set the register to 0 
VMOV.F32 s7, s0	 ; # set the register to 0 
VMOV.F32 s10, s0 ; # set the register to 0 
VMOV.F32 s6, s0	 ; # set the register to 0 
VMOV.F32 s5, s0	 ; # set the register to 0 
VMOV.F32 s9, s0	 ; # set the register to 0 
VMOV.F32 s4, s0	 ; # set the register to 0 
FSTS    s5, [r7, #0*4]
MOVW r3,#18350
MOVT r3,#16457
VMOV.F32 s0,r3
""")
# Out:
#
#         # ENABLE FLOATING POINT OPERATIONS
#         mov.w r0, #0xf00000
#         mcr p15, #0x0, r0, c1, c0, #0x2
#         isb sy
#         mov.w r3, #0x40000000
#         vmsr fpexc, r3
#
# # PROGRAM
# VMOV.F32 s5,#0.125
#  = [15, 6, 160, 227, 80, 15, 1, 238, 111, 240, 127, 245, 1, 49, 160, 227, 16, 58, 232, 238, 0, 42, 244, 238] (number of statements: 12)
# <class 'str'>
# Emulate ARM code
# Emulation done. Below is the CPU context
# >>> s0  = 0.000000
# >>> s15 = 0.000000
# >>> r0 =  0xf00000

# %%
assemble_and_run(
"""
MOV r7,#0
VMOV.F32 s15, #0.2500
FSTS s15, [r7, #4]
FLDS s0, [r7, #4]
"""
)
# Out:
#
#         # ENABLE FLOATING POINT OPERATIONS
#         mov.w r0, #0xf00000
#         mcr p15, #0x0, r0, c1, c0, #0x2
#         isb sy
#         mov.w r3, #0x40000000
#         vmsr fpexc, r3
#
# MOV r7,#0
# VMOV.F32 s15, #0.2500
# FSTS s15, [r7, #4]
# FLDS s0, [r7, #4]
#  = [15, 6, 160, 227, 80, 15, 1, 238, 111, 240, 127, 245, 1, 49, 160, 227, 16, 58, 232, 238, 0, 112, 160, 227, 0, 122, 245, 238, 1, 122, 199, 237, 1, 10, 151, 237] (number of statements: 13)
# <class 'str'>
# Emulate ARM code
# Emulation done. Below is the CPU context
# >>> s0  = 0.250000
# >>> s15 = 0.250000
# >>> r0 =  0xf00000

# %%
struct.unpack('f',int(9123).to_bytes(2,'little') + int(16137).to_bytes(2,'little'))
# Out:
# (0.5357000231742859,)

# %%
struct.unpack('h',struct.pack('f',3.145)[:2]), struct.unpack('h',struct.pack('f',3.145)[2:])
# Out:
# ((18350,), (16457,))
