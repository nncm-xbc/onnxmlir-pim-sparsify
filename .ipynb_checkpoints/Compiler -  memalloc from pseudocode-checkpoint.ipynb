# %% [markdown]
# # Compiler

# %% [markdown]
# ## Network container class
# Define a class able to contain a neural network

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import jax
import jax.numpy as jnp

class Program:
    # this class contains in a structured manner matrices and biases
    # which encode the semantics of the program network, in the same fashion
    # of the source code of a program
    def __init__(self, topology , activation_functions_list):
        self.topology = topology
        self.activation_functions_list = activation_functions_list
        self.W = [ 0 for t in topology[:-1]]
        self.b = [ 0 for t in topology[:-1]]
        
        
        self.activation_functions = {}
        self.activation_functions['RELU']   = lambda x : jnp.maximum(0.,x)
        self.activation_functions['LINEAR'] = lambda x : x
        
    def random_init_weights(self):
        for layer in range(len(self.topology[:-1])):
            self.W[layer] = np.random.normal( size = (self.topology[layer + 1] , self.topology[layer] ) )**2
            size = self.W[layer].shape[0] * self.W[layer].shape[1] 
            for i in range(size - int(np.sqrt(size))):
                r = np.random.choice(len(self.W[layer]))
                c = np.random.choice(len(self.W[layer].T))
                self.W[layer][r,c] = 0.   # adding some sparsity
                
            self.b[layer] = np.random.normal( size = self.topology[layer + 1] )
    def print(self):
        for i,layer in enumerate(self.topology[:-1]):
            print("layer %d->%d "%(i,i+1))
            print("W.shape = %s \t b.shape = %s" % (str(self.W[i].shape),str(self.b[i].shape)))
    def visualize_weights(self):
        for w in self.W:
            print(w.shape)
            plt.figure(figsize=(10,10))
            plt.imshow(w > 0.)        
    
    def run(self, data):
        layer = data
        for f_name,weight,bias in zip(self.activation_functions_list,
                                      self.W,
                                      self.b):
            f     = self.activation_functions[f_name]
            layer = f(weight @ layer  + bias)
        return layer

programma = Program([10,20,30,2], ['RELU','RELU','LINEAR'])
programma.random_init_weights()
programma.run( np.random.randn(10))
# Out:
# DeviceArray([149.99422, 139.81287], dtype=float32)

# %% [markdown]
# ## Sparsification algorithm
# Refer to the other notebook, for clarity is not included here

# %% [markdown]
# ## IR production

# %% [markdown]
# ### Lightweight trees representation

# %%
class c:
    # every element is a node in the tree.
    # the first argument denotes the name of the node ; the possible next arguments are a list of the sons.
    # Note that nodes without sons are simply leaf (eg. ADD, MUL,...)
    def __init__(self, ID, *args):
        self.id   = ID
        self.sons = list()
        for arg in args:
            self.sons.append(arg)
    def print(self,level = 0):
        print( ("\t" * level) + str(self.id) )
        for s in self.sons:
            s.print(level + 1)
    def __str__(self):
        ret = str(self.id)
        if len(self.sons) > 0:
            ret += "("
            for s in self.sons:
                ret += str(s)
                if s != self.sons[-1]:
                    ret += ','
            ret += ")"
        return ret
    def flatten(self):
        ret = []
        ret += [self.id]
        for s in self.sons:
            ret += s.flatten()
        return ret

# %% [markdown]
# ### IR production function

# %%
def IR(program, compile_time_data = True):
    # for every layer
    ### print("y = input")
    ret = list()
    
    for layer,t in enumerate(program.topology[1:]):
        IR_instruction = c("COMMENT", c("START"))
        ### print(IR_instruction)
        ret.append(IR_instruction)
        
        f = program.activation_functions_list[layer]
        R_offset = program.topology[layer]
        for i in range(len(program.b[layer])): # for every row
            #print("R[%d] = 0" % (i))
            #print("MOVE( TEMP(%d) , CONST(0) )" % (i + R_offset))
            IR_instruction = c(
                    "MOVE",
                     c("TEMP" , c(i + R_offset) ),
                     c("CONST", c(0))
            )
            ### print(str(IR_instruction))
            ret.append(IR_instruction)
            
            
        for i in range(len(program.W[layer])): # for every row
            for j in range(len(program.W[layer].T)): # for every column
                if( program.W[layer][i,j] != 0):
                    # if there is zero is useless to compute the contribution
                    #print("->MOVE(TEMP(%d),BINOP(ADD,TEMP(%d),BINOP(MUL,CONST(%f),TEMP(%d)))) " % (i + R_offset,i + R_offset, program.W[layer][i,j],i )) # COMPILE DATA HYPOTHESIS
                    IR_instruction = c(
                        "MOVE",
                        c("TEMP",
                            c(i + R_offset)
                        ),
                        c("BINOP",
                            c("ADD"),
                            c("TEMP",
                                c(i + R_offset)
                            ),
                            c("BINOP",
                                c("MUL"),
                                c("CONST",
                                     c(program.W[layer][i,j])
                                 ),
                                c("TEMP",
                                 c(j)
                                 )
                            )
                        )
                    )
                    #print(IR_instruction)
                    ret.append(IR_instruction)
                else:
                    0
                    ### print("# here there was a 0 so we exploit sparsity ")
                    
        for i in range(len(program.b[layer])): # for every row
            # a priori in compile time since the amount of "repetitions" doens't scale quadratically , in opposite to weights
            #print("->MOVE(TEMP(%d),BINOP(ADD,TEMP(%d),CONST(%f)))" % (i, i + R_offset , program.b[layer][i]) )
            
            # For each output temporary i add the bias to it
            # Since after the add of the bias the only modification
            # That is performed on a temporary variable is the application of the 
            # activation function, i condensate the instructions
            # in order to avoid useless memory reads
            
            IR_instruction = c("MOVE",
                                c("CALL",
                                    c(f),
                                    c("TEMP",
                                     c(i + R_offset)
                                     ),
                                    c("BINOP",
                                     c("ADD"),
                                     c("TEMP",
                                       c(i + R_offset)
                                      ),
                                     c("CONST",
                                      c(program.b[layer][i])
                                      )
                                     )
                                 )
                                )
            ### print((IR_instruction))
            ret.append(IR_instruction)

        IR_instruction = c("COMMENT", c("END"))
        ### print(IR_instruction)
        ret.append(IR_instruction)
    return ret

# %% [markdown]
# ## Register and memory allocation

# %% [markdown]
# ### Temporary variables statistics class

# %%
class TemporaryVariablesStatistics:
    def __init__(self):
        self.temp_usage_map = {}
    def increment(self,temp_variable):
        old_value = self.temp_usage_map.get(temp_variable)
        if old_value == None:
            old_value = 0
        self.temp_usage_map[temp_variable] = old_value + 1
    def get_data(self):
        return self.temp_usage_map
    def vectorize(self):
        arr = []
        for s in self.get_data():
            arr.append( [ s, self.get_data()[s]] )
        arr = np.array(arr)                                                              # builds a tempstable [ temp | usage ]
        arr = arr[ arr[:,1].argsort()[-1::-1] ]                                          # sort the tempstable by usage  (decreasing)
        return arr
    
    def print(self):
        for t in self.temp_usage_map:
            print("%d --> %d" % (t , self.temp_usage_map[t]) )

# %% [markdown]
# ### Register allocation data class

# %%
#"sx".startswith("x")

# %%
class RegisterAllocationData:
    def __init__(self):
        self.temp_reg_map = {}
    
    def get(self,temp_variable):
        return self.temp_reg_map[temp_variable]
    
    def insert(self,temp_variable, register):
        self.temp_reg_map[temp_variable] = register
    def get_data(self):
        return self.temp_reg_map
    
    def rename(self,old_reg_name, new_reg_name):
        for t in self.temp_reg_map:
            if self.temp_reg_map[t] == old_reg_name:
                self.temp_reg_map[t] = new_reg_name
    
    def get_unitialized_temps(self):
        # returns the list of temps that have a register starting with "register_"
        ret = list()
        for s in self.temp_reg_map:
            if self.temp_reg_map[s].startswith("register_"):
                ret.append(s)
        return ret
    
    def get_initialized_registers(self):
        # returns a list of the register ACTUALLY used (no place holder)
        ret = list()
        for s in self.temp_reg_map:
            if not self.temp_reg_map[s].startswith("register_"):
                ret.append(self.temp_reg_map[s])
        return ret
    
    def get_variables_list(self):
        ret = list()
        for s in self.temp_reg_map:
            ret.append(s)
        return ret
    
    def get_input_temps(self, prev_layer_size):
        all_vars = np.array(self.get_variables_list())
        ret      = list()
        for var in all_vars:
            if var < prev_layer_size:
                ret.append([var, self.temp_reg_map[var]])
        return np.array(ret)
    
    def get_output_temps(self, prev_layer_size):
        all_vars = np.array(self.get_variables_list())
        ret      = list()
        for var in all_vars:
            if var >= prev_layer_size:
                ret.append([var, self.temp_reg_map[var]])
        return np.array(ret)
    
    def print(self):
        for t in self.temp_reg_map:
            print(t , "\t", self.temp_reg_map[t] )
    def contains(self,tmp_name):
        return tmp_name in self.temp_reg_map

# %% [markdown]
# ### Memory allocation data class

# %%
class MemoryAllocationData:
    def __init__(self):
        self.temp_mem_map = {}
        
    def insert(self,temp_variable, address):
        self.temp_mem_map[temp_variable] = address
        
        
    def batch_set(self, list_of_temps, list_of_addresses):
        for tmp_id, mem_addr in zip(list_of_temps,list_of_addresses):
            self.temp_mem_map[tmp_id] = mem_addr
        
    def get_data(self):
        return self.temp_mem_map
    
    def get(self,x):
        return self.temp_mem_map[x]
    
    def get_variables_list(self):
        ret = list()
        for s in self.temp_mem_map:
            ret.append(s)
        return ret
    
    def get_input_temps(self, prev_layer_size):
        all_vars = np.array(self.get_variables_list())
        return all_vars[all_vars < prev_layer_size]
    
    def get_output_temps(self,prev_layer_size):
        all_vars = np.array(self.get_variables_list())
        return all_vars[all_vars >= prev_layer_size]
    
    def print(self):
        for t in self.temp_mem_map:
            print(t , "\t", self.temp_mem_map[t] )

# %% [markdown]
# ### Block Signals

# %%
class BlockSignals:
    def __init__(self, memory_allocation_object):
        # initialize an empty dictionary starting from the variables name
        self.memory_allocation_object = memory_allocation_object
        self.temp_signals_map = {}
        for t in memory_allocation_object.get_data():
            self.temp_signals_map[t] = []
        
    def add_tick(self, temp_variables):
        temp_variables          = np.intersect1d(temp_variables, self.memory_allocation_object.get_variables_list())
        all_temporary_variables = self.memory_allocation_object.get_variables_list()
        # push 0 in the lists of unused temps and 1 in the list of the used temp
        for t in all_temporary_variables:
            self.temp_signals_map[t].append(0)
        for t in temp_variables:
            self.temp_signals_map[t][-1] = 1.
            
    def get_data(self):
        return self.temp_signals_map

# %% [markdown]
# ### Interface Communication between blocks

# %%
class MemoryToRegisterFlow:
    # contains the information about the movement of information from a memory
    # cell to a register from a matrix mult to the next one
    def __init__(self, mem_address, register):
        self.mem_address = mem_address
        self.register    = register
    def print(self):
        print("M2R flow\t%s\t->\t%s" % (self.mem_address,self.register))
class RegisterToMemoryFlow:
    # contains the information about the movement of information from a register 
    # to a memory cell from a matrix mult to the next one
    def __init__(self, register, mem_address):
        self.mem_address = mem_address
        self.register    = register
    def print(self):
        print("R2M flow\t%s\t->\t%s" % (self.register,self.mem_address))

class RegisterRenameFlow:
    # contains the information about the movement of information from a register 
    # to a memory cell from a matrix mult to the next one
    def __init__(self, register_placeholder, register_name):
        self.register_placeholder = register_placeholder
        self.register_name        = register_name
    def print(self):
        print("R2R flow\t%s\t->\t%s" % (self.register_placeholder,self.register_name))

        
class InterfaceCommunication:
    # contains the list of movements "flows" between two matrix mult blocks
    def __init__(self):
        self.reg2memFlows = list()
        self.mem2regFlows = list()
        self.reg2regFlows = list()
    def insert(self,flow):
        if type(flow).__name__ == "RegisterToMemoryFlow":
            self.reg2memFlows.append(flow)
        else:
            if type(flow).__name__ == "MemoryToRegisterFlow":
                self.mem2regFlows.append(flow)
            else:
                if type(flow).__name__ == "RegisterRenameFlow":
                    self.reg2regFlows.append(flow)
                    
    def getReg2MemFlows(self):
        return self.reg2memFlows
    def getMem2RegFlows(self):
        return self.mem2regFlows
    def getReg2RegFlows(self):
        return self.reg2regFlows
    
    def print(self):
        reg2mem = self.getMem2RegFlows()
        mem2reg = self.getReg2MemFlows()
        reg2reg = self.getReg2RegFlows()
        for rm in reg2mem:
            rm.print()
        for mr in mem2reg:
            mr.print()
        for rr in reg2reg:
            rr.print()
        
# interface[layer_1,layer_2] = InterfaceCommunication()
# interface[layer_1,layer_2].insert( RegisterToInputFlow('AX', 0x1234))
# interface[layer_1,layer_2].insert( RegisterToInputFlow('BX', 0x1235))
# interface[layer_1,layer_2].insert( RegisterToInputFlow(0x1236, 'AX'))

A = InterfaceCommunication()
A.insert( RegisterToMemoryFlow("AX",0) )
A.insert( RegisterToMemoryFlow("BX",1) )
A.insert( MemoryToRegisterFlow(2, "AX") )
A.insert( RegisterRenameFlow("register_0", "AX") )
A.print()
# Out:
# M2R flow	2	->	AX
# R2M flow	AX	->	0
# R2M flow	BX	->	1
# R2R flow	register_0	->	AX

# %% [markdown]
# ### Theoretical argument : memory allocation

# %% [markdown]
# Suppose that we have some kind of distance between temporary variables in a <b>matrixmult</b>. <br>
# Therefore we have a collection of distance matrices $\{D_{1,2},D_{2,3},...,D_{N-1,N}\}$ <br>
# We can formulate the following optimization problem <br><br>
# $
#     \text{Find $\{P_{1,2},P_{2,3},...,P_{N-1,N}\}$ permutations of
#     $\{ [1,n_{1,2}], [1,n_{2,3}],... ,[1,n_{N-1,N}] \}$ }
# $ <br>
# $
# \text{such that
#     $D(P_{i,i+1}) \sim D_{i,i+1} \ \ \ \forall i$
# }
# $ <br>
# $
# \text{Subject to
#     $ (P_{i,i+1})_{\text{output (only memory)}} = (P_{i+1,i+2})_{\text{input (only memory)}}  \ \ \forall i$
# }
# $

# %% [markdown]
# ### Proposed algorithm

# %% [markdown]
# $
# \text{$P_0 \leftarrow$ Permutation$(Temp_{\mathcal l,\mathcal l + 1})$ optimal}\\
# \text{${\bf for } \ \ \ i,(layer,layer+1) \in temps $ : } \\
# \hspace{2em} \text{$ P_i \leftarrow $ Permutation$(Temp_{\mathcal l_i,\mathcal l_{i+1}})$ optimal subject to $P_i^{input} = P_{i-1}^{output}$ }
# $

# %% [markdown]
# ### Allocator class

# %%
from sklearn.manifold import MDS
import seaborn as sns

class Allocator:
    def __init__(self, ir, program, register_names):
        self.register_allocation_data = []  # register allocations for every matrix multiplication operation
        self.memory_allocation_data   = []  # memory allocations for every matrix multiplication operation
        self.interfaces               = {}
        self.register_names           = register_names
        self.program                  = program
        # ------------------------------
        # Register allocation subroutine
        
        # compute the usage of each temp
        temp_statistics = self.most_used_temps(ir)   # produces a list of register statistics objects
        
        # 
        self.register_allocation_and_memory_alloc_init(temp_statistics, register_names)
        self.memory_allocation(
                self.compute_signals_distance_matrix(
                    self.compute_signals(ir)
                )
        )
        
    ########################################################################################
    # Input and output masks
    ########################################################################################
    
    def get_input_mapping(self):
        ret = {}
        def is_in_first_layer_input(temp):
            if temp < self.program.topology[0]:
                return True
            return False
        
        for temp in self.register_allocation_data[0].get_data():
            if is_in_first_layer_input(temp):
                ret[temp] = ("reg", self.register_allocation_data[0].get_data()[temp]) 
        
        for temp in self.memory_allocation_data[0].get_data():
            if is_in_first_layer_input(temp):
                ret[temp] = ("mem", 4 * int(self.memory_allocation_data[0].get_data()[temp]))
        return ret
    
    def get_output_mapping(self):
        ret = {}
        def is_in_last_layer_output(temp):
            if temp >= self.program.topology[-2]:
                return True
            return False
        
        for temp in self.register_allocation_data[-1].get_data():
            if is_in_last_layer_output(temp):
                ret[temp - self.program.topology[-2]] = ("reg", self.register_allocation_data[-1].get_data()[temp]) 
        
        for temp in self.memory_allocation_data[-1].get_data():
            if is_in_last_layer_output(temp):
                ret[temp - self.program.topology[-2]] = ("mem", 4 * int(self.memory_allocation_data[-1].get_data()[temp]))
        return ret
    ########################################################################################
    # Register allocation
    ########################################################################################
    
    def most_used_temps(self, ir):
        # IN   : takes as input an intermediate representation
        # OUT  : produces a list of TemporaryVariableStatistics objects, one for each matrix mult
        statistics_per_block = list()
        
        for ir_instruction in ir:                                                            # iterate over the IR statements
            if(ir_instruction.id == "COMMENT"):                                              # 
                if(ir_instruction.sons[0].id == "START"):
                    statistics_per_block.append(TemporaryVariablesStatistics())              # i create a temporaryvariablestatistcs
            else:
                unrolled_ir = ir_instruction.flatten()                                       # unroll the statemenet
                temps_in_statement   = list()                                                # container for temps variables in the current statement
                for u,val in zip(unrolled_ir[:-1],unrolled_ir[1:]):  
                    if u == "TEMP": 
                        temps_in_statement.append(val)                                       
                                                                                             # now "temps_in_statement" contains only the values of the temporary variables
                for t in temps_in_statement:                                                 # count the usage of each temporal 
                    statistics_per_block[-1].increment(t)                                       # the current temporary variable statistics is updated 
        return statistics_per_block
    
    def register_allocation_and_memory_alloc_init(self, statistics_list , register_names):
        # IN  : a statistics list obtained from  most_used_temps , register names
        # OUT : a registerAllocation object
        
        # convert the dictionary to an array
        temp_stats_per_block = list()
        first_block = True
        for stat in statistics_list:
            # I transform the dictitonary in a sorted-by-usage vector
            arr = stat.vectorize()
            #print(arr)
            
            # I initialize a Registerallocation  object
            reg_data = RegisterAllocationData()   
            
            # for every register i take an element, starting from the beginning, of the array
            temp_var_count = 0
            for r_id,r in enumerate(register_names):
                if temp_var_count >= len(arr):
                    break
                if first_block:     # registers are decided a priori only in the first block
                    reg_data.insert(arr[temp_var_count,0],r)                                  # i add as a used register the temporary variables with more usage
                else:
                    reg_data.insert(arr[temp_var_count,0],"register_%d" % r_id)
                temp_var_count += 1
            self.register_allocation_data.append(reg_data)                                    # i append the register allocation data obtained to the list of RAD
            
            # I also initialize the "slots" for the memory allocation data
            mem_data = MemoryAllocationData()                                                 
            for t in range(temp_var_count, len(arr)):
                mem_data.insert(arr[t,0], -1)                                                 # initializa with -1
            self.memory_allocation_data.append(mem_data)                                      # i add them to the list
            first_block = False
        
        ###for r in self.register_allocation_data:
        ###    print("+---------+")
        ###    r.print()
        
        return 0
    
    ########################################################################################
    # Memory allocation
    ########################################################################################

    def compute_signals(self, ir):
        # takes as input an intermediate repr and a register allocation output
        signals_per_block = list()
 
        curr_alloc_block = 0
    
        for ir_instruction in ir:
            if(ir_instruction.id == "COMMENT"):
                if(ir_instruction.sons[0].id == "START"):
                    curr_memory_alloc_block = self.memory_allocation_data[curr_alloc_block]
                    signals_per_block.append(BlockSignals(curr_memory_alloc_block))                       
                    curr_alloc_block += 1

            unrolled_ir = ir_instruction.flatten()
            temps_in_statement   = list()
            for u,val in zip(unrolled_ir[:-1],unrolled_ir[1:]):
                if u == "TEMP":
                    temps_in_statement.append(val)      
                    
            signals_per_block[-1].add_tick(temps_in_statement)
        return signals_per_block
    
    def compute_signals_distance_matrix(self, signals):
        # IN   : takes as input a collection of TempVarSignals
        # OUT  : produces a 
        inverse_mappings = list()
        mappings = list()          # mapping between the rows of the matrix and the temp_var
        Ds = list()                # list of matrices
        
        for signals_block in signals:
            D = np.zeros((len(signals_block.get_data()),len(signals_block.get_data())))
            mapping = {}
            inverse_mapping = {}
            for i,a in enumerate(signals_block.get_data()):
                mapping[i] = a
                inverse_mapping[a] = i
                for j,b in enumerate(signals_block.get_data()):  
                    v_a = np.arange(len(signals_block.get_data()[a]))[np.array(signals_block.get_data()[a]) == 1.]
                    v_b = np.arange(len(signals_block.get_data()[b]))[np.array(signals_block.get_data()[b]) == 1.]
                    distanza = 0.5 * (np.mean([ np.min(np.abs(s_1 - v_b)) for s_1 in v_a]) + np.mean([ np.min(np.abs(s_2 - v_a)) for s_2 in v_b]))
                    D[i,j] = distanza
            Ds.append(D)
            mappings.append(mapping)
            inverse_mappings.append(inverse_mapping)
        return Ds, mappings, inverse_mappings
    
    def anneal(self,
               unconstrainedTemps,     # temporary unconstrained
               addresses,              # list of available memory addresses
               Ds,                     # distance matrix
               inverse_mapping):       # mapping between rows of the distance matrix and temps
        ####print(inverse_mapping)
        # initialize a random association
        
        association = []
        for u,a in zip(unconstrainedTemps,addresses):
            association.append([u,a])
        association = np.array(association)
        
        # nothing to optimize actually...
        if(len(unconstrainedTemps) == 1):
            return association
        
        decay = 1e-3 #decay = 1e-3
        T = 10.
        T_end = 1e-3
        
        inverse_mapping_unconstrained = {}
        for i,u in enumerate(unconstrainedTemps):
            inverse_mapping_unconstrained[u] = i
        
        Ds_unconstrained = Ds[
            [ inverse_mapping[u] for u in unconstrainedTemps], :
        ][ :, [ inverse_mapping[u] for u in unconstrainedTemps]]
        
        
        def build_D_reconstructed(association):
            D_reconstructed = np.zeros(Ds_unconstrained.shape)
            for a in association:
                for b in association:
                    D_reconstructed[inverse_mapping_unconstrained[a[0]], inverse_mapping_unconstrained[b[0]]] = np.abs( a[1] - b[1] )
            return D_reconstructed
        
        def std(M):
            return (M - M.min(axis = 1)[:,None]) / (M.max(axis = 1) - M.min(axis = 1))[:,None]
        
        def cost(association):
            D_reconstructed = build_D_reconstructed(association)
            return np.linalg.norm(
                std(D_reconstructed) - std(Ds_unconstrained)
            )
        # ANNEALING
        
        anneal_iterations = (np.log(T_end) - np.log(T)) / np.log(1 - decay)
        anneal_count = 0
        while T > T_end:
            T = (1. - decay) * T

            mossa            = np.arange(len(association)).astype(int)
            # swap two random
            a = np.random.choice(len(mossa))
            b = np.random.choice(len(mossa))
            tmp = mossa[a]
            mossa[a] = mossa[b]
            mossa[b] = tmp
            new_association      = association.copy()
            new_association[:,1] = association[:,1][mossa]
            
            dE = cost(new_association) - cost(association)
            
            if dE <= 0.:
                association = new_association
            else:
                if( np.random.uniform() > np.exp( - T)):
                    association = new_association
            
            if anneal_count % int( anneal_iterations / 10 ) == 0:
                print("cost = %.2f" % cost(association))
                
            anneal_count += 1
            
        axs = plt.figure(figsize=(10,5)).subplots(1,2).flatten()
        sns.heatmap(  Ds_unconstrained, annot = True, ax = axs[0])
        sns.heatmap( build_D_reconstructed(association), annot = True, ax = axs[1] )
        
        return association
    
    
    
    def density_optimizer_memory_subset_for_output(self,
                                                   memory,
                                                   constrained, 
                                                   m_i,
                                                   unconstrained_temps_size):
        # i get the already allocated addresses
        m_i_on_constraint = [ 
                m_i.get(c)
            for c in constrained
        ]
        ###print("|unconstrained| = %d" % unconstrained_temps_size)
        ###print("constrained addresses = ", m_i_on_constraint)
        memory_mask = np.arange(len(memory))[ [ not(x in m_i_on_constraint ) for x in np.arange(len(memory))] ]
        ###print("MEMORY MASK =" , memory_mask)
        
        rows = list()
        densities = list()
        
        for j in range( len(memory) - len(m_i_on_constraint) - unconstrained_temps_size + 1):
            row = np.zeros(len(memory))
            
            for mem_add_const in m_i_on_constraint:
                row[mem_add_const] = -1.
            
            row[memory_mask[j:j+unconstrained_temps_size]] = 1.
            
            density = lambda r : (r != 0 )[ (r != 0).argmax() : (len(r) - (r != 0)[-1::-1].argmax())].mean()
            rows.append(row)
            densities.append(density(row))
            
        if(len(rows) == 1):
            return memory[rows[0] > 0.]
        else:
            densities = np.array(densities)
            rows      = np.array(rows)
            #plt.figure()
            #plt.imshow(rows)
            # choose the best
            # among the maximal densities
            ###print("@@@",rows)
            ###print("###",densities)
            ###print("***",densities == densities.max())
            available_configurations = rows[densities == densities.max()]
            # choose the one where the first unconstrained address is closer to the last constrained address
            ###print(available_configurations)
            configuration = available_configurations[0]
            for a in available_configurations:
                first_one     = configuration.argmax()
                last_minusone = len(configuration) - configuration[-1::-1].argmax() 
                distance_conf = np.abs(last_minusone - first_one)

                afirst_one     = a.argmax()
                alast_minusone = len(a) - a[-1::-1].argmax()
                adistance_conf = np.abs(alast_minusone - afirst_one)
                
                if adistance_conf < distance_conf:
                    configuration = a


            ####print("CHOSEN = ", configuration)
            ####print( m_i_on_constraint )
            ####print( memory[configuration > 0.] )
            return memory[configuration > 0.]
        

####################################################################################################################
#####                  #############################################################################################
#####   huge function  #############################################################################################
#####                  #############################################################################################
####################################################################################################################

    def memory_allocation(self, DS_MAPPINGS):
        
                   

        
        # i define a fake memory just for debug
        memory = np.arange(
            np.max(
                [
                       np.max(len(m.get_variables_list()))
                    for m in self.memory_allocation_data 
                ]
            )
        )
        
        ####print("MEMORY = ", memory)
        ####print("\nMEM ALLOC DATA [len DS = %d]\n" % len(DS_MAPPINGS[0]))
        
        # compute m1
        # every memory temp is an unconstrained temp
        print("\tMatrix Multiplication %d" % 0)
        T_mem_1       = self.memory_allocation_data[0].get_variables_list()
        mem_addresses = np.arange(0, len(T_mem_1))
        Ds_1                      = DS_MAPPINGS[0][0]
        mapping_1                 = DS_MAPPINGS[1][0]
        inverse_mapping_1         = DS_MAPPINGS[2][0]
        # optimize the                 
        if len(T_mem_1) > 0:
            print("Optimizing memory allocation of unconstrained temps...")
            temp_addr_mapping = self.anneal( T_mem_1, 
                                        mem_addresses,
                                        Ds_1,
                                        inverse_mapping_1
                                      )
            for mappa in temp_addr_mapping:
                self.memory_allocation_data[0].insert(
                    mappa[0],
                    mappa[1]
                )
        
        T                       =  np.arange( self.program.topology[0] + self.program.topology[1] )
        T_in_curr, T_out_curr   = T_in_prev , T_out_prev  =  set(T[T < self.program.topology[0]]) , set(T[T >= self.program.topology[0]])
        T_mem_curr, T_reg_curr  = T_mem_prev , T_reg_prev =  set(self.memory_allocation_data[0].get_variables_list()), set(self.register_allocation_data[0].get_variables_list())
        

        for i in range(1, len(DS_MAPPINGS[0]) ): 
            print("\n\tMatrix Multiplication %d" % i)
            ##############
            
            T                       = np.arange( self.program.topology[i] + self.program.topology[i + 1] )
            # Define the IO partition
            T_in_curr , T_out_curr  = set(T[T < self.program.topology[i]]) , set(T[T >= self.program.topology[i]])
            # Define the MR partition
            T_mem_curr , T_reg_curr = set(self.memory_allocation_data[i].get_variables_list()), set(self.register_allocation_data[i].get_variables_list())    
        
            ### Define the mappings when the input is batch
            
            # define the mapping from curr input to previous layer output
            phi_inv      = lambda t_in_curr  : set((len(T_in_prev) + np.array(list(t_in_curr))))
            # define the mapping from previous layer output to curr input
            phi          = lambda t_out_prev : set((np.array(list(t_out_prev)) - len(T_in_prev)))
            
            ### Redefine the mapping when the input is single
            # define the mapping from curr input to previous layer output
            single_phi_inv      = lambda t_in_curr  : len(T_in_prev) + t_in_curr
            # define the mapping from previous layer output to curr input
            single_phi          = lambda t_out_prev : t_out_prev - len(T_in_prev)
            
            
            # define the flows
            self.interfaces[i-1,i] = InterfaceCommunication()
           
            # FreeRegisters
            freeRegisters = set()
            for r in self.register_names:
                freeRegisters.add(r)
            ####print(freeRegisters)
            
            
            # if some output stays in registers when it becomes input we dont want to move it
            for t in T_in_curr.intersection(T_reg_curr):
                if single_phi_inv(t) in ( T_out_prev.intersection(T_reg_prev)):
                    r  = self.register_allocation_data[i - 1].get(
                                                               single_phi_inv(t)
                                                           )
                    self.register_allocation_data[i].insert(t, 
                                                            r
                                                           )
                    freeRegisters.remove(r)
                    
            # from memory to registers
            for t in T_in_curr.intersection(T_reg_curr):
                if single_phi_inv(t) in T_out_prev.intersection(T_mem_prev):
                    r = list(freeRegisters)[0]
                    self.register_allocation_data[i].insert(t, r)
                    freeRegisters.remove(r)
                    self.interfaces[i-1,i].insert(
                        MemoryToRegisterFlow(
                            self.memory_allocation_data[i - 1].get(single_phi_inv(t)),
                            r
                        )
                    )
                    
            # outputs that go into registers
            for t in T_out_curr.intersection(T_reg_curr):
                r = list(freeRegisters)[0]
                self.register_allocation_data[i].insert(t, r)
                freeRegisters.remove(r)
            
            
            # Memory
            
            UnconstrainedTemps = T_mem_curr.copy()
            ConstrainedTemps   = set()
            
            for t in T_in_curr.intersection(T_mem_curr):
                if single_phi_inv(t) in T_out_prev.intersection(T_mem_prev):
                    self.memory_allocation_data[i].insert( 
                        t , 
                        self.memory_allocation_data[i - 1].get(single_phi_inv(t))
                    )       
                    UnconstrainedTemps.remove(t)
                    ConstrainedTemps.add(t)
                    
            if len(UnconstrainedTemps) > 0:
                print("Optimizing memory allocation of unconstrained temps...")
                
                MemoryAddressImageOfMi = self.density_optimizer_memory_subset_for_output(
                    memory,                           # memory object
                    ConstrainedTemps,                 # set temporaries that are constrained
                    self.memory_allocation_data[i],   # funzione m_i
                    len(UnconstrainedTemps)           # length of the unconstrained temps to place  
                ) # returns a list of addresses that suit the unconstrained variables

                
                Ds              = DS_MAPPINGS[0][i]
                mapping         = DS_MAPPINGS[1][i]
                inverse_mapping = DS_MAPPINGS[2][i]
                
            
                temp_addr_mapping = self.anneal(    UnconstrainedTemps, 
                                                    MemoryAddressImageOfMi,
                                                    Ds,
                                                    inverse_mapping
                                                  )
                for a in temp_addr_mapping:
                    self.memory_allocation_data[i].insert(a[0],a[1])
            
            
            for t in T_in_curr.intersection(T_mem_curr):
                if single_phi_inv(t) in T_out_prev.intersection(T_reg_prev):
                    self.interfaces[i-1,i].insert(
                        RegisterToMemoryFlow(
                            self.register_allocation_data[i-1].get(
                                single_phi_inv(t)
                            ),
                            self.memory_allocation_data[i].get(t)
                        )
                    )
            
            
            # save the previous partitions
            T_in_prev , T_out_prev   = T_in_curr  , T_out_curr  
            T_mem_prev , T_reg_prev  = T_mem_curr , T_reg_curr

# %% [markdown]
# ## Code generator

# %% [markdown]
# ## Assembler

# %% [markdown]
# ## Orchestrator function

# %% [markdown]
# ### Interface manager

# %%
import networkx as nx
def interfaces_manager(interface,buffer_register_1):
    global ret_
    ret_   = ""
    def codeprint_function(stringa):
        global ret_
        ret_ += stringa + "\n"
    
    
    G = nx.DiGraph()
    selectable_registers = set()
    for r2m in interface.getReg2MemFlows():
        G.add_edge("reg_" + str(r2m.register), "mem_" + str(r2m.mem_address))
        G.nodes["mem_" + str(r2m.mem_address)]['in'] = "reg_" + str(r2m.register)
        G.nodes["reg_" + str(r2m.register)  ]['out'] = "mem_" + str(r2m.mem_address) 
        
        selectable_registers.add("reg_" + str(r2m.register))
        
    for m2r in interface.getMem2RegFlows():
        G.add_edge("mem_" + str(m2r.mem_address),"reg_" + str(m2r.register))
        
        G.nodes["mem_" + str(m2r.mem_address)]['out'] = "reg_" + str(m2r.register)
        G.nodes["reg_" + str(m2r.register)  ]['in'] = "mem_" + str(m2r.mem_address) 
        
        selectable_registers.add("reg_" + str(m2r.register))

    plt.figure()
    pos = nx.spring_layout(G, k=0.15, iterations=100)
    nx.draw(G, pos = pos, with_labels = True, node_size = 100)

    # until no more selectable registers
    while len(selectable_registers) > 0:
    #   head <- select a random SELECTABLE register (each thread or loop contains AT LEAST ONE register by the way flows are defined)
        head_id = list(selectable_registers)[0]
        selectable_registers.remove(head_id)
        head    = G.nodes[head_id]
        
    #   cursor <- head
        cursor_id = head_id
        cursor    = head
        
    #   while cursor != head AND cursor != NIL
        
        if cursor.get("out") != None:
            cursor_id = cursor.get("out")
            cursor = G.nodes[cursor_id]
            
            while cursor != head:
        #       cursor <- cursor.next
                if cursor.get("out") != None:
                    cursor_id = cursor.get("out")
                    cursor    = G.nodes[cursor_id]
                else:
                    break
    # 
    #   if cursor.next = NIL
        if cursor.get('out') == None:
    #       // this is a thread
    #       while cursor.prev.prev != NIL
            while G.nodes.get(cursor.get("in"))  != None:
                cursor_father_id = cursor.get("in")
                
                if cursor_id in selectable_registers:
                        selectable_registers.remove(cursor_id)
                if cursor_father_id in selectable_registers:
                        selectable_registers.remove(cursor_father_id)
                        
    #           codeprint [ move data from cursor.prev to cursor ]
                    
                # if source is register
                if cursor_father_id.startswith("reg_"):
                    register = cursor_father_id.split("_")[1]
                    address  = 4 * int(cursor_id.split("_")[1])
                    # // dest is memory
                    codeprint_function("FSTS %s,[r7,#%s]" %  (register, address))
                # if source is memory
                else:
                    # // dest is register
                    register  = cursor_id.split("_")[1]
                    address = 4 * int(cursor_father_id.split("_")[1])
                    codeprint_function("FLDS %s,[r7,#%s]" %  (register, address))
    #           cursor = cursor.prev
                cursor_id = cursor.get("in")
                cursor    = G.nodes[cursor_id]
        else:
    #       // this is a loop
    #       codeprint [ copy head into BUFFER_REGISTER_1] // head_copy
            ### codeprint_function("# move from %s to %s" % (head_id , "BUFFER_REGISTER_1"))
            register = head_id.split("_")[1]
            codeprint_function("VMOV.F32 %s,%s" % (buffer_register_1 , register))
    #       cursor <- head // asserted by the if
    #       while cursor.prev != head
            while cursor.get("in") != head_id:
    #           if cursors is a register
    #                cursor.selectable = False
                codeprint_function("#printing %s" % cursor_id)
                cursor_father_id = cursor.get("in")
                
                if cursor_id in selectable_registers:
                        selectable_registers.remove(cursor_id)
                if cursor_father_id in selectable_registers:
                        selectable_registers.remove(cursor_father_id)
    #           codeprint [ move data from cursor.prev to cursor ]    
                # if source is register
                if cursor_father_id.startswith("reg_"):
                    register = cursor_father_id.split("_")[1]
                    address  = 4 * int(cursor_id.split("_")[1])
                    # // dest is memory
                    codeprint_function("FSTS %s,[r7,#%s]" %  (register, address))
                # if source is memory
                else:
                    # // dest is register
                    register  = cursor_id.split("_")[1]
                    address = 4 * int(cursor_father_id.split("_")[1])
                    codeprint_function("FLDS %s,[r7,#%s]" %  (register, address))
    #           cursor = cursor.prev
                cursor_id = cursor.get("in")
                cursor    = G.nodes[cursor_id]
    #       codeprint [ copy BUFFER_REGISTER_1 into cursor] // head_copy
            ###codeprint_function("# move from %s to %s" % ("BUFFER_REGISTER_1", cursor_id))
            register = cursor_id.split("_")[1]
            codeprint_function("VMOV.F32 %s,%s" % (register, buffer_register_1))    
    nx.draw(G, pos = pos, with_labels = True, node_size = 100)
    return ret_[:-1]

# %% [markdown]
# ### Compiler + Compilazione di una rete ($\star$)

# %%
import struct
def compiler(rete, registers, sparsify = False, r7offset = 0):
    

    global ret
    ret   = ""
    def codeprint(stringa):
        global ret
        ret += stringa + "\n"
    
    reg_0 = registers[0]
    reg_1 = registers[1]
    
    # debug, we don't actually read a file but we generate it randomly
    #rete = Program([10,30,30,2], ["RELU","RELU","LINEAR"])
    #rete.random_init_weights()
    intermediate_representation = IR(rete)
    for i in intermediate_representation:
        print(i.flatten())
    
    allocator   = Allocator(intermediate_representation , rete , registers[3:])
    input_mask  = allocator.get_input_mapping()    # dictionary that maps inputs entries to registers/memory units
    output_mask = allocator.get_output_mapping()   # dictionary that maps outputs entries to register/memory units
    
    
    
    
    asm_code = []
    
    zero_register     = registers[0]
    buffer_register_1 = registers[1]
    buffer_register_2 = registers[2]
    codeprint("MOV r7, %d \t ; # address offset" % r7offset)
    codeprint("VSUB.F32 %s,%s,%s \t ; # initalize the zero register"
         % (
             zero_register,
             zero_register,
             zero_register
         )
         )
    
    #for m in allocator.memory_allocation_data:
    #    m.print()
    #    print("----")
    
    cursor_allocator = 0
    label_counter = 0
    
    for ir_statement in intermediate_representation:
        flattened = ir_statement.flatten()
        #print(flattened)
        if(flattened[0] == "COMMENT"):
            if(flattened[1] == "END"):
                #print("\n # NUOVO BLOCCO \n")
                codeprint("######################################## HERE GOES THE INTERFACE")
                if (cursor_allocator) < len(allocator.interfaces):
                    codeprint("# LEGGO L'INTERFACCIA [%d,%d]" % (cursor_allocator, cursor_allocator + 1))
                    interfaccia = allocator.interfaces[cursor_allocator, cursor_allocator + 1]

                    codeprint( interfaces_manager(interfaccia,buffer_register_1) )

                    #interfaccia.print()
                cursor_allocator += 1
        
        if(flattened[0] == "MOVE" 
           and 
           flattened[3] == "CONST"
          ): # set the temporary variable
            tmp_name =  flattened[2]
            val       = flattened[4]
            # we have to understand if tmp_name is a register or not
            if(allocator.register_allocation_data[cursor_allocator].contains(tmp_name)):
                # variable is in registers
                register = allocator.register_allocation_data[cursor_allocator].get_data()[tmp_name]
                #print("MOV TO $%s THE VALUE #%f" % (
                #      register,
                #      val)
                #     )
                codeprint("VMOV.F32 %s, %s\t ; # set the register to 0 " % (register,zero_register))
            else:
                # variable is in memory
                address = 4 * allocator.memory_allocation_data[cursor_allocator].get_data()[tmp_name]
                #print("STORE THE VALUE 0 IN ADDRESS %d" % address)
                codeprint("FSTS %s, [r7,#%d]" % (zero_register,address) )
                
                
        if(flattened[0] == "MOVE"
           and
           flattened[3] == "BINOP"
           and 
           len(flattened ) == 13
          ): # addition and multiply
            neuron_dest   = flattened[2]
            neuron_source = flattened[12]
            weight        = flattened[10]
            
            
            if(allocator.register_allocation_data[cursor_allocator].contains(neuron_source)):
                register = allocator.register_allocation_data[cursor_allocator].get_data()[neuron_source]
                weight_bytes = struct.pack('f', weight)
                weight_bytes_upper = struct.unpack('H',weight_bytes[:2])
                weight_bytes_lower = struct.unpack('H',weight_bytes[2:])
                
                codeprint("MOVW r1,#%d \t ; # move the most significative bits in r3" % weight_bytes_upper[0])
                codeprint("MOVT r1,#%d \t ; # move the least significative bits in r3" % weight_bytes_lower[0])
                codeprint("VMOV.F32 %s,r1 \t ; # copy r3 in buffer_register_1" % (buffer_register_1))
                codeprint("VMUL.F32 %s,%s,%s \t ; # save in buffer_register_2 the multiplication " % (
                        buffer_register_2,
                        buffer_register_1,
                        register
                ))
                #print("MULT $%s BY #%f AND SAVE IT IN $%s" % (
                #      allocator.register_allocation_data[cursor_allocator].get_data()[neuron_source],
                #      weight,
                #      reg_0)
                #     )
            else:
                # variable is in memory
                address = 4 * allocator.memory_allocation_data[cursor_allocator].get_data()[neuron_source]
                weight_bytes = struct.pack('f', weight)
                weight_bytes_upper = struct.unpack('H',weight_bytes[:2])
                weight_bytes_lower = struct.unpack('H',weight_bytes[2:])
                
                codeprint("FLDS %s,[r7, #%d] \t ; # copy the value in the address on the buffer_register_2" % (buffer_register_2, address))
                codeprint("MOVW r1,#%d \t ; # move the most significative bits in r3" % weight_bytes_upper[0])
                codeprint("MOVT r1,#%d \t ; # move the least significative bits in r3" % weight_bytes_lower[0])
                codeprint("VMOV.F32 %s,r1 \t ; # copy r3 in buffer_register_1" % (buffer_register_1))
                codeprint("VMUL.F32 %s,%s,%s \t ; # save in buffer_register_2 the multiplication " % (
                        buffer_register_2,
                        buffer_register_1,
                        buffer_register_2
                ))    
                #print("LOAD IN REGISTER $%s THE ADDRESS %d"  % (
                #            reg_0,
                #            allocator.memory_allocation_data[cursor_allocator].get_data()[neuron_source])
                #     )
                #print("MULT $%s BY #%f AND SAVE IT IN $%s" % (
                #      reg_0,
                #      weight,
                #      reg_0
                #      )
                 #    )
                    
            # NOW BUFFER_REGISTER_2 CONTAINS weight * input
        
            if(allocator.register_allocation_data[cursor_allocator].contains(neuron_dest)):
                #print("ADD $%s to $%s" % (
                #      reg_0,
                #      allocator.register_allocation_data[cursor_allocator].get_data()[neuron_dest])
                #     )
                
                # dest += weight * input
                codeprint("VADD.F32 %s,%s,%s \t ; # " %( 
                    allocator.register_allocation_data[cursor_allocator].get_data()[neuron_dest],
                    buffer_register_2,
                    allocator.register_allocation_data[cursor_allocator].get_data()[neuron_dest]))
                
            else:
                # variable is in memory
                address = 4 * allocator.memory_allocation_data[cursor_allocator].get_data()[neuron_dest]
                #print("LOAD IN REGISTER $ %s THE ADDRESS %d" % (reg_1,address) )               
                codeprint("FLDS %s,[r7, #%d] \t ; # load the content of the output neuron in buffer_register_1 " % (buffer_register_1, address))
                codeprint("VADD.F32 %s,%s,%s \t ; # buffer_register_1 += weight * input"  % (buffer_register_1, buffer_register_2, buffer_register_1))
                codeprint("FSTS %s,[r7, #%d] " % (buffer_register_1, address))
                
        if(flattened[0] == "MOVE"
           and
           flattened[1] == "CALL"
          ): # adding the bias and applying the activation function
            
            tmp_name = flattened[4]  # name of the temporary variable
            f_name   = flattened[2]  # name of the activation function
            bias     = flattened[-1] # bias
            
            if(allocator.register_allocation_data[cursor_allocator].contains(tmp_name)):
                # the variable is in a register
                register = allocator.register_allocation_data[cursor_allocator].get_data()[tmp_name]
                #print("ADD TO $%s VALUE #%f " %
                #             (
                #                 register,
                #                 bias
                #             )
                #         )              
                
                register = allocator.register_allocation_data[cursor_allocator].get_data()[tmp_name]
                bias_bytes = struct.pack('f', bias)
                bias_bytes_upper = struct.unpack('H',bias_bytes[:2])
                bias_bytes_lower = struct.unpack('H',bias_bytes[2:])
                
                codeprint("MOVW r1,#%d \t ; # move the most significative bits in r3" % bias_bytes_upper[0])
                codeprint("MOVT r1,#%d \t ; # move the least significative bits in r3" % bias_bytes_lower[0])
                codeprint("VMOV.F32 %s,r1 \t ; # copy r3 in buffer_register_1" % (buffer_register_1))
                codeprint("VADD.F32 %s,%s,%s \t ; # add the bias" % (
                        register,
                        buffer_register_1,
                        register
                ))
                
                
                if f_name == 'RELU':
                    #the function is RELU
                    #print("GTZ $%s TO $%s" %   # if greater than 0 save 1 in $0 else 0 in $0
                    #         (
                    #             register,
                    #             reg_0
                    #         )
                    #     )
                    #print("MULT $%s, $%s, $%s" %
                    #         (
                    #             register,
                    #             reg_0,
                    #             register
                    #         )
                    #     )
                    codeprint("# RELU")
                    codeprint("vcmpe.f32  %s, #0 ; \t # compare the register with 0  " % (register))
                    codeprint("vmrs    APSR_nzcv, FPSCR ")
                    codeprint("bgt     .L%d" % (label_counter) )
                    codeprint(".ANTIL%d:" % label_counter)
                    codeprint("vmsr fpexc, r3")
                    codeprint("VMOV.F32 %s,%s  ; \t # put the value to 0 if less than 0" % (register,zero_register))
                    codeprint(".L%d: " % (label_counter))
                    codeprint("vmsr fpexc, r3")
                    label_counter += 1
                    
                if f_name == 'LINEAR':
                    #the function is Linear activation  function
                    0 # do nothing 
            else:
                # the variable is in memory
                address = 4 * allocator.memory_allocation_data[cursor_allocator].get_data()[tmp_name]
                bias_bytes = struct.pack('f', bias)
                bias_bytes_upper = struct.unpack('H',bias_bytes[:2])
                bias_bytes_lower = struct.unpack('H',bias_bytes[2:])
                
                #print("LOAD ADDRESS #%d INTO REGISTER $%s " %
                # (
                #     address,
                #     reg_1
                # )
                #)
                codeprint("FLDS %s,[r7, #%d] \t ; # load the content of the output neuron in buffer_register_2 " % (buffer_register_2, address))
                codeprint("MOVW r1,#%d \t ; # move the most significative bits in r3" % bias_bytes_upper[0])
                codeprint("MOVT r1,#%d \t ; # move the least significative bits in r3" % bias_bytes_lower[0])
                codeprint("VMOV.F32 %s,r1 \t ; # copy r3 in buffer_register_1" % (buffer_register_1))
                codeprint("VADD.F32 %s,%s,%s \t ; # add the bias" % (
                        buffer_register_2,
                        buffer_register_1,
                        buffer_register_2
                ))
                
                #print("ADDI $%s,$%s,#%f" %
                #      (
                #          reg_1,
                #          reg_1,
                #          bias
                #      ))
                if f_name == 'RELU':
                    #the function is RELU
                    #print("GTZ $%s TO $%s" %   # if greater than 0 save 1 in $0 else 0 in $0
                    #         (
                    #             reg_1,
                    #             reg_0
                    #         )
                    #     )
                    #print("MULT $%s, $%s, $%s" %
                    #         (
                    #             reg_1,
                    #             reg_0,
                    #             reg_1
                    #         )
                    #     )
                    codeprint("# RELU")
                    codeprint("vcmpe.f32  %s, #0 ; \t # compare the register with 0  " % (buffer_register_2))
                    codeprint("vmrs    APSR_nzcv, FPSCR ")
                    codeprint("bgt     .L%d" % (label_counter) )
                    codeprint(".ANTIL%d:" % label_counter)
                    codeprint("vmsr fpexc, r3")
                    codeprint("VMOV.F32 %s,%s  ; \t # put the value to 0 if less than 0" % (buffer_register_2,zero_register))
                    codeprint(".L%d: " % (label_counter))
                    codeprint("vmsr fpexc, r3")
                    label_counter += 1
                    
                if f_name == 'LINEAR':
                    #the function is Linear activation  function
                    0
                
                #print("STORE  $%s  INTO ADDRESS #%d" %
                # (
                #     reg_1,
                #     address
                # )
                #)
                codeprint("FSTS %s,[r7, #%d] " % (buffer_register_2, address))
    return ret, input_mask, output_mask

rete = Program([10,30,30,2], ["RELU","RELU","LINEAR"])
rete.random_init_weights()
codice, input_mask, output_mask = compiler(rete, [ 's' + str(i) for i in range(16)] , r7offset = 0x1000000)
print(codice)
# Out:
# ['COMMENT', 'START']
# ['MOVE', 'TEMP', 10, 'CONST', 0]
# ['MOVE', 'TEMP', 11, 'CONST', 0]
# ['MOVE', 'TEMP', 12, 'CONST', 0]
# ['MOVE', 'TEMP', 13, 'CONST', 0]
# ['MOVE', 'TEMP', 14, 'CONST', 0]
# ['MOVE', 'TEMP', 15, 'CONST', 0]
# ['MOVE', 'TEMP', 16, 'CONST', 0]
# ['MOVE', 'TEMP', 17, 'CONST', 0]
# ['MOVE', 'TEMP', 18, 'CONST', 0]
# ['MOVE', 'TEMP', 19, 'CONST', 0]
# ['MOVE', 'TEMP', 20, 'CONST', 0]
# ['MOVE', 'TEMP', 21, 'CONST', 0]
# ['MOVE', 'TEMP', 22, 'CONST', 0]
# ['MOVE', 'TEMP', 23, 'CONST', 0]
# ['MOVE', 'TEMP', 24, 'CONST', 0]
# ['MOVE', 'TEMP', 25, 'CONST', 0]
# ['MOVE', 'TEMP', 26, 'CONST', 0]
# ['MOVE', 'TEMP', 27, 'CONST', 0]
# ['MOVE', 'TEMP', 28, 'CONST', 0]
# ['MOVE', 'TEMP', 29, 'CONST', 0]
# ['MOVE', 'TEMP', 30, 'CONST', 0]
# ['MOVE', 'TEMP', 31, 'CONST', 0]
# ['MOVE', 'TEMP', 32, 'CONST', 0]
# ['MOVE', 'TEMP', 33, 'CONST', 0]
# ['MOVE', 'TEMP', 34, 'CONST', 0]
# ['MOVE', 'TEMP', 35, 'CONST', 0]
# ['MOVE', 'TEMP', 36, 'CONST', 0]
# ['MOVE', 'TEMP', 37, 'CONST', 0]
# ['MOVE', 'TEMP', 38, 'CONST', 0]
# ['MOVE', 'TEMP', 39, 'CONST', 0]
# ['MOVE', 'TEMP', 10, 'BINOP', 'ADD', 'TEMP', 10, 'BINOP', 'MUL', 'CONST', 0.2061732212563508, 'TEMP', 1]
# ['MOVE', 'TEMP', 10, 'BINOP', 'ADD', 'TEMP', 10, 'BINOP', 'MUL', 'CONST', 1.630612101506088, 'TEMP', 3]
# ['MOVE', 'TEMP', 10, 'BINOP', 'ADD', 'TEMP', 10, 'BINOP', 'MUL', 'CONST', 1.5071209057786168, 'TEMP', 5]
# ['MOVE', 'TEMP', 10, 'BINOP', 'ADD', 'TEMP', 10, 'BINOP', 'MUL', 'CONST', 1.9599755208287637, 'TEMP', 6]
# ['MOVE', 'TEMP', 10, 'BINOP', 'ADD', 'TEMP', 10, 'BINOP', 'MUL', 'CONST', 0.6231285275585343, 'TEMP', 7]
# ['MOVE', 'TEMP', 11, 'BINOP', 'ADD', 'TEMP', 11, 'BINOP', 'MUL', 'CONST', 0.1703378383852727, 'TEMP', 2]
# ['MOVE', 'TEMP', 11, 'BINOP', 'ADD', 'TEMP', 11, 'BINOP', 'MUL', 'CONST', 0.1293046372866427, 'TEMP', 4]
# ['MOVE', 'TEMP', 12, 'BINOP', 'ADD', 'TEMP', 12, 'BINOP', 'MUL', 'CONST', 0.21245973129287232, 'TEMP', 2]
# ['MOVE', 'TEMP', 13, 'BINOP', 'ADD', 'TEMP', 13, 'BINOP', 'MUL', 'CONST', 0.6630862320224179, 'TEMP', 3]
# ['MOVE', 'TEMP', 13, 'BINOP', 'ADD', 'TEMP', 13, 'BINOP', 'MUL', 'CONST', 0.28269015029331945, 'TEMP', 4]
# ['MOVE', 'TEMP', 13, 'BINOP', 'ADD', 'TEMP', 13, 'BINOP', 'MUL', 'CONST', 0.6027999873362676, 'TEMP', 5]
# ['MOVE', 'TEMP', 13, 'BINOP', 'ADD', 'TEMP', 13, 'BINOP', 'MUL', 'CONST', 4.155579895838087, 'TEMP', 8]
# ['MOVE', 'TEMP', 13, 'BINOP', 'ADD', 'TEMP', 13, 'BINOP', 'MUL', 'CONST', 0.02532039992099252, 'TEMP', 9]
# ['MOVE', 'TEMP', 14, 'BINOP', 'ADD', 'TEMP', 14, 'BINOP', 'MUL', 'CONST', 1.9602827664363938, 'TEMP', 2]
# ['MOVE', 'TEMP', 14, 'BINOP', 'ADD', 'TEMP', 14, 'BINOP', 'MUL', 'CONST', 0.07797268941228576, 'TEMP', 3]
# ['MOVE', 'TEMP', 14, 'BINOP', 'ADD', 'TEMP', 14, 'BINOP', 'MUL', 'CONST', 2.1961290458707423, 'TEMP', 4]
# ['MOVE', 'TEMP', 14, 'BINOP', 'ADD', 'TEMP', 14, 'BINOP', 'MUL', 'CONST', 0.12210131557431465, 'TEMP', 8]
# ['MOVE', 'TEMP', 15, 'BINOP', 'ADD', 'TEMP', 15, 'BINOP', 'MUL', 'CONST', 4.618764147755701, 'TEMP', 3]
# ['MOVE', 'TEMP', 15, 'BINOP', 'ADD', 'TEMP', 15, 'BINOP', 'MUL', 'CONST', 0.3798019571144842, 'TEMP', 4]
# ['MOVE', 'TEMP', 15, 'BINOP', 'ADD', 'TEMP', 15, 'BINOP', 'MUL', 'CONST', 0.1209082116862158, 'TEMP', 5]
# ['MOVE', 'TEMP', 16, 'BINOP', 'ADD', 'TEMP', 16, 'BINOP', 'MUL', 'CONST', 0.11183561176366735, 'TEMP', 2]
# ['MOVE', 'TEMP', 16, 'BINOP', 'ADD', 'TEMP', 16, 'BINOP', 'MUL', 'CONST', 0.20374161916552896, 'TEMP', 7]
# ['MOVE', 'TEMP', 16, 'BINOP', 'ADD', 'TEMP', 16, 'BINOP', 'MUL', 'CONST', 2.552271517027553, 'TEMP', 9]
# ['MOVE', 'TEMP', 17, 'BINOP', 'ADD', 'TEMP', 17, 'BINOP', 'MUL', 'CONST', 0.35612409920406307, 'TEMP', 8]
# ['MOVE', 'TEMP', 17, 'BINOP', 'ADD', 'TEMP', 17, 'BINOP', 'MUL', 'CONST', 0.1983391246504129, 'TEMP', 9]
# ['MOVE', 'TEMP', 18, 'BINOP', 'ADD', 'TEMP', 18, 'BINOP', 'MUL', 'CONST', 1.0833086419860731, 'TEMP', 0]
# ['MOVE', 'TEMP', 18, 'BINOP', 'ADD', 'TEMP', 18, 'BINOP', 'MUL', 'CONST', 1.394975247010524, 'TEMP', 1]
# ['MOVE', 'TEMP', 18, 'BINOP', 'ADD', 'TEMP', 18, 'BINOP', 'MUL', 'CONST', 1.3052329910457912, 'TEMP', 5]
# ['MOVE', 'TEMP', 18, 'BINOP', 'ADD', 'TEMP', 18, 'BINOP', 'MUL', 'CONST', 0.1818447435652785, 'TEMP', 6]
# ['MOVE', 'TEMP', 18, 'BINOP', 'ADD', 'TEMP', 18, 'BINOP', 'MUL', 'CONST', 2.9956412731034385, 'TEMP', 7]
# ['MOVE', 'TEMP', 19, 'BINOP', 'ADD', 'TEMP', 19, 'BINOP', 'MUL', 'CONST', 2.3055932337960288, 'TEMP', 1]
# ['MOVE', 'TEMP', 19, 'BINOP', 'ADD', 'TEMP', 19, 'BINOP', 'MUL', 'CONST', 0.7400018862968838, 'TEMP', 4]
# ['MOVE', 'TEMP', 19, 'BINOP', 'ADD', 'TEMP', 19, 'BINOP', 'MUL', 'CONST', 0.5446140824574708, 'TEMP', 5]
# ['MOVE', 'TEMP', 19, 'BINOP', 'ADD', 'TEMP', 19, 'BINOP', 'MUL', 'CONST', 7.845666985230501, 'TEMP', 8]
# ['MOVE', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'BINOP', 'MUL', 'CONST', 0.8272503164218068, 'TEMP', 0]
# ['MOVE', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'BINOP', 'MUL', 'CONST', 4.928871726870301e-07, 'TEMP', 4]
# ['MOVE', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'BINOP', 'MUL', 'CONST', 4.615041205310452, 'TEMP', 5]
# ['MOVE', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'BINOP', 'MUL', 'CONST', 1.6302737401424185, 'TEMP', 6]
# ['MOVE', 'TEMP', 21, 'BINOP', 'ADD', 'TEMP', 21, 'BINOP', 'MUL', 'CONST', 0.27732936877940745, 'TEMP', 0]
# ['MOVE', 'TEMP', 21, 'BINOP', 'ADD', 'TEMP', 21, 'BINOP', 'MUL', 'CONST', 0.03317651333164718, 'TEMP', 2]
# ['MOVE', 'TEMP', 21, 'BINOP', 'ADD', 'TEMP', 21, 'BINOP', 'MUL', 'CONST', 0.001956158095002134, 'TEMP', 3]
# ['MOVE', 'TEMP', 21, 'BINOP', 'ADD', 'TEMP', 21, 'BINOP', 'MUL', 'CONST', 2.6692370022829675, 'TEMP', 4]
# ['MOVE', 'TEMP', 21, 'BINOP', 'ADD', 'TEMP', 21, 'BINOP', 'MUL', 'CONST', 0.913365487995825, 'TEMP', 5]
# ['MOVE', 'TEMP', 21, 'BINOP', 'ADD', 'TEMP', 21, 'BINOP', 'MUL', 'CONST', 4.341530353565347, 'TEMP', 7]
# ['MOVE', 'TEMP', 21, 'BINOP', 'ADD', 'TEMP', 21, 'BINOP', 'MUL', 'CONST', 0.07422377937491308, 'TEMP', 8]
# ['MOVE', 'TEMP', 22, 'BINOP', 'ADD', 'TEMP', 22, 'BINOP', 'MUL', 'CONST', 0.9432538527603499, 'TEMP', 1]
# ['MOVE', 'TEMP', 22, 'BINOP', 'ADD', 'TEMP', 22, 'BINOP', 'MUL', 'CONST', 2.0723745694184674, 'TEMP', 2]
# ['MOVE', 'TEMP', 22, 'BINOP', 'ADD', 'TEMP', 22, 'BINOP', 'MUL', 'CONST', 0.0007393471423265945, 'TEMP', 5]
# ['MOVE', 'TEMP', 22, 'BINOP', 'ADD', 'TEMP', 22, 'BINOP', 'MUL', 'CONST', 0.2904953987329622, 'TEMP', 6]
# ['MOVE', 'TEMP', 22, 'BINOP', 'ADD', 'TEMP', 22, 'BINOP', 'MUL', 'CONST', 1.1240231575622763, 'TEMP', 7]
# ['MOVE', 'TEMP', 23, 'BINOP', 'ADD', 'TEMP', 23, 'BINOP', 'MUL', 'CONST', 0.45284094131944796, 'TEMP', 1]
# ['MOVE', 'TEMP', 23, 'BINOP', 'ADD', 'TEMP', 23, 'BINOP', 'MUL', 'CONST', 4.121364133942601, 'TEMP', 2]
# ['MOVE', 'TEMP', 23, 'BINOP', 'ADD', 'TEMP', 23, 'BINOP', 'MUL', 'CONST', 0.0036569628936347735, 'TEMP', 3]
# ['MOVE', 'TEMP', 23, 'BINOP', 'ADD', 'TEMP', 23, 'BINOP', 'MUL', 'CONST', 0.25131134345034806, 'TEMP', 5]
# ['MOVE', 'TEMP', 23, 'BINOP', 'ADD', 'TEMP', 23, 'BINOP', 'MUL', 'CONST', 1.031847871323493, 'TEMP', 8]
# ['MOVE', 'TEMP', 24, 'BINOP', 'ADD', 'TEMP', 24, 'BINOP', 'MUL', 'CONST', 0.4753848845276069, 'TEMP', 0]
# ['MOVE', 'TEMP', 24, 'BINOP', 'ADD', 'TEMP', 24, 'BINOP', 'MUL', 'CONST', 1.5302858700190578, 'TEMP', 4]
# ['MOVE', 'TEMP', 25, 'BINOP', 'ADD', 'TEMP', 25, 'BINOP', 'MUL', 'CONST', 0.06499846966034585, 'TEMP', 0]
# ['MOVE', 'TEMP', 25, 'BINOP', 'ADD', 'TEMP', 25, 'BINOP', 'MUL', 'CONST', 0.12548404438747643, 'TEMP', 3]
# ['MOVE', 'TEMP', 25, 'BINOP', 'ADD', 'TEMP', 25, 'BINOP', 'MUL', 'CONST', 6.416730602719913, 'TEMP', 5]
# ['MOVE', 'TEMP', 25, 'BINOP', 'ADD', 'TEMP', 25, 'BINOP', 'MUL', 'CONST', 1.2263103414927166, 'TEMP', 9]
# ['MOVE', 'TEMP', 26, 'BINOP', 'ADD', 'TEMP', 26, 'BINOP', 'MUL', 'CONST', 0.6776190088135721, 'TEMP', 0]
# ['MOVE', 'TEMP', 26, 'BINOP', 'ADD', 'TEMP', 26, 'BINOP', 'MUL', 'CONST', 1.0765987174452203, 'TEMP', 1]
# ['MOVE', 'TEMP', 26, 'BINOP', 'ADD', 'TEMP', 26, 'BINOP', 'MUL', 'CONST', 0.5815683239321013, 'TEMP', 2]
# ['MOVE', 'TEMP', 26, 'BINOP', 'ADD', 'TEMP', 26, 'BINOP', 'MUL', 'CONST', 0.3843313891246838, 'TEMP', 3]
# ['MOVE', 'TEMP', 26, 'BINOP', 'ADD', 'TEMP', 26, 'BINOP', 'MUL', 'CONST', 0.047802592545125276, 'TEMP', 4]
# ['MOVE', 'TEMP', 27, 'BINOP', 'ADD', 'TEMP', 27, 'BINOP', 'MUL', 'CONST', 0.061554511967788716, 'TEMP', 2]
# ['MOVE', 'TEMP', 28, 'BINOP', 'ADD', 'TEMP', 28, 'BINOP', 'MUL', 'CONST', 1.219558838071412, 'TEMP', 3]
# ['MOVE', 'TEMP', 28, 'BINOP', 'ADD', 'TEMP', 28, 'BINOP', 'MUL', 'CONST', 0.2051826992150757, 'TEMP', 6]
# ['MOVE', 'TEMP', 28, 'BINOP', 'ADD', 'TEMP', 28, 'BINOP', 'MUL', 'CONST', 0.0720697848078434, 'TEMP', 7]
# ['MOVE', 'TEMP', 28, 'BINOP', 'ADD', 'TEMP', 28, 'BINOP', 'MUL', 'CONST', 0.21784133701505803, 'TEMP', 8]
# ['MOVE', 'TEMP', 29, 'BINOP', 'ADD', 'TEMP', 29, 'BINOP', 'MUL', 'CONST', 0.8561410542222923, 'TEMP', 0]
# ['MOVE', 'TEMP', 29, 'BINOP', 'ADD', 'TEMP', 29, 'BINOP', 'MUL', 'CONST', 0.0034101382323528367, 'TEMP', 1]
# ['MOVE', 'TEMP', 29, 'BINOP', 'ADD', 'TEMP', 29, 'BINOP', 'MUL', 'CONST', 0.6087669018575906, 'TEMP', 2]
# ['MOVE', 'TEMP', 29, 'BINOP', 'ADD', 'TEMP', 29, 'BINOP', 'MUL', 'CONST', 0.2368475396083679, 'TEMP', 4]
# ['MOVE', 'TEMP', 29, 'BINOP', 'ADD', 'TEMP', 29, 'BINOP', 'MUL', 'CONST', 0.36549972813746195, 'TEMP', 5]
# ['MOVE', 'TEMP', 29, 'BINOP', 'ADD', 'TEMP', 29, 'BINOP', 'MUL', 'CONST', 4.099797247587584, 'TEMP', 9]
# ['MOVE', 'TEMP', 30, 'BINOP', 'ADD', 'TEMP', 30, 'BINOP', 'MUL', 'CONST', 0.002339303753546173, 'TEMP', 0]
# ['MOVE', 'TEMP', 30, 'BINOP', 'ADD', 'TEMP', 30, 'BINOP', 'MUL', 'CONST', 0.14780039944587095, 'TEMP', 1]
# ['MOVE', 'TEMP', 30, 'BINOP', 'ADD', 'TEMP', 30, 'BINOP', 'MUL', 'CONST', 0.5125842520747462, 'TEMP', 5]
# ['MOVE', 'TEMP', 30, 'BINOP', 'ADD', 'TEMP', 30, 'BINOP', 'MUL', 'CONST', 0.053881409238168025, 'TEMP', 6]
# ['MOVE', 'TEMP', 31, 'BINOP', 'ADD', 'TEMP', 31, 'BINOP', 'MUL', 'CONST', 0.7800750428230311, 'TEMP', 1]
# ['MOVE', 'TEMP', 32, 'BINOP', 'ADD', 'TEMP', 32, 'BINOP', 'MUL', 'CONST', 0.8747931681665645, 'TEMP', 1]
# ['MOVE', 'TEMP', 32, 'BINOP', 'ADD', 'TEMP', 32, 'BINOP', 'MUL', 'CONST', 0.33804506362109293, 'TEMP', 8]
# ['MOVE', 'TEMP', 33, 'BINOP', 'ADD', 'TEMP', 33, 'BINOP', 'MUL', 'CONST', 0.05193026839363703, 'TEMP', 0]
# ['MOVE', 'TEMP', 33, 'BINOP', 'ADD', 'TEMP', 33, 'BINOP', 'MUL', 'CONST', 0.0001915327292008412, 'TEMP', 1]
# ['MOVE', 'TEMP', 33, 'BINOP', 'ADD', 'TEMP', 33, 'BINOP', 'MUL', 'CONST', 1.133184785121126, 'TEMP', 2]
# ['MOVE', 'TEMP', 33, 'BINOP', 'ADD', 'TEMP', 33, 'BINOP', 'MUL', 'CONST', 0.8028090533739475, 'TEMP', 3]
# ['MOVE', 'TEMP', 33, 'BINOP', 'ADD', 'TEMP', 33, 'BINOP', 'MUL', 'CONST', 0.012876815681998043, 'TEMP', 9]
# ['MOVE', 'TEMP', 34, 'BINOP', 'ADD', 'TEMP', 34, 'BINOP', 'MUL', 'CONST', 0.12680759005899644, 'TEMP', 2]
# ['MOVE', 'TEMP', 34, 'BINOP', 'ADD', 'TEMP', 34, 'BINOP', 'MUL', 'CONST', 1.4532264363135408, 'TEMP', 9]
# ['MOVE', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'BINOP', 'MUL', 'CONST', 0.7214840129455328, 'TEMP', 3]
# ['MOVE', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'BINOP', 'MUL', 'CONST', 0.011391387466870668, 'TEMP', 7]
# ['MOVE', 'TEMP', 36, 'BINOP', 'ADD', 'TEMP', 36, 'BINOP', 'MUL', 'CONST', 2.4516838095760756, 'TEMP', 6]
# ['MOVE', 'TEMP', 36, 'BINOP', 'ADD', 'TEMP', 36, 'BINOP', 'MUL', 'CONST', 6.800220864104408, 'TEMP', 7]
# ['MOVE', 'TEMP', 37, 'BINOP', 'ADD', 'TEMP', 37, 'BINOP', 'MUL', 'CONST', 0.614904222236319, 'TEMP', 1]
# ['MOVE', 'TEMP', 37, 'BINOP', 'ADD', 'TEMP', 37, 'BINOP', 'MUL', 'CONST', 2.398925320286505, 'TEMP', 3]
# ['MOVE', 'TEMP', 37, 'BINOP', 'ADD', 'TEMP', 37, 'BINOP', 'MUL', 'CONST', 2.6329869257218306, 'TEMP', 7]
# ['MOVE', 'TEMP', 37, 'BINOP', 'ADD', 'TEMP', 37, 'BINOP', 'MUL', 'CONST', 4.536444377570662, 'TEMP', 8]
# ['MOVE', 'TEMP', 38, 'BINOP', 'ADD', 'TEMP', 38, 'BINOP', 'MUL', 'CONST', 1.039761902946449, 'TEMP', 1]
# ['MOVE', 'TEMP', 38, 'BINOP', 'ADD', 'TEMP', 38, 'BINOP', 'MUL', 'CONST', 0.25101011956565616, 'TEMP', 2]
# ['MOVE', 'TEMP', 38, 'BINOP', 'ADD', 'TEMP', 38, 'BINOP', 'MUL', 'CONST', 0.5269387602442499, 'TEMP', 3]
# ['MOVE', 'TEMP', 38, 'BINOP', 'ADD', 'TEMP', 38, 'BINOP', 'MUL', 'CONST', 1.7424472142705127, 'TEMP', 4]
# ['MOVE', 'TEMP', 38, 'BINOP', 'ADD', 'TEMP', 38, 'BINOP', 'MUL', 'CONST', 1.3306715659516635, 'TEMP', 6]
# ['MOVE', 'TEMP', 38, 'BINOP', 'ADD', 'TEMP', 38, 'BINOP', 'MUL', 'CONST', 1.1207095039219674, 'TEMP', 9]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 0.22247651001744506, 'TEMP', 0]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 0.3330659506443425, 'TEMP', 3]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 0.002327630607195863, 'TEMP', 4]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 0.8190538884868934, 'TEMP', 5]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 3.2949157874423656, 'TEMP', 7]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 1.3386465002978374, 'TEMP', 9]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 10, 'BINOP', 'ADD', 'TEMP', 10, 'CONST', -1.8203796766046443]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 11, 'BINOP', 'ADD', 'TEMP', 11, 'CONST', -0.8552996229802686]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 12, 'BINOP', 'ADD', 'TEMP', 12, 'CONST', 0.966594437971497]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 13, 'BINOP', 'ADD', 'TEMP', 13, 'CONST', 0.2612268845109286]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 14, 'BINOP', 'ADD', 'TEMP', 14, 'CONST', -0.3965101005005671]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 15, 'BINOP', 'ADD', 'TEMP', 15, 'CONST', 0.4228534270395131]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 16, 'BINOP', 'ADD', 'TEMP', 16, 'CONST', 1.1623430672386659]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 17, 'BINOP', 'ADD', 'TEMP', 17, 'CONST', -1.4132513244163425]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 18, 'BINOP', 'ADD', 'TEMP', 18, 'CONST', 0.7686315402997462]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 19, 'BINOP', 'ADD', 'TEMP', 19, 'CONST', -0.8286342645287106]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 20, 'BINOP', 'ADD', 'TEMP', 20, 'CONST', 0.7014411401177489]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 21, 'BINOP', 'ADD', 'TEMP', 21, 'CONST', -0.6293425276746185]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 22, 'BINOP', 'ADD', 'TEMP', 22, 'CONST', 0.01196124548541135]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 23, 'BINOP', 'ADD', 'TEMP', 23, 'CONST', 0.7579466979007649]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 24, 'BINOP', 'ADD', 'TEMP', 24, 'CONST', -0.5173103086441649]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 25, 'BINOP', 'ADD', 'TEMP', 25, 'CONST', 0.05512290226089037]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 26, 'BINOP', 'ADD', 'TEMP', 26, 'CONST', 0.00802532125379494]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 27, 'BINOP', 'ADD', 'TEMP', 27, 'CONST', 1.3452946455130488]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 28, 'BINOP', 'ADD', 'TEMP', 28, 'CONST', 0.41207693608583146]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 29, 'BINOP', 'ADD', 'TEMP', 29, 'CONST', 0.1238816042696143]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 30, 'BINOP', 'ADD', 'TEMP', 30, 'CONST', -0.5614106895543881]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 31, 'BINOP', 'ADD', 'TEMP', 31, 'CONST', -0.24909936584536546]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 32, 'BINOP', 'ADD', 'TEMP', 32, 'CONST', -0.3696954390918804]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 33, 'BINOP', 'ADD', 'TEMP', 33, 'CONST', -0.43105976578984456]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 34, 'BINOP', 'ADD', 'TEMP', 34, 'CONST', -2.494966868610228]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'CONST', -1.099045311619812]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 36, 'BINOP', 'ADD', 'TEMP', 36, 'CONST', -0.6587468448876488]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 37, 'BINOP', 'ADD', 'TEMP', 37, 'CONST', 0.4641029685884602]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 38, 'BINOP', 'ADD', 'TEMP', 38, 'CONST', 0.829309909099101]
# ['MOVE', 'CALL', 'RELU', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'CONST', 0.22631750455770616]
# ['COMMENT', 'END']
# ['COMMENT', 'START']
# ['MOVE', 'TEMP', 30, 'CONST', 0]
# ['MOVE', 'TEMP', 31, 'CONST', 0]
# ['MOVE', 'TEMP', 32, 'CONST', 0]
# ['MOVE', 'TEMP', 33, 'CONST', 0]
# ['MOVE', 'TEMP', 34, 'CONST', 0]
# ['MOVE', 'TEMP', 35, 'CONST', 0]
# ['MOVE', 'TEMP', 36, 'CONST', 0]
# ['MOVE', 'TEMP', 37, 'CONST', 0]
# ['MOVE', 'TEMP', 38, 'CONST', 0]
# ['MOVE', 'TEMP', 39, 'CONST', 0]
# ['MOVE', 'TEMP', 40, 'CONST', 0]
# ['MOVE', 'TEMP', 41, 'CONST', 0]
# ['MOVE', 'TEMP', 42, 'CONST', 0]
# ['MOVE', 'TEMP', 43, 'CONST', 0]
# ['MOVE', 'TEMP', 44, 'CONST', 0]
# ['MOVE', 'TEMP', 45, 'CONST', 0]
# ['MOVE', 'TEMP', 46, 'CONST', 0]
# ['MOVE', 'TEMP', 47, 'CONST', 0]
# ['MOVE', 'TEMP', 48, 'CONST', 0]
# ['MOVE', 'TEMP', 49, 'CONST', 0]
# ['MOVE', 'TEMP', 50, 'CONST', 0]
# ['MOVE', 'TEMP', 51, 'CONST', 0]
# ['MOVE', 'TEMP', 52, 'CONST', 0]
# ['MOVE', 'TEMP', 53, 'CONST', 0]
# ['MOVE', 'TEMP', 54, 'CONST', 0]
# ['MOVE', 'TEMP', 55, 'CONST', 0]
# ['MOVE', 'TEMP', 56, 'CONST', 0]
# ['MOVE', 'TEMP', 57, 'CONST', 0]
# ['MOVE', 'TEMP', 58, 'CONST', 0]
# ['MOVE', 'TEMP', 59, 'CONST', 0]
# ['MOVE', 'TEMP', 30, 'BINOP', 'ADD', 'TEMP', 30, 'BINOP', 'MUL', 'CONST', 0.05164862973247706, 'TEMP', 2]
# ['MOVE', 'TEMP', 30, 'BINOP', 'ADD', 'TEMP', 30, 'BINOP', 'MUL', 'CONST', 2.0568872587504967, 'TEMP', 4]
# ['MOVE', 'TEMP', 30, 'BINOP', 'ADD', 'TEMP', 30, 'BINOP', 'MUL', 'CONST', 0.3387553275635225, 'TEMP', 5]
# ['MOVE', 'TEMP', 30, 'BINOP', 'ADD', 'TEMP', 30, 'BINOP', 'MUL', 'CONST', 1.0397190115411834, 'TEMP', 6]
# ['MOVE', 'TEMP', 30, 'BINOP', 'ADD', 'TEMP', 30, 'BINOP', 'MUL', 'CONST', 1.750637824290346, 'TEMP', 9]
# ['MOVE', 'TEMP', 30, 'BINOP', 'ADD', 'TEMP', 30, 'BINOP', 'MUL', 'CONST', 3.403059899032162, 'TEMP', 10]
# ['MOVE', 'TEMP', 30, 'BINOP', 'ADD', 'TEMP', 30, 'BINOP', 'MUL', 'CONST', 2.5593191109394335, 'TEMP', 11]
# ['MOVE', 'TEMP', 30, 'BINOP', 'ADD', 'TEMP', 30, 'BINOP', 'MUL', 'CONST', 3.0546311582476946, 'TEMP', 14]
# ['MOVE', 'TEMP', 30, 'BINOP', 'ADD', 'TEMP', 30, 'BINOP', 'MUL', 'CONST', 1.2423578369269392, 'TEMP', 15]
# ['MOVE', 'TEMP', 30, 'BINOP', 'ADD', 'TEMP', 30, 'BINOP', 'MUL', 'CONST', 7.6207607585282515, 'TEMP', 16]
# ['MOVE', 'TEMP', 30, 'BINOP', 'ADD', 'TEMP', 30, 'BINOP', 'MUL', 'CONST', 0.005303066438077354, 'TEMP', 20]
# ['MOVE', 'TEMP', 30, 'BINOP', 'ADD', 'TEMP', 30, 'BINOP', 'MUL', 'CONST', 6.624250740712249e-06, 'TEMP', 22]
# ['MOVE', 'TEMP', 31, 'BINOP', 'ADD', 'TEMP', 31, 'BINOP', 'MUL', 'CONST', 2.6811164300868406, 'TEMP', 0]
# ['MOVE', 'TEMP', 31, 'BINOP', 'ADD', 'TEMP', 31, 'BINOP', 'MUL', 'CONST', 0.3231852577131733, 'TEMP', 4]
# ['MOVE', 'TEMP', 31, 'BINOP', 'ADD', 'TEMP', 31, 'BINOP', 'MUL', 'CONST', 0.08213354020374385, 'TEMP', 5]
# ['MOVE', 'TEMP', 31, 'BINOP', 'ADD', 'TEMP', 31, 'BINOP', 'MUL', 'CONST', 0.5542343989672242, 'TEMP', 8]
# ['MOVE', 'TEMP', 31, 'BINOP', 'ADD', 'TEMP', 31, 'BINOP', 'MUL', 'CONST', 7.604655909359745, 'TEMP', 9]
# ['MOVE', 'TEMP', 31, 'BINOP', 'ADD', 'TEMP', 31, 'BINOP', 'MUL', 'CONST', 0.07066563744023488, 'TEMP', 13]
# ['MOVE', 'TEMP', 31, 'BINOP', 'ADD', 'TEMP', 31, 'BINOP', 'MUL', 'CONST', 0.22038041957497032, 'TEMP', 14]
# ['MOVE', 'TEMP', 31, 'BINOP', 'ADD', 'TEMP', 31, 'BINOP', 'MUL', 'CONST', 1.130492023301469, 'TEMP', 15]
# ['MOVE', 'TEMP', 31, 'BINOP', 'ADD', 'TEMP', 31, 'BINOP', 'MUL', 'CONST', 0.2466916709949199, 'TEMP', 16]
# ['MOVE', 'TEMP', 31, 'BINOP', 'ADD', 'TEMP', 31, 'BINOP', 'MUL', 'CONST', 0.040888249665145954, 'TEMP', 19]
# ['MOVE', 'TEMP', 31, 'BINOP', 'ADD', 'TEMP', 31, 'BINOP', 'MUL', 'CONST', 1.5612158349488012, 'TEMP', 21]
# ['MOVE', 'TEMP', 31, 'BINOP', 'ADD', 'TEMP', 31, 'BINOP', 'MUL', 'CONST', 0.43732285603367055, 'TEMP', 23]
# ['MOVE', 'TEMP', 31, 'BINOP', 'ADD', 'TEMP', 31, 'BINOP', 'MUL', 'CONST', 0.0077667088970144625, 'TEMP', 24]
# ['MOVE', 'TEMP', 31, 'BINOP', 'ADD', 'TEMP', 31, 'BINOP', 'MUL', 'CONST', 0.554735309219519, 'TEMP', 27]
# ['MOVE', 'TEMP', 32, 'BINOP', 'ADD', 'TEMP', 32, 'BINOP', 'MUL', 'CONST', 0.03795002086841146, 'TEMP', 0]
# ['MOVE', 'TEMP', 32, 'BINOP', 'ADD', 'TEMP', 32, 'BINOP', 'MUL', 'CONST', 0.1478978256018925, 'TEMP', 2]
# ['MOVE', 'TEMP', 32, 'BINOP', 'ADD', 'TEMP', 32, 'BINOP', 'MUL', 'CONST', 1.4672756328176806, 'TEMP', 8]
# ['MOVE', 'TEMP', 32, 'BINOP', 'ADD', 'TEMP', 32, 'BINOP', 'MUL', 'CONST', 0.08173698987300206, 'TEMP', 9]
# ['MOVE', 'TEMP', 32, 'BINOP', 'ADD', 'TEMP', 32, 'BINOP', 'MUL', 'CONST', 0.6275724030807671, 'TEMP', 10]
# ['MOVE', 'TEMP', 32, 'BINOP', 'ADD', 'TEMP', 32, 'BINOP', 'MUL', 'CONST', 0.018938880062304278, 'TEMP', 16]
# ['MOVE', 'TEMP', 32, 'BINOP', 'ADD', 'TEMP', 32, 'BINOP', 'MUL', 'CONST', 1.5922990631237657, 'TEMP', 17]
# ['MOVE', 'TEMP', 32, 'BINOP', 'ADD', 'TEMP', 32, 'BINOP', 'MUL', 'CONST', 0.25318142098578617, 'TEMP', 18]
# ['MOVE', 'TEMP', 32, 'BINOP', 'ADD', 'TEMP', 32, 'BINOP', 'MUL', 'CONST', 2.73407510622509, 'TEMP', 21]
# ['MOVE', 'TEMP', 32, 'BINOP', 'ADD', 'TEMP', 32, 'BINOP', 'MUL', 'CONST', 2.404374898237316, 'TEMP', 22]
# ['MOVE', 'TEMP', 32, 'BINOP', 'ADD', 'TEMP', 32, 'BINOP', 'MUL', 'CONST', 1.5939903539170086, 'TEMP', 23]
# ['MOVE', 'TEMP', 32, 'BINOP', 'ADD', 'TEMP', 32, 'BINOP', 'MUL', 'CONST', 0.8669186471755831, 'TEMP', 25]
# ['MOVE', 'TEMP', 33, 'BINOP', 'ADD', 'TEMP', 33, 'BINOP', 'MUL', 'CONST', 0.6859674014156848, 'TEMP', 5]
# ['MOVE', 'TEMP', 33, 'BINOP', 'ADD', 'TEMP', 33, 'BINOP', 'MUL', 'CONST', 0.019754802873576196, 'TEMP', 9]
# ['MOVE', 'TEMP', 33, 'BINOP', 'ADD', 'TEMP', 33, 'BINOP', 'MUL', 'CONST', 0.2402331646157658, 'TEMP', 13]
# ['MOVE', 'TEMP', 33, 'BINOP', 'ADD', 'TEMP', 33, 'BINOP', 'MUL', 'CONST', 1.4236831468998994, 'TEMP', 15]
# ['MOVE', 'TEMP', 33, 'BINOP', 'ADD', 'TEMP', 33, 'BINOP', 'MUL', 'CONST', 0.6081559521384899, 'TEMP', 18]
# ['MOVE', 'TEMP', 33, 'BINOP', 'ADD', 'TEMP', 33, 'BINOP', 'MUL', 'CONST', 6.768622751891715, 'TEMP', 23]
# ['MOVE', 'TEMP', 33, 'BINOP', 'ADD', 'TEMP', 33, 'BINOP', 'MUL', 'CONST', 0.009763305884253445, 'TEMP', 24]
# ['MOVE', 'TEMP', 33, 'BINOP', 'ADD', 'TEMP', 33, 'BINOP', 'MUL', 'CONST', 0.9370827689893989, 'TEMP', 25]
# ['MOVE', 'TEMP', 33, 'BINOP', 'ADD', 'TEMP', 33, 'BINOP', 'MUL', 'CONST', 0.28753507747560186, 'TEMP', 28]
# ['MOVE', 'TEMP', 34, 'BINOP', 'ADD', 'TEMP', 34, 'BINOP', 'MUL', 'CONST', 0.8614636373030169, 'TEMP', 3]
# ['MOVE', 'TEMP', 34, 'BINOP', 'ADD', 'TEMP', 34, 'BINOP', 'MUL', 'CONST', 0.06342730238523661, 'TEMP', 5]
# ['MOVE', 'TEMP', 34, 'BINOP', 'ADD', 'TEMP', 34, 'BINOP', 'MUL', 'CONST', 1.5429366916653018, 'TEMP', 7]
# ['MOVE', 'TEMP', 34, 'BINOP', 'ADD', 'TEMP', 34, 'BINOP', 'MUL', 'CONST', 2.0281950883479203, 'TEMP', 15]
# ['MOVE', 'TEMP', 34, 'BINOP', 'ADD', 'TEMP', 34, 'BINOP', 'MUL', 'CONST', 0.0790280651066768, 'TEMP', 17]
# ['MOVE', 'TEMP', 34, 'BINOP', 'ADD', 'TEMP', 34, 'BINOP', 'MUL', 'CONST', 0.3044698023411907, 'TEMP', 20]
# ['MOVE', 'TEMP', 34, 'BINOP', 'ADD', 'TEMP', 34, 'BINOP', 'MUL', 'CONST', 1.5340696720495528, 'TEMP', 22]
# ['MOVE', 'TEMP', 34, 'BINOP', 'ADD', 'TEMP', 34, 'BINOP', 'MUL', 'CONST', 0.4453431125462258, 'TEMP', 23]
# ['MOVE', 'TEMP', 34, 'BINOP', 'ADD', 'TEMP', 34, 'BINOP', 'MUL', 'CONST', 1.8785435397665475, 'TEMP', 25]
# ['MOVE', 'TEMP', 34, 'BINOP', 'ADD', 'TEMP', 34, 'BINOP', 'MUL', 'CONST', 0.01666283262912676, 'TEMP', 27]
# ['MOVE', 'TEMP', 34, 'BINOP', 'ADD', 'TEMP', 34, 'BINOP', 'MUL', 'CONST', 0.10344467937465651, 'TEMP', 29]
# ['MOVE', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'BINOP', 'MUL', 'CONST', 0.25792540101825506, 'TEMP', 0]
# ['MOVE', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'BINOP', 'MUL', 'CONST', 0.014755041662247543, 'TEMP', 3]
# ['MOVE', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'BINOP', 'MUL', 'CONST', 3.2009707185031497, 'TEMP', 11]
# ['MOVE', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'BINOP', 'MUL', 'CONST', 0.17229017911620156, 'TEMP', 12]
# ['MOVE', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'BINOP', 'MUL', 'CONST', 0.01744249264192461, 'TEMP', 13]
# ['MOVE', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'BINOP', 'MUL', 'CONST', 5.599995500862127, 'TEMP', 16]
# ['MOVE', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'BINOP', 'MUL', 'CONST', 1.4524977796670493, 'TEMP', 18]
# ['MOVE', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'BINOP', 'MUL', 'CONST', 0.03645750976309703, 'TEMP', 21]
# ['MOVE', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'BINOP', 'MUL', 'CONST', 0.006955746649999601, 'TEMP', 23]
# ['MOVE', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'BINOP', 'MUL', 'CONST', 0.2938238632150872, 'TEMP', 26]
# ['MOVE', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'BINOP', 'MUL', 'CONST', 0.7678494416523696, 'TEMP', 28]
# ['MOVE', 'TEMP', 35, 'BINOP', 'ADD', 'TEMP', 35, 'BINOP', 'MUL', 'CONST', 0.8416443155955141, 'TEMP', 29]
# ['MOVE', 'TEMP', 36, 'BINOP', 'ADD', 'TEMP', 36, 'BINOP', 'MUL', 'CONST', 0.07280271109573928, 'TEMP', 1]
# ['MOVE', 'TEMP', 36, 'BINOP', 'ADD', 'TEMP', 36, 'BINOP', 'MUL', 'CONST', 0.6972565125140694, 'TEMP', 4]
# ['MOVE', 'TEMP', 36, 'BINOP', 'ADD', 'TEMP', 36, 'BINOP', 'MUL', 'CONST', 0.0817856189325929, 'TEMP', 8]
# ['MOVE', 'TEMP', 36, 'BINOP', 'ADD', 'TEMP', 36, 'BINOP', 'MUL', 'CONST', 0.13387231347140022, 'TEMP', 10]
# ['MOVE', 'TEMP', 36, 'BINOP', 'ADD', 'TEMP', 36, 'BINOP', 'MUL', 'CONST', 0.13161659443832177, 'TEMP', 11]
# ['MOVE', 'TEMP', 36, 'BINOP', 'ADD', 'TEMP', 36, 'BINOP', 'MUL', 'CONST', 1.1747149722341015, 'TEMP', 13]
# ['MOVE', 'TEMP', 36, 'BINOP', 'ADD', 'TEMP', 36, 'BINOP', 'MUL', 'CONST', 0.17295348883066025, 'TEMP', 14]
# ['MOVE', 'TEMP', 36, 'BINOP', 'ADD', 'TEMP', 36, 'BINOP', 'MUL', 'CONST', 0.6444045487336866, 'TEMP', 16]
# ['MOVE', 'TEMP', 36, 'BINOP', 'ADD', 'TEMP', 36, 'BINOP', 'MUL', 'CONST', 1.3753850458462977, 'TEMP', 17]
# ['MOVE', 'TEMP', 36, 'BINOP', 'ADD', 'TEMP', 36, 'BINOP', 'MUL', 'CONST', 1.0899239593435388, 'TEMP', 20]
# ['MOVE', 'TEMP', 36, 'BINOP', 'ADD', 'TEMP', 36, 'BINOP', 'MUL', 'CONST', 0.004388954371200738, 'TEMP', 21]
# ['MOVE', 'TEMP', 36, 'BINOP', 'ADD', 'TEMP', 36, 'BINOP', 'MUL', 'CONST', 0.7240190129466061, 'TEMP', 23]
# ['MOVE', 'TEMP', 36, 'BINOP', 'ADD', 'TEMP', 36, 'BINOP', 'MUL', 'CONST', 3.0654165154870334, 'TEMP', 24]
# ['MOVE', 'TEMP', 37, 'BINOP', 'ADD', 'TEMP', 37, 'BINOP', 'MUL', 'CONST', 0.6572970684720625, 'TEMP', 4]
# ['MOVE', 'TEMP', 37, 'BINOP', 'ADD', 'TEMP', 37, 'BINOP', 'MUL', 'CONST', 2.314519110849082, 'TEMP', 7]
# ['MOVE', 'TEMP', 37, 'BINOP', 'ADD', 'TEMP', 37, 'BINOP', 'MUL', 'CONST', 0.1504403819372296, 'TEMP', 8]
# ['MOVE', 'TEMP', 37, 'BINOP', 'ADD', 'TEMP', 37, 'BINOP', 'MUL', 'CONST', 2.1828998370078256, 'TEMP', 9]
# ['MOVE', 'TEMP', 37, 'BINOP', 'ADD', 'TEMP', 37, 'BINOP', 'MUL', 'CONST', 0.016480476938259728, 'TEMP', 13]
# ['MOVE', 'TEMP', 37, 'BINOP', 'ADD', 'TEMP', 37, 'BINOP', 'MUL', 'CONST', 0.0394609826192612, 'TEMP', 17]
# ['MOVE', 'TEMP', 37, 'BINOP', 'ADD', 'TEMP', 37, 'BINOP', 'MUL', 'CONST', 0.5141053627105142, 'TEMP', 19]
# ['MOVE', 'TEMP', 37, 'BINOP', 'ADD', 'TEMP', 37, 'BINOP', 'MUL', 'CONST', 0.16132217480200153, 'TEMP', 20]
# ['MOVE', 'TEMP', 37, 'BINOP', 'ADD', 'TEMP', 37, 'BINOP', 'MUL', 'CONST', 0.04757637275353742, 'TEMP', 22]
# ['MOVE', 'TEMP', 37, 'BINOP', 'ADD', 'TEMP', 37, 'BINOP', 'MUL', 'CONST', 0.08299883077642897, 'TEMP', 24]
# ['MOVE', 'TEMP', 37, 'BINOP', 'ADD', 'TEMP', 37, 'BINOP', 'MUL', 'CONST', 0.89969675273675, 'TEMP', 25]
# ['MOVE', 'TEMP', 37, 'BINOP', 'ADD', 'TEMP', 37, 'BINOP', 'MUL', 'CONST', 0.431363168718891, 'TEMP', 29]
# ['MOVE', 'TEMP', 38, 'BINOP', 'ADD', 'TEMP', 38, 'BINOP', 'MUL', 'CONST', 0.0019237385953241085, 'TEMP', 0]
# ['MOVE', 'TEMP', 38, 'BINOP', 'ADD', 'TEMP', 38, 'BINOP', 'MUL', 'CONST', 0.9127856561196437, 'TEMP', 2]
# ['MOVE', 'TEMP', 38, 'BINOP', 'ADD', 'TEMP', 38, 'BINOP', 'MUL', 'CONST', 0.11327806524587598, 'TEMP', 7]
# ['MOVE', 'TEMP', 38, 'BINOP', 'ADD', 'TEMP', 38, 'BINOP', 'MUL', 'CONST', 0.002663436524054929, 'TEMP', 11]
# ['MOVE', 'TEMP', 38, 'BINOP', 'ADD', 'TEMP', 38, 'BINOP', 'MUL', 'CONST', 2.167977318147648, 'TEMP', 18]
# ['MOVE', 'TEMP', 38, 'BINOP', 'ADD', 'TEMP', 38, 'BINOP', 'MUL', 'CONST', 1.455804456900308, 'TEMP', 20]
# ['MOVE', 'TEMP', 38, 'BINOP', 'ADD', 'TEMP', 38, 'BINOP', 'MUL', 'CONST', 0.10290365881205514, 'TEMP', 21]
# ['MOVE', 'TEMP', 38, 'BINOP', 'ADD', 'TEMP', 38, 'BINOP', 'MUL', 'CONST', 0.0465632832242604, 'TEMP', 22]
# ['MOVE', 'TEMP', 38, 'BINOP', 'ADD', 'TEMP', 38, 'BINOP', 'MUL', 'CONST', 0.5923296625707882, 'TEMP', 23]
# ['MOVE', 'TEMP', 38, 'BINOP', 'ADD', 'TEMP', 38, 'BINOP', 'MUL', 'CONST', 3.6461992035696182, 'TEMP', 25]
# ['MOVE', 'TEMP', 38, 'BINOP', 'ADD', 'TEMP', 38, 'BINOP', 'MUL', 'CONST', 0.05931066271359154, 'TEMP', 27]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 1.3351202231066572, 'TEMP', 1]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 0.016605692715234113, 'TEMP', 3]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 2.333158431681331, 'TEMP', 6]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 0.7175587855431685, 'TEMP', 8]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 1.5946527257225438, 'TEMP', 10]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 5.106407403557694, 'TEMP', 12]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 0.01023661920974611, 'TEMP', 14]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 2.385148112549443, 'TEMP', 15]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 0.025438245261190425, 'TEMP', 20]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 0.009126859644666292, 'TEMP', 22]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 4.21596554840823, 'TEMP', 23]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 0.0805520098985554, 'TEMP', 27]
# ['MOVE', 'TEMP', 39, 'BINOP', 'ADD', 'TEMP', 39, 'BINOP', 'MUL', 'CONST', 0.5316711102100226, 'TEMP', 28]
# ['MOVE', 'TEMP', 40, 'BINOP', 'ADD', 'TEMP', 40, 'BINOP', 'MUL', 'CONST', 0.31132919238761336, 'TEMP', 4]
# ['MOVE', 'TEMP', 40, 'BINOP', 'ADD', 'TEMP', 40, 'BINOP', 'MUL', 'CONST', 1.2355758128189596, 'TEMP', 5]
# ['MOVE', 'TEMP', 40, 'BINOP', 'ADD', 'TEMP', 40, 'BINOP', 'MUL', 'CONST', 0.31466671160604803, 'TEMP', 6]
# ['MOVE', 'TEMP', 40, 'BINOP', 'ADD', 'TEMP', 40, 'BINOP', 'MUL', 'CONST', 3.624405277784461, 'TEMP', 8]
# ['MOVE', 'TEMP', 40, 'BINOP', 'ADD', 'TEMP', 40, 'BINOP', 'MUL', 'CONST', 1.3218874476664642, 'TEMP', 12]
# ['MOVE', 'TEMP', 40, 'BINOP', 'ADD', 'TEMP', 40, 'BINOP', 'MUL', 'CONST', 0.7843588692316708, 'TEMP', 14]
# ['MOVE', 'TEMP', 40, 'BINOP', 'ADD', 'TEMP', 40, 'BINOP', 'MUL', 'CONST', 1.8904151573716081, 'TEMP', 15]
# ['MOVE', 'TEMP', 40, 'BINOP', 'ADD', 'TEMP', 40, 'BINOP', 'MUL', 'CONST', 0.036149721161867335, 'TEMP', 16]
# ['MOVE', 'TEMP', 40, 'BINOP', 'ADD', 'TEMP', 40, 'BINOP', 'MUL', 'CONST', 0.31556735891122123, 'TEMP', 18]
# ['MOVE', 'TEMP', 40, 'BINOP', 'ADD', 'TEMP', 40, 'BINOP', 'MUL', 'CONST', 0.01432470825478167, 'TEMP', 19]
# ['MOVE', 'TEMP', 40, 'BINOP', 'ADD', 'TEMP', 40, 'BINOP', 'MUL', 'CONST', 0.8151138742676447, 'TEMP', 23]
# ['MOVE', 'TEMP', 40, 'BINOP', 'ADD', 'TEMP', 40, 'BINOP', 'MUL', 'CONST', 1.7472395173694018, 'TEMP', 24]
# ['MOVE', 'TEMP', 40, 'BINOP', 'ADD', 'TEMP', 40, 'BINOP', 'MUL', 'CONST', 1.287868667583494, 'TEMP', 25]
# ['MOVE', 'TEMP', 41, 'BINOP', 'ADD', 'TEMP', 41, 'BINOP', 'MUL', 'CONST', 0.4353902079317639, 'TEMP', 0]
# ['MOVE', 'TEMP', 41, 'BINOP', 'ADD', 'TEMP', 41, 'BINOP', 'MUL', 'CONST', 0.21146372281460712, 'TEMP', 1]
# ['MOVE', 'TEMP', 41, 'BINOP', 'ADD', 'TEMP', 41, 'BINOP', 'MUL', 'CONST', 9.449589863873899e-05, 'TEMP', 2]
# ['MOVE', 'TEMP', 41, 'BINOP', 'ADD', 'TEMP', 41, 'BINOP', 'MUL', 'CONST', 0.24805682537752402, 'TEMP', 4]
# ['MOVE', 'TEMP', 41, 'BINOP', 'ADD', 'TEMP', 41, 'BINOP', 'MUL', 'CONST', 2.098326124058883, 'TEMP', 7]
# ['MOVE', 'TEMP', 41, 'BINOP', 'ADD', 'TEMP', 41, 'BINOP', 'MUL', 'CONST', 0.06651003556599908, 'TEMP', 10]
# ['MOVE', 'TEMP', 41, 'BINOP', 'ADD', 'TEMP', 41, 'BINOP', 'MUL', 'CONST', 0.45295319500464293, 'TEMP', 14]
# ['MOVE', 'TEMP', 41, 'BINOP', 'ADD', 'TEMP', 41, 'BINOP', 'MUL', 'CONST', 0.1358260646328495, 'TEMP', 15]
# ['MOVE', 'TEMP', 41, 'BINOP', 'ADD', 'TEMP', 41, 'BINOP', 'MUL', 'CONST', 1.6674403097918495, 'TEMP', 23]
# ['MOVE', 'TEMP', 41, 'BINOP', 'ADD', 'TEMP', 41, 'BINOP', 'MUL', 'CONST', 8.359814976592663, 'TEMP', 24]
# ['MOVE', 'TEMP', 41, 'BINOP', 'ADD', 'TEMP', 41, 'BINOP', 'MUL', 'CONST', 2.3117823420548542, 'TEMP', 25]
# ['MOVE', 'TEMP', 41, 'BINOP', 'ADD', 'TEMP', 41, 'BINOP', 'MUL', 'CONST', 0.013089488639355495, 'TEMP', 27]
# ['MOVE', 'TEMP', 42, 'BINOP', 'ADD', 'TEMP', 42, 'BINOP', 'MUL', 'CONST', 0.0923779323697788, 'TEMP', 0]
# ['MOVE', 'TEMP', 42, 'BINOP', 'ADD', 'TEMP', 42, 'BINOP', 'MUL', 'CONST', 1.487426402994, 'TEMP', 2]
# ['MOVE', 'TEMP', 42, 'BINOP', 'ADD', 'TEMP', 42, 'BINOP', 'MUL', 'CONST', 0.12673030250890835, 'TEMP', 3]
# ['MOVE', 'TEMP', 42, 'BINOP', 'ADD', 'TEMP', 42, 'BINOP', 'MUL', 'CONST', 0.3710746661355926, 'TEMP', 7]
# ['MOVE', 'TEMP', 42, 'BINOP', 'ADD', 'TEMP', 42, 'BINOP', 'MUL', 'CONST', 0.19635935206611885, 'TEMP', 9]
# ['MOVE', 'TEMP', 42, 'BINOP', 'ADD', 'TEMP', 42, 'BINOP', 'MUL', 'CONST', 0.12638542278234502, 'TEMP', 10]
# ['MOVE', 'TEMP', 42, 'BINOP', 'ADD', 'TEMP', 42, 'BINOP', 'MUL', 'CONST', 1.949463701313074, 'TEMP', 11]
# ['MOVE', 'TEMP', 42, 'BINOP', 'ADD', 'TEMP', 42, 'BINOP', 'MUL', 'CONST', 0.08644103700622302, 'TEMP', 12]
# ['MOVE', 'TEMP', 42, 'BINOP', 'ADD', 'TEMP', 42, 'BINOP', 'MUL', 'CONST', 1.5609659896322903, 'TEMP', 13]
# ['MOVE', 'TEMP', 42, 'BINOP', 'ADD', 'TEMP', 42, 'BINOP', 'MUL', 'CONST', 0.8603629296569274, 'TEMP', 18]
# ['MOVE', 'TEMP', 42, 'BINOP', 'ADD', 'TEMP', 42, 'BINOP', 'MUL', 'CONST', 0.153746386059948, 'TEMP', 22]
# ['MOVE', 'TEMP', 43, 'BINOP', 'ADD', 'TEMP', 43, 'BINOP', 'MUL', 'CONST', 0.1876344506191094, 'TEMP', 3]
# ['MOVE', 'TEMP', 43, 'BINOP', 'ADD', 'TEMP', 43, 'BINOP', 'MUL', 'CONST', 0.20489893377487636, 'TEMP', 9]
# ['MOVE', 'TEMP', 43, 'BINOP', 'ADD', 'TEMP', 43, 'BINOP', 'MUL', 'CONST', 0.6669322228245266, 'TEMP', 10]
# ['MOVE', 'TEMP', 43, 'BINOP', 'ADD', 'TEMP', 43, 'BINOP', 'MUL', 'CONST', 0.646654682554221, 'TEMP', 15]
# ['MOVE', 'TEMP', 43, 'BINOP', 'ADD', 'TEMP', 43, 'BINOP', 'MUL', 'CONST', 0.012906001284069138, 'TEMP', 21]
# ['MOVE', 'TEMP', 43, 'BINOP', 'ADD', 'TEMP', 43, 'BINOP', 'MUL', 'CONST', 0.018390937240510198, 'TEMP', 24]
# ['MOVE', 'TEMP', 43, 'BINOP', 'ADD', 'TEMP', 43, 'BINOP', 'MUL', 'CONST', 0.07605549772065837, 'TEMP', 27]
# ['MOVE', 'TEMP', 43, 'BINOP', 'ADD', 'TEMP', 43, 'BINOP', 'MUL', 'CONST', 0.059517263648658114, 'TEMP', 28]
# ['MOVE', 'TEMP', 43, 'BINOP', 'ADD', 'TEMP', 43, 'BINOP', 'MUL', 'CONST', 0.5895574152069722, 'TEMP', 29]
# ['MOVE', 'TEMP', 44, 'BINOP', 'ADD', 'TEMP', 44, 'BINOP', 'MUL', 'CONST', 0.028276651341547193, 'TEMP', 6]
# ['MOVE', 'TEMP', 44, 'BINOP', 'ADD', 'TEMP', 44, 'BINOP', 'MUL', 'CONST', 0.8705804628914142, 'TEMP', 7]
# ['MOVE', 'TEMP', 44, 'BINOP', 'ADD', 'TEMP', 44, 'BINOP', 'MUL', 'CONST', 2.151153624217852, 'TEMP', 17]
# ['MOVE', 'TEMP', 44, 'BINOP', 'ADD', 'TEMP', 44, 'BINOP', 'MUL', 'CONST', 1.3861488878599193, 'TEMP', 18]
# ['MOVE', 'TEMP', 44, 'BINOP', 'ADD', 'TEMP', 44, 'BINOP', 'MUL', 'CONST', 0.14992037623561777, 'TEMP', 19]
# ['MOVE', 'TEMP', 44, 'BINOP', 'ADD', 'TEMP', 44, 'BINOP', 'MUL', 'CONST', 0.13369472628841317, 'TEMP', 20]
# ['MOVE', 'TEMP', 44, 'BINOP', 'ADD', 'TEMP', 44, 'BINOP', 'MUL', 'CONST', 0.4647074018057178, 'TEMP', 28]
# ['MOVE', 'TEMP', 45, 'BINOP', 'ADD', 'TEMP', 45, 'BINOP', 'MUL', 'CONST', 0.16257150474232665, 'TEMP', 4]
# ['MOVE', 'TEMP', 45, 'BINOP', 'ADD', 'TEMP', 45, 'BINOP', 'MUL', 'CONST', 0.02020269193586776, 'TEMP', 7]
# ['MOVE', 'TEMP', 45, 'BINOP', 'ADD', 'TEMP', 45, 'BINOP', 'MUL', 'CONST', 0.0008650868487150553, 'TEMP', 10]
# ['MOVE', 'TEMP', 45, 'BINOP', 'ADD', 'TEMP', 45, 'BINOP', 'MUL', 'CONST', 0.22938374703571346, 'TEMP', 11]
# ['MOVE', 'TEMP', 45, 'BINOP', 'ADD', 'TEMP', 45, 'BINOP', 'MUL', 'CONST', 1.2745723869301455, 'TEMP', 13]
# ['MOVE', 'TEMP', 45, 'BINOP', 'ADD', 'TEMP', 45, 'BINOP', 'MUL', 'CONST', 1.1265543355791838, 'TEMP', 15]
# ['MOVE', 'TEMP', 45, 'BINOP', 'ADD', 'TEMP', 45, 'BINOP', 'MUL', 'CONST', 1.699448808204483, 'TEMP', 19]
# ['MOVE', 'TEMP', 45, 'BINOP', 'ADD', 'TEMP', 45, 'BINOP', 'MUL', 'CONST', 2.116672910427304, 'TEMP', 20]
# ['MOVE', 'TEMP', 45, 'BINOP', 'ADD', 'TEMP', 45, 'BINOP', 'MUL', 'CONST', 0.07895770474854823, 'TEMP', 21]
# ['MOVE', 'TEMP', 46, 'BINOP', 'ADD', 'TEMP', 46, 'BINOP', 'MUL', 'CONST', 0.6108036397789637, 'TEMP', 2]
# ['MOVE', 'TEMP', 46, 'BINOP', 'ADD', 'TEMP', 46, 'BINOP', 'MUL', 'CONST', 0.09148020747853233, 'TEMP', 3]
# ['MOVE', 'TEMP', 46, 'BINOP', 'ADD', 'TEMP', 46, 'BINOP', 'MUL', 'CONST', 2.7393117629113797, 'TEMP', 5]
# ['MOVE', 'TEMP', 46, 'BINOP', 'ADD', 'TEMP', 46, 'BINOP', 'MUL', 'CONST', 0.1407159839585269, 'TEMP', 6]
# ['MOVE', 'TEMP', 46, 'BINOP', 'ADD', 'TEMP', 46, 'BINOP', 'MUL', 'CONST', 5.495024752630505, 'TEMP', 7]
# ['MOVE', 'TEMP', 46, 'BINOP', 'ADD', 'TEMP', 46, 'BINOP', 'MUL', 'CONST', 0.3480514014419911, 'TEMP', 8]
# ['MOVE', 'TEMP', 46, 'BINOP', 'ADD', 'TEMP', 46, 'BINOP', 'MUL', 'CONST', 5.131268237581725, 'TEMP', 9]
# ['MOVE', 'TEMP', 46, 'BINOP', 'ADD', 'TEMP', 46, 'BINOP', 'MUL', 'CONST', 3.292562390981301, 'TEMP', 11]
# ['MOVE', 'TEMP', 46, 'BINOP', 'ADD', 'TEMP', 46, 'BINOP', 'MUL', 'CONST', 0.11938265010965474, 'TEMP', 12]
# ['MOVE', 'TEMP', 46, 'BINOP', 'ADD', 'TEMP', 46, 'BINOP', 'MUL', 'CONST', 0.1923006475197721, 'TEMP', 13]
# ['MOVE', 'TEMP', 46, 'BINOP', 'ADD', 'TEMP', 46, 'BINOP', 'MUL', 'CONST', 0.6330938761181746, 'TEMP', 15]
# ['MOVE', 'TEMP', 46, 'BINOP', 'ADD', 'TEMP', 46, 'BINOP', 'MUL', 'CONST', 0.2574291148735236, 'TEMP', 16]
# ['MOVE', 'TEMP', 46, 'BINOP', 'ADD', 'TEMP', 46, 'BINOP', 'MUL', 'CONST', 0.010818068877509359, 'TEMP', 24]
# ['MOVE', 'TEMP', 46, 'BINOP', 'ADD', 'TEMP', 46, 'BINOP', 'MUL', 'CONST', 0.019738706057987148, 'TEMP', 26]
# ['MOVE', 'TEMP', 47, 'BINOP', 'ADD', 'TEMP', 47, 'BINOP', 'MUL', 'CONST', 0.027546930587432742, 'TEMP', 1]
# ['MOVE', 'TEMP', 47, 'BINOP', 'ADD', 'TEMP', 47, 'BINOP', 'MUL', 'CONST', 0.13833766385147814, 'TEMP', 2]
# ['MOVE', 'TEMP', 47, 'BINOP', 'ADD', 'TEMP', 47, 'BINOP', 'MUL', 'CONST', 0.875099460933681, 'TEMP', 4]
# ['MOVE', 'TEMP', 47, 'BINOP', 'ADD', 'TEMP', 47, 'BINOP', 'MUL', 'CONST', 1.0249676046500487, 'TEMP', 8]
# ['MOVE', 'TEMP', 47, 'BINOP', 'ADD', 'TEMP', 47, 'BINOP', 'MUL', 'CONST', 3.7307379886680945, 'TEMP', 20]
# ['MOVE', 'TEMP', 47, 'BINOP', 'ADD', 'TEMP', 47, 'BINOP', 'MUL', 'CONST', 3.6359607931148092, 'TEMP', 25]
# ['MOVE', 'TEMP', 48, 'BINOP', 'ADD', 'TEMP', 48, 'BINOP', 'MUL', 'CONST', 0.8382963530567278, 'TEMP', 6]
# ['MOVE', 'TEMP', 48, 'BINOP', 'ADD', 'TEMP', 48, 'BINOP', 'MUL', 'CONST', 0.08687387672450457, 'TEMP', 10]
# ['MOVE', 'TEMP', 48, 'BINOP', 'ADD', 'TEMP', 48, 'BINOP', 'MUL', 'CONST', 0.11255596576862395, 'TEMP', 11]
# ['MOVE', 'TEMP', 48, 'BINOP', 'ADD', 'TEMP', 48, 'BINOP', 'MUL', 'CONST', 2.2035329565232913, 'TEMP', 12]
# ['MOVE', 'TEMP', 48, 'BINOP', 'ADD', 'TEMP', 48, 'BINOP', 'MUL', 'CONST', 0.5952124276487893, 'TEMP', 13]
# ['MOVE', 'TEMP', 48, 'BINOP', 'ADD', 'TEMP', 48, 'BINOP', 'MUL', 'CONST', 0.23328333267519896, 'TEMP', 14]
# ['MOVE', 'TEMP', 48, 'BINOP', 'ADD', 'TEMP', 48, 'BINOP', 'MUL', 'CONST', 1.0058586559356966, 'TEMP', 16]
# ['MOVE', 'TEMP', 48, 'BINOP', 'ADD', 'TEMP', 48, 'BINOP', 'MUL', 'CONST', 0.00422358069106568, 'TEMP', 20]
# ['MOVE', 'TEMP', 48, 'BINOP', 'ADD', 'TEMP', 48, 'BINOP', 'MUL', 'CONST', 0.39722691881180633, 'TEMP', 23]
# ['MOVE', 'TEMP', 48, 'BINOP', 'ADD', 'TEMP', 48, 'BINOP', 'MUL', 'CONST', 3.5897919404273804, 'TEMP', 25]
# ['MOVE', 'TEMP', 48, 'BINOP', 'ADD', 'TEMP', 48, 'BINOP', 'MUL', 'CONST', 1.1142415386801565, 'TEMP', 27]
# ['MOVE', 'TEMP', 48, 'BINOP', 'ADD', 'TEMP', 48, 'BINOP', 'MUL', 'CONST', 0.20977300113585742, 'TEMP', 28]
# ['MOVE', 'TEMP', 49, 'BINOP', 'ADD', 'TEMP', 49, 'BINOP', 'MUL', 'CONST', 0.6917854149569381, 'TEMP', 0]
# ['MOVE', 'TEMP', 49, 'BINOP', 'ADD', 'TEMP', 49, 'BINOP', 'MUL', 'CONST', 0.011725640789821322, 'TEMP', 3]
# ['MOVE', 'TEMP', 49, 'BINOP', 'ADD', 'TEMP', 49, 'BINOP', 'MUL', 'CONST', 0.6206029905532648, 'TEMP', 4]
# ['MOVE', 'TEMP', 49, 'BINOP', 'ADD', 'TEMP', 49, 'BINOP', 'MUL', 'CONST', 1.9205962064112019, 'TEMP', 5]
# ['MOVE', 'TEMP', 49, 'BINOP', 'ADD', 'TEMP', 49, 'BINOP', 'MUL', 'CONST', 3.7101279268826546, 'TEMP', 10]
# ['MOVE', 'TEMP', 49, 'BINOP', 'ADD', 'TEMP', 49, 'BINOP', 'MUL', 'CONST', 0.03985784931790958, 'TEMP', 11]
# ['MOVE', 'TEMP', 49, 'BINOP', 'ADD', 'TEMP', 49, 'BINOP', 'MUL', 'CONST', 0.4523151687681741, 'TEMP', 16]
# ['MOVE', 'TEMP', 49, 'BINOP', 'ADD', 'TEMP', 49, 'BINOP', 'MUL', 'CONST', 0.5046202167481096, 'TEMP', 20]
# ['MOVE', 'TEMP', 49, 'BINOP', 'ADD', 'TEMP', 49, 'BINOP', 'MUL', 'CONST', 0.8524817419805653, 'TEMP', 22]
# ['MOVE', 'TEMP', 49, 'BINOP', 'ADD', 'TEMP', 49, 'BINOP', 'MUL', 'CONST', 0.0007846101607738335, 'TEMP', 23]
# ['MOVE', 'TEMP', 49, 'BINOP', 'ADD', 'TEMP', 49, 'BINOP', 'MUL', 'CONST', 0.8096419443778441, 'TEMP', 24]
# ['MOVE', 'TEMP', 49, 'BINOP', 'ADD', 'TEMP', 49, 'BINOP', 'MUL', 'CONST', 0.02589447821579707, 'TEMP', 25]
# ['MOVE', 'TEMP', 50, 'BINOP', 'ADD', 'TEMP', 50, 'BINOP', 'MUL', 'CONST', 0.8687740173945482, 'TEMP', 1]
# ['MOVE', 'TEMP', 50, 'BINOP', 'ADD', 'TEMP', 50, 'BINOP', 'MUL', 'CONST', 4.900183967827805, 'TEMP', 4]
# ['MOVE', 'TEMP', 50, 'BINOP', 'ADD', 'TEMP', 50, 'BINOP', 'MUL', 'CONST', 0.030879340200197194, 'TEMP', 6]
# ['MOVE', 'TEMP', 50, 'BINOP', 'ADD', 'TEMP', 50, 'BINOP', 'MUL', 'CONST', 0.04130059963863691, 'TEMP', 8]
# ['MOVE', 'TEMP', 50, 'BINOP', 'ADD', 'TEMP', 50, 'BINOP', 'MUL', 'CONST', 0.19386596034623646, 'TEMP', 9]
# ['MOVE', 'TEMP', 50, 'BINOP', 'ADD', 'TEMP', 50, 'BINOP', 'MUL', 'CONST', 0.0004286075299706589, 'TEMP', 11]
# ['MOVE', 'TEMP', 50, 'BINOP', 'ADD', 'TEMP', 50, 'BINOP', 'MUL', 'CONST', 0.018608984419103823, 'TEMP', 15]
# ['MOVE', 'TEMP', 50, 'BINOP', 'ADD', 'TEMP', 50, 'BINOP', 'MUL', 'CONST', 0.13152896655184973, 'TEMP', 17]
# ['MOVE', 'TEMP', 50, 'BINOP', 'ADD', 'TEMP', 50, 'BINOP', 'MUL', 'CONST', 0.01753157745194735, 'TEMP', 21]
# ['MOVE', 'TEMP', 50, 'BINOP', 'ADD', 'TEMP', 50, 'BINOP', 'MUL', 'CONST', 1.0024558522566844, 'TEMP', 23]
# ['MOVE', 'TEMP', 50, 'BINOP', 'ADD', 'TEMP', 50, 'BINOP', 'MUL', 'CONST', 0.4900867464633412, 'TEMP', 24]
# ['MOVE', 'TEMP', 50, 'BINOP', 'ADD', 'TEMP', 50, 'BINOP', 'MUL', 'CONST', 0.7384155188893373, 'TEMP', 25]
# ['MOVE', 'TEMP', 50, 'BINOP', 'ADD', 'TEMP', 50, 'BINOP', 'MUL', 'CONST', 3.964890764728386, 'TEMP', 27]
# ['MOVE', 'TEMP', 50, 'BINOP', 'ADD', 'TEMP', 50, 'BINOP', 'MUL', 'CONST', 0.06524791484024123, 'TEMP', 28]
# ['MOVE', 'TEMP', 50, 'BINOP', 'ADD', 'TEMP', 50, 'BINOP', 'MUL', 'CONST', 0.09067134813464484, 'TEMP', 29]
# ['MOVE', 'TEMP', 51, 'BINOP', 'ADD', 'TEMP', 51, 'BINOP', 'MUL', 'CONST', 0.6077888942569499, 'TEMP', 0]
# ['MOVE', 'TEMP', 51, 'BINOP', 'ADD', 'TEMP', 51, 'BINOP', 'MUL', 'CONST', 0.034954399788091686, 'TEMP', 1]
# ['MOVE', 'TEMP', 51, 'BINOP', 'ADD', 'TEMP', 51, 'BINOP', 'MUL', 'CONST', 1.4262328974359755, 'TEMP', 5]
# ['MOVE', 'TEMP', 51, 'BINOP', 'ADD', 'TEMP', 51, 'BINOP', 'MUL', 'CONST', 0.4360508065837459, 'TEMP', 7]
# ['MOVE', 'TEMP', 51, 'BINOP', 'ADD', 'TEMP', 51, 'BINOP', 'MUL', 'CONST', 0.008214928104515214, 'TEMP', 10]
# ['MOVE', 'TEMP', 51, 'BINOP', 'ADD', 'TEMP', 51, 'BINOP', 'MUL', 'CONST', 3.5215690631081444, 'TEMP', 12]
# ['MOVE', 'TEMP', 51, 'BINOP', 'ADD', 'TEMP', 51, 'BINOP', 'MUL', 'CONST', 0.0015698203770413385, 'TEMP', 16]
# ['MOVE', 'TEMP', 51, 'BINOP', 'ADD', 'TEMP', 51, 'BINOP', 'MUL', 'CONST', 0.5608622269544444, 'TEMP', 17]
# ['MOVE', 'TEMP', 51, 'BINOP', 'ADD', 'TEMP', 51, 'BINOP', 'MUL', 'CONST', 0.3602175335133907, 'TEMP', 18]
# ['MOVE', 'TEMP', 51, 'BINOP', 'ADD', 'TEMP', 51, 'BINOP', 'MUL', 'CONST', 1.2885265712461873, 'TEMP', 19]
# ['MOVE', 'TEMP', 51, 'BINOP', 'ADD', 'TEMP', 51, 'BINOP', 'MUL', 'CONST', 0.41947166858373497, 'TEMP', 20]
# ['MOVE', 'TEMP', 51, 'BINOP', 'ADD', 'TEMP', 51, 'BINOP', 'MUL', 'CONST', 0.013164951016894098, 'TEMP', 23]
# ['MOVE', 'TEMP', 51, 'BINOP', 'ADD', 'TEMP', 51, 'BINOP', 'MUL', 'CONST', 2.255851656116945, 'TEMP', 24]
# ['MOVE', 'TEMP', 51, 'BINOP', 'ADD', 'TEMP', 51, 'BINOP', 'MUL', 'CONST', 0.05239310138619156, 'TEMP', 25]
# ['MOVE', 'TEMP', 51, 'BINOP', 'ADD', 'TEMP', 51, 'BINOP', 'MUL', 'CONST', 1.717879227487475, 'TEMP', 28]
# ['MOVE', 'TEMP', 52, 'BINOP', 'ADD', 'TEMP', 52, 'BINOP', 'MUL', 'CONST', 0.7512263357534449, 'TEMP', 2]
# ['MOVE', 'TEMP', 52, 'BINOP', 'ADD', 'TEMP', 52, 'BINOP', 'MUL', 'CONST', 1.0731739424969167, 'TEMP', 5]
# ['MOVE', 'TEMP', 52, 'BINOP', 'ADD', 'TEMP', 52, 'BINOP', 'MUL', 'CONST', 2.3720621050476427, 'TEMP', 7]
# ['MOVE', 'TEMP', 52, 'BINOP', 'ADD', 'TEMP', 52, 'BINOP', 'MUL', 'CONST', 0.7775689864951463, 'TEMP', 8]
# ['MOVE', 'TEMP', 52, 'BINOP', 'ADD', 'TEMP', 52, 'BINOP', 'MUL', 'CONST', 0.020462482850270254, 'TEMP', 10]
# ['MOVE', 'TEMP', 52, 'BINOP', 'ADD', 'TEMP', 52, 'BINOP', 'MUL', 'CONST', 0.7281985430580087, 'TEMP', 11]
# ['MOVE', 'TEMP', 52, 'BINOP', 'ADD', 'TEMP', 52, 'BINOP', 'MUL', 'CONST', 0.09706112245845679, 'TEMP', 12]
# ['MOVE', 'TEMP', 52, 'BINOP', 'ADD', 'TEMP', 52, 'BINOP', 'MUL', 'CONST', 6.774942691740729, 'TEMP', 13]
# ['MOVE', 'TEMP', 52, 'BINOP', 'ADD', 'TEMP', 52, 'BINOP', 'MUL', 'CONST', 0.4515720160238555, 'TEMP', 14]
# ['MOVE', 'TEMP', 52, 'BINOP', 'ADD', 'TEMP', 52, 'BINOP', 'MUL', 'CONST', 0.4075158363360135, 'TEMP', 15]
# ['MOVE', 'TEMP', 52, 'BINOP', 'ADD', 'TEMP', 52, 'BINOP', 'MUL', 'CONST', 2.281744256990216, 'TEMP', 17]
# ['MOVE', 'TEMP', 52, 'BINOP', 'ADD', 'TEMP', 52, 'BINOP', 'MUL', 'CONST', 0.3221391558012214, 'TEMP', 18]
# ['MOVE', 'TEMP', 52, 'BINOP', 'ADD', 'TEMP', 52, 'BINOP', 'MUL', 'CONST', 2.067323338014801, 'TEMP', 22]
# ['MOVE', 'TEMP', 52, 'BINOP', 'ADD', 'TEMP', 52, 'BINOP', 'MUL', 'CONST', 1.1318696492993188, 'TEMP', 23]
# ['MOVE', 'TEMP', 52, 'BINOP', 'ADD', 'TEMP', 52, 'BINOP', 'MUL', 'CONST', 0.02642877005780728, 'TEMP', 25]
# ['MOVE', 'TEMP', 52, 'BINOP', 'ADD', 'TEMP', 52, 'BINOP', 'MUL', 'CONST', 0.0039148782290469065, 'TEMP', 26]
# ['MOVE', 'TEMP', 52, 'BINOP', 'ADD', 'TEMP', 52, 'BINOP', 'MUL', 'CONST', 1.6023867843420467, 'TEMP', 28]
# ['MOVE', 'TEMP', 52, 'BINOP', 'ADD', 'TEMP', 52, 'BINOP', 'MUL', 'CONST', 0.5174588133771123, 'TEMP', 29]
# ['MOVE', 'TEMP', 53, 'BINOP', 'ADD', 'TEMP', 53, 'BINOP', 'MUL', 'CONST', 1.226517843725358, 'TEMP', 0]
# ['MOVE', 'TEMP', 53, 'BINOP', 'ADD', 'TEMP', 53, 'BINOP', 'MUL', 'CONST', 0.4942352608093711, 'TEMP', 1]
# ['MOVE', 'TEMP', 53, 'BINOP', 'ADD', 'TEMP', 53, 'BINOP', 'MUL', 'CONST', 0.012169683473854161, 'TEMP', 2]
# ['MOVE', 'TEMP', 53, 'BINOP', 'ADD', 'TEMP', 53, 'BINOP', 'MUL', 'CONST', 0.022628563060261644, 'TEMP', 5]
# ['MOVE', 'TEMP', 53, 'BINOP', 'ADD', 'TEMP', 53, 'BINOP', 'MUL', 'CONST', 0.8667841952954383, 'TEMP', 7]
# ['MOVE', 'TEMP', 53, 'BINOP', 'ADD', 'TEMP', 53, 'BINOP', 'MUL', 'CONST', 1.0359087153218627, 'TEMP', 9]
# ['MOVE', 'TEMP', 53, 'BINOP', 'ADD', 'TEMP', 53, 'BINOP', 'MUL', 'CONST', 0.5397673337826048, 'TEMP', 13]
# ['MOVE', 'TEMP', 53, 'BINOP', 'ADD', 'TEMP', 53, 'BINOP', 'MUL', 'CONST', 0.141046247030953, 'TEMP', 14]
# ['MOVE', 'TEMP', 53, 'BINOP', 'ADD', 'TEMP', 53, 'BINOP', 'MUL', 'CONST', 3.279130123243037, 'TEMP', 15]
# ['MOVE', 'TEMP', 53, 'BINOP', 'ADD', 'TEMP', 53, 'BINOP', 'MUL', 'CONST', 0.16771161406364934, 'TEMP', 24]
# ['MOVE', 'TEMP', 54, 'BINOP', 'ADD', 'TEMP', 54, 'BINOP', 'MUL', 'CONST', 1.8446569451058963, 'TEMP', 2]
# ['MOVE', 'TEMP', 54, 'BINOP', 'ADD', 'TEMP', 54, 'BINOP', 'MUL', 'CONST', 0.407401769836628, 'TEMP', 3]
# ['MOVE', 'TEMP', 54, 'BINOP', 'ADD', 'TEMP', 54, 'BINOP', 'MUL', 'CONST', 5.271602270484546, 'TEMP', 4]
# ['MOVE', 'TEMP', 54, 'BINOP', 'ADD', 'TEMP', 54, 'BINOP', 'MUL', 'CONST', 5.934806670280702, 'TEMP', 6]
# ['MOVE', 'TEMP', 54, 'BINOP', 'ADD', 'TEMP', 54, 'BINOP', 'MUL', 'CONST', 2.267087370561442, 'TEMP', 8]
# ['MOVE', 'TEMP', 54, 'BINOP', 'ADD', 'TEMP', 54, 'BINOP', 'MUL', 'CONST', 0.08315459315201265, 'TEMP', 14]
# ['MOVE', 'TEMP', 54, 'BINOP', 'ADD', 'TEMP', 54, 'BINOP', 'MUL', 'CONST', 0.33400735410563404, 'TEMP', 16]
# ['MOVE', 'TEMP', 54, 'BINOP', 'ADD', 'TEMP', 54, 'BINOP', 'MUL', 'CONST', 1.2333499973255735, 'TEMP', 21]
# ['MOVE', 'TEMP', 54, 'BINOP', 'ADD', 'TEMP', 54, 'BINOP', 'MUL', 'CONST', 0.1236740128854684, 'TEMP', 25]
# ['MOVE', 'TEMP', 54, 'BINOP', 'ADD', 'TEMP', 54, 'BINOP', 'MUL', 'CONST', 0.4696560008380393, 'TEMP', 27]
# ['MOVE', 'TEMP', 54, 'BINOP', 'ADD', 'TEMP', 54, 'BINOP', 'MUL', 'CONST', 0.008607486958071973, 'TEMP', 28]
# ['MOVE', 'TEMP', 55, 'BINOP', 'ADD', 'TEMP', 55, 'BINOP', 'MUL', 'CONST', 0.8643421314303583, 'TEMP', 0]
# ['MOVE', 'TEMP', 55, 'BINOP', 'ADD', 'TEMP', 55, 'BINOP', 'MUL', 'CONST', 0.06254925680664475, 'TEMP', 1]
# ['MOVE', 'TEMP', 55, 'BINOP', 'ADD', 'TEMP', 55, 'BINOP', 'MUL', 'CONST', 0.10856116898729218, 'TEMP', 2]
# ...
# VADD.F32 s2,s1,s2 	 ; # add the bias
# # RELU
# vcmpe.f32  s2, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L47
# .ANTIL47:
# vmsr fpexc, r3
# VMOV.F32 s2,s0  ; 	 # put the value to 0 if less than 0
# .L47:
# vmsr fpexc, r3
# FSTS s2,[r7, #172]
# FLDS s2,[r7, #160] 	 ; # load the content of the output neuron in buffer_register_2
# MOVW r1,#45504 	 ; # move the most significative bits in r3
# MOVT r1,#48798 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VADD.F32 s2,s1,s2 	 ; # add the bias
# # RELU
# vcmpe.f32  s2, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L48
# .ANTIL48:
# vmsr fpexc, r3
# VMOV.F32 s2,s0  ; 	 # put the value to 0 if less than 0
# .L48:
# vmsr fpexc, r3
# FSTS s2,[r7, #160]
# FLDS s2,[r7, #156] 	 ; # load the content of the output neuron in buffer_register_2
# MOVW r1,#9323 	 ; # move the most significative bits in r3
# MOVT r1,#16311 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VADD.F32 s2,s1,s2 	 ; # add the bias
# # RELU
# vcmpe.f32  s2, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L49
# .ANTIL49:
# vmsr fpexc, r3
# VMOV.F32 s2,s0  ; 	 # put the value to 0 if less than 0
# .L49:
# vmsr fpexc, r3
# FSTS s2,[r7, #156]
# MOVW r1,#32560 	 ; # move the most significative bits in r3
# MOVT r1,#49056 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VADD.F32 s8,s1,s8 	 ; # add the bias
# # RELU
# vcmpe.f32  s8, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L50
# .ANTIL50:
# vmsr fpexc, r3
# VMOV.F32 s8,s0  ; 	 # put the value to 0 if less than 0
# .L50:
# vmsr fpexc, r3
# MOVW r1,#21241 	 ; # move the most significative bits in r3
# MOVT r1,#48714 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VADD.F32 s9,s1,s9 	 ; # add the bias
# # RELU
# vcmpe.f32  s9, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L51
# .ANTIL51:
# vmsr fpexc, r3
# VMOV.F32 s9,s0  ; 	 # put the value to 0 if less than 0
# .L51:
# vmsr fpexc, r3
# MOVW r1,#62492 	 ; # move the most significative bits in r3
# MOVT r1,#48884 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VADD.F32 s10,s1,s10 	 ; # add the bias
# # RELU
# vcmpe.f32  s10, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L52
# .ANTIL52:
# vmsr fpexc, r3
# VMOV.F32 s10,s0  ; 	 # put the value to 0 if less than 0
# .L52:
# vmsr fpexc, r3
# FLDS s2,[r7, #56] 	 ; # load the content of the output neuron in buffer_register_2
# MOVW r1,#11514 	 ; # move the most significative bits in r3
# MOVT r1,#15961 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VADD.F32 s2,s1,s2 	 ; # add the bias
# # RELU
# vcmpe.f32  s2, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L53
# .ANTIL53:
# vmsr fpexc, r3
# VMOV.F32 s2,s0  ; 	 # put the value to 0 if less than 0
# .L53:
# vmsr fpexc, r3
# FSTS s2,[r7, #56]
# FLDS s2,[r7, #48] 	 ; # load the content of the output neuron in buffer_register_2
# MOVW r1,#49041 	 ; # move the most significative bits in r3
# MOVT r1,#16241 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VADD.F32 s2,s1,s2 	 ; # add the bias
# # RELU
# vcmpe.f32  s2, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L54
# .ANTIL54:
# vmsr fpexc, r3
# VMOV.F32 s2,s0  ; 	 # put the value to 0 if less than 0
# .L54:
# vmsr fpexc, r3
# FSTS s2,[r7, #48]
# MOVW r1,#32239 	 ; # move the most significative bits in r3
# MOVT r1,#16150 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VADD.F32 s3,s1,s3 	 ; # add the bias
# # RELU
# vcmpe.f32  s3, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L55
# .ANTIL55:
# vmsr fpexc, r3
# VMOV.F32 s3,s0  ; 	 # put the value to 0 if less than 0
# .L55:
# vmsr fpexc, r3
# FLDS s2,[r7, #44] 	 ; # load the content of the output neuron in buffer_register_2
# MOVW r1,#21840 	 ; # move the most significative bits in r3
# MOVT r1,#16213 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VADD.F32 s2,s1,s2 	 ; # add the bias
# # RELU
# vcmpe.f32  s2, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L56
# .ANTIL56:
# vmsr fpexc, r3
# VMOV.F32 s2,s0  ; 	 # put the value to 0 if less than 0
# .L56:
# vmsr fpexc, r3
# FSTS s2,[r7, #44]
# FLDS s2,[r7, #40] 	 ; # load the content of the output neuron in buffer_register_2
# MOVW r1,#7873 	 ; # move the most significative bits in r3
# MOVT r1,#16067 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VADD.F32 s2,s1,s2 	 ; # add the bias
# # RELU
# vcmpe.f32  s2, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L57
# .ANTIL57:
# vmsr fpexc, r3
# VMOV.F32 s2,s0  ; 	 # put the value to 0 if less than 0
# .L57:
# vmsr fpexc, r3
# FSTS s2,[r7, #40]
# FLDS s2,[r7, #32] 	 ; # load the content of the output neuron in buffer_register_2
# MOVW r1,#23832 	 ; # move the most significative bits in r3
# MOVT r1,#16199 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VADD.F32 s2,s1,s2 	 ; # add the bias
# # RELU
# vcmpe.f32  s2, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L58
# .ANTIL58:
# vmsr fpexc, r3
# VMOV.F32 s2,s0  ; 	 # put the value to 0 if less than 0
# .L58:
# vmsr fpexc, r3
# FSTS s2,[r7, #32]
# MOVW r1,#50952 	 ; # move the most significative bits in r3
# MOVT r1,#16316 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VADD.F32 s12,s1,s12 	 ; # add the bias
# # RELU
# vcmpe.f32  s12, #0 ; 	 # compare the register with 0
# vmrs    APSR_nzcv, FPSCR
# bgt     .L59
# .ANTIL59:
# vmsr fpexc, r3
# VMOV.F32 s12,s0  ; 	 # put the value to 0 if less than 0
# .L59:
# vmsr fpexc, r3
# ######################################## HERE GOES THE INTERFACE
# # LEGGO L'INTERFACCIA [1,2]
# FLDS s14,[r7,#108]
# FSTS s15,[r7,#72]
# FSTS s8,[r7,#84]
# FLDS s8,[r7,#176]
# FSTS s12,[r7,#68]
# FLDS s6,[r7,#36]
# FLDS s4,[r7,#52]
# FSTS s10,[r7,#88]
# FLDS s10,[r7,#156]
# FSTS s11,[r7,#80]
# FLDS s11,[r7,#164]
# FSTS s13,[r7,#76]
# FLDS s13,[r7,#60]
# FSTS s9,[r7,#60]
# FLDS s9,[r7,#184]
# FSTS s3,[r7,#64]
# FLDS s3,[r7,#32]
# VMOV.F32 s12, s0	 ; # set the register to 0
# VMOV.F32 s15, s0	 ; # set the register to 0
# MOVW r1,#49673 	 ; # move the most significative bits in r3
# MOVT r1,#15370 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s6 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s12,s2,s12 	 ; #
# MOVW r1,#33336 	 ; # move the most significative bits in r3
# MOVT r1,#16178 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s5 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s12,s2,s12 	 ; #
# MOVW r1,#6888 	 ; # move the most significative bits in r3
# MOVT r1,#15538 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s4 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s12,s2,s12 	 ; #
# MOVW r1,#61748 	 ; # move the most significative bits in r3
# MOVT r1,#16282 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s13 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s12,s2,s12 	 ; #
# MOVW r1,#2647 	 ; # move the most significative bits in r3
# MOVT r1,#16101 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s7 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s12,s2,s12 	 ; #
# MOVW r1,#49298 	 ; # move the most significative bits in r3
# MOVT r1,#16533 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s14 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s12,s2,s12 	 ; #
# MOVW r1,#56616 	 ; # move the most significative bits in r3
# MOVT r1,#16217 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s11 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s12,s2,s12 	 ; #
# MOVW r1,#18302 	 ; # move the most significative bits in r3
# MOVT r1,#16526 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s8 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s12,s2,s12 	 ; #
# MOVW r1,#45329 	 ; # move the most significative bits in r3
# MOVT r1,#15895 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s9 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s12,s2,s12 	 ; #
# MOVW r1,#30045 	 ; # move the most significative bits in r3
# MOVT r1,#16358 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s10 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s12,s2,s12 	 ; #
# FLDS s2,[r7, #60] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r1,#9201 	 ; # move the most significative bits in r3
# MOVT r1,#16116 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s12,s2,s12 	 ; #
# FLDS s2,[r7, #48] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r1,#56374 	 ; # move the most significative bits in r3
# MOVT r1,#16175 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s12,s2,s12 	 ; #
# FLDS s2,[r7, #64] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r1,#58640 	 ; # move the most significative bits in r3
# MOVT r1,#16385 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s12,s2,s12 	 ; #
# MOVW r1,#52707 	 ; # move the most significative bits in r3
# MOVT r1,#16326 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s3 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s12,s2,s12 	 ; #
# FLDS s2,[r7, #68] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r1,#27742 	 ; # move the most significative bits in r3
# MOVT r1,#16288 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s12,s2,s12 	 ; #
# FLDS s2,[r7, #72] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r1,#32442 	 ; # move the most significative bits in r3
# MOVT r1,#16161 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s15,s2,s15 	 ; #
# MOVW r1,#29001 	 ; # move the most significative bits in r3
# MOVT r1,#16443 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s5 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s15,s2,s15 	 ; #
# MOVW r1,#20162 	 ; # move the most significative bits in r3
# MOVT r1,#16332 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s13 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s15,s2,s15 	 ; #
# FLDS s2,[r7, #76] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r1,#48101 	 ; # move the most significative bits in r3
# MOVT r1,#16043 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s15,s2,s15 	 ; #
# MOVW r1,#42456 	 ; # move the most significative bits in r3
# MOVT r1,#16336 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s11 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s15,s2,s15 	 ; #
# FLDS s2,[r7, #168] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r1,#20305 	 ; # move the most significative bits in r3
# MOVT r1,#15856 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s15,s2,s15 	 ; #
# FLDS s2,[r7, #180] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r1,#1420 	 ; # move the most significative bits in r3
# MOVT r1,#15816 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s15,s2,s15 	 ; #
# MOVW r1,#22330 	 ; # move the most significative bits in r3
# MOVT r1,#15956 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s9 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s15,s2,s15 	 ; #
# FLDS s2,[r7, #80] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r1,#22090 	 ; # move the most significative bits in r3
# MOVT r1,#15873 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s15,s2,s15 	 ; #
# FLDS s2,[r7, #160] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r1,#34890 	 ; # move the most significative bits in r3
# MOVT r1,#15445 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s15,s2,s15 	 ; #
# MOVW r1,#50373 	 ; # move the most significative bits in r3
# MOVT r1,#16315 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s10 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s15,s2,s15 	 ; #
# FLDS s2,[r7, #84] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r1,#59977 	 ; # move the most significative bits in r3
# MOVT r1,#16008 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s15,s2,s15 	 ; #
# FLDS s2,[r7, #88] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r1,#24036 	 ; # move the most significative bits in r3
# MOVT r1,#16152 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s15,s2,s15 	 ; #
# FLDS s2,[r7, #56] 	 ; # copy the value in the address on the buffer_register_2
# MOVW r1,#54610 	 ; # move the most significative bits in r3
# MOVT r1,#15629 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s2 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s15,s2,s15 	 ; #
# MOVW r1,#52975 	 ; # move the most significative bits in r3
# MOVT r1,#14616 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VMUL.F32 s2,s1,s3 	 ; # save in buffer_register_2 the multiplication
# VADD.F32 s15,s2,s15 	 ; #
# MOVW r1,#21869 	 ; # move the most significative bits in r3
# MOVT r1,#49005 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VADD.F32 s12,s1,s12 	 ; # add the bias
# MOVW r1,#44364 	 ; # move the most significative bits in r3
# MOVT r1,#16057 	 ; # move the least significative bits in r3
# VMOV.F32 s1,r1 	 ; # copy r3 in buffer_register_1
# VADD.F32 s15,s1,s15 	 ; # add the bias
# ######################################## HERE GOES THE INTERFACE

# %%
input_mask, output_mask
# Out:
# ({3: ('reg', 's7'),
#   1: ('reg', 's15'),
#   2: ('mem', 48),
#   5: ('mem', 36),
#   4: ('mem', 32),
#   7: ('mem', 44),
#   0: ('mem', 60),
#   9: ('mem', 52),
#   8: ('mem', 56),
#   6: ('mem', 40)},
#  {0: ('reg', 's12'), 1: ('reg', 's15')})

# %% [markdown]
# # Test

# %% [markdown]
# ## Unicorn emulator

# %%
from unicorn import *
from unicorn.x86_const import *
from unicorn.mips_const import *
from unicorn.arm_const import *
import struct
from keystone import *

def assemble(codice):
    # in  : assembly code
    # out : machine code
    CODE = """         
        # ENABLE FLOATING POINT OPERATIONS
        mov.w r0, #0xf00000
        mcr p15, #0x0, r0, c1, c0, #0x2
        isb sy
        mov.w r3, #0x40000000
        vmsr fpexc, r3
        """ + codice                           # enabler for FLOAT operations
    try:
        # Initialize engine in X86-32bit mode
        ks = Ks(KS_ARCH_ARM, KS_MODE_ARM)
        encoding, count = ks.asm(CODE)
        #print("%s = %s (number of statements: %u)" %(CODE, encoding, count))

    except KsError as e:
        print("ERROR: %s" %e)
        return 0
    return b''.join( e.to_bytes(1,'little') for e  in encoding)

# %% [markdown]
# # Test Network with input

# %%
def run_compiled_network(codice, input_mask, output_mask, input_vector, r7offset = 0x1000000):
    
    ret = np.zeros(len(output_mask))
    
    register_dict = {}
    register_dict["s0"] = UC_ARM_REG_S0
    register_dict["s1"] = UC_ARM_REG_S1  
    register_dict["s2"] = UC_ARM_REG_S2
    register_dict["s3"] = UC_ARM_REG_S3
    register_dict["s4"] = UC_ARM_REG_S4
    register_dict["s5"] = UC_ARM_REG_S5  
    register_dict["s6"] = UC_ARM_REG_S6
    register_dict["s7"] = UC_ARM_REG_S7
    register_dict["s8"] = UC_ARM_REG_S8
    register_dict["s9"] = UC_ARM_REG_S9  
    register_dict["s10"] = UC_ARM_REG_S10
    register_dict["s11"] = UC_ARM_REG_S11
    register_dict["s12"] = UC_ARM_REG_S12
    register_dict["s13"] = UC_ARM_REG_S13 
    register_dict["s14"] = UC_ARM_REG_S14
    register_dict["s15"] = UC_ARM_REG_S15
    
    def write_register(mu,reg, value):
        mu.reg_write(register_dict[reg], struct.unpack('i',struct.pack('f', value))[0])
    def write_memory(mu,addr,value):
        mu.mem_write(addr + r7offset , struct.pack('f', value))
    def read_register(mu,reg):
        return  mu.reg_read(register_dict[reg])
    def read_memory(mu,addr):
        return  mu.mem_read(addr)
    
    # memory address where emulation starts
    ADDRESS = 0x0000000  # TODO : fix offset in mappings
    print("Emulate ARM code")
    try:
        # Initialize emulator in X86-32bit mode
        mu = Uc(UC_ARCH_ARM, UC_MODE_ARM)

        # map 10MB memory for this emulation
        mu.mem_map(ADDRESS, 17 * 1024 * 1024)

        # write machine code to be emulated to memory
        mu.mem_write(ADDRESS , (codice))

        for idx in input_mask:
            if input_mask[idx][0] == "reg":
                write_register(mu,input_mask[idx][1], input_vector[idx])
            else:
                # mem
                write_memory(mu,input_mask[idx][1], input_vector[idx])

        # emulate code in infinite time & unlimited instructions
        mu.emu_start( ADDRESS,  ADDRESS + len(codice))

        # now print out some registers
        print("Emulation done. Below is the CPU context")
#
 #       r_s7 = mu.reg_read(UC_ARM_REG_S7)
 #       r_s15 = mu.reg_read(UC_ARM_REG_S15)
 #       r_0 = mu.reg_read(UC_ARM_REG_R0)
 #       print(">>> s7 = %f" % struct.unpack('f', r_s7.to_bytes(4,'little')) )
 #       print(">>> s15 = %f" % struct.unpack('f', r_s15.to_bytes(4,'little')) )
 #       print(">>> r0 =  0x%x" % r_0)
        
        
        for idx in output_mask:
            if output_mask[idx][0] == "reg":
                ret[idx] = struct.unpack('f', read_register(mu,output_mask[idx][1]).to_bytes(4,'little'))[0]
            else:
                # mem
                ret[idx] = struct.unpack('f', read_memory(mu,output_mask[idx][1]).to_bytes(4,'little'))[0]

    except UcError as e:
        print("ERROR: %s" % e)
    
    return ret

# %% [markdown]
# # Test della rete definita in ($\star$)

# %%
v  = np.random.randn(10)
machine_code = assemble(codice)
run_compiled_network(machine_code, input_mask, output_mask,v, r7offset = 0x1000000)
# Out:
# Emulate ARM code
# Emulation done. Below is the CPU context
# array([172.68595886, 127.97576904])

# %%
rete.run(v)
# Out:
# DeviceArray([172.68596, 127.97577], dtype=float32)
